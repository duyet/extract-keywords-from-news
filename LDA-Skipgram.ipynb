# %%
import glob
import gensim
import pandas as pd
import logging
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

wordnet_lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'\w+')
STOPWORDS = set(stopwords.words('english'))
STOPWORDS.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# close_branch_reuter, deal_reuter, layoff_reuter, m_a_reuter, new_branch_reuter, new_brand_reuter
KEYWORD_TYPE = 'm_a_reuter'

# Input file
INPUT_FILE = "data/"+ KEYWORD_TYPE +".csv"

data = pd.read_csv(INPUT_FILE, encoding='utf-8', dtype={'short_text': str, 'long_text': str})
print 'Reading', INPUT_FILE, ' => ' , len(data.index), 'rows'
data.drop_duplicates(inplace=True)
# data['short_text'] = data.short_text.astype(str)
print "Unique row:", len(data)
data.head()
# Out:
# Reading data/m_a_reuter.csv  =>  1000 rows
# Unique row: 1000
#                                                  url  \
# 0  https://www.reuters.com/article/akzo-nobel-sha...
# 1  https://www.reuters.com/article/ls-group-kkr-i...
# 2  https://www.reuters.com/article/brief-lkk-heal...
# 3  https://www.reuters.com/article/clariant-hunst...
# 4  https://www.reuters.com/article/clariant-resul...
#
#                                                title  tag        time  \
# 0  Round Two: Elliott Advisors, Akzo Nobel resume...  NaN  3:56am EDT
# 1  KKR to acquire auto assets from S. Korea's LS ...  NaN  3:07am EDT
# 2  BRIEF-Lkk Health Products Group acquires Landm...  NaN  2:27am EDT
# 3          Clariant says Huntsman merger is on track  NaN  1:18am EDT
# 4  Clariant keeps full year guidance after meetin...  NaN  1:08am EDT
#
#                                           short_text  \
# 0  Activist hedge fund ElliottAdvisors on Thursda...
# 1  U.S. buyout firm KKR & Cosaid it has agreed to...
# 2  * Lkk Health Products Group acquires Landmark ...
# 3  Swiss chemicals maker Clariantsaid on Thursday...
# 4  Swiss chemicals group Clariant, which is carry...
#
#                                            long_text
# 0  AMSTERDAM (Reuters) - Activist hedge fund Elli...
# 1  SEOUL (Reuters) - U.S. buyout firm KKR & Co sa...
# 2  July 27 (Reuters) -  LKK Health Products Group...
# 3  ZURICH (Reuters) - Swiss chemicals maker Clari...
# 4  ZURICH, July 27 (Reuters) - Swiss chemicals gr...

# %%
from itertools import chain, combinations
import copy
from nltk.util import ngrams

def pad_sequence(sequence, n, pad_left=False, pad_right=False, pad_symbol=None):
    if pad_left:
        sequence = chain((pad_symbol,) * (n-1), sequence)
    if pad_right:
        sequence = chain(sequence, (pad_symbol,) * (n-1))
    return sequence

def skipgrams(sequence, n, k, pad_left=False, pad_right=False, pad_symbol=None):
    sequence_length = len(sequence)
    sequence = iter(sequence)
    sequence = pad_sequence(sequence, n, pad_left, pad_right, pad_symbol)

    if sequence_length + pad_left + pad_right < k:
        raise Exception("The length of sentence + padding(s) < skip")

    if n < k:
        raise Exception("Degree of Ngrams (n) needs to be bigger than skip (k)")    

    history = []
    nk = n+k

    # Return point for recursion.
    if nk < 1: 
        return
    # If n+k longer than sequence, reduce k by 1 and recur
    elif nk > sequence_length: 
        for ng in skipgrams(list(sequence), n, k-1):
            yield ng

    while nk > 1: # Collects the first instance of n+k length history
        history.append(next(sequence))
        nk -= 1

    # Iterative drop first item in history and picks up the next
    # while yielding skipgrams for each iteration.
    for item in sequence:
        history.append(item)
        current_token = history.pop(0)      
        # Iterates through the rest of the history and 
        # pick out all combinations the n-1grams
        for idx in list(combinations(range(len(history)), n-1)):
            ng = [current_token]
            for _id in idx:
                ng.append(history[_id])
            yield tuple(ng)

    # Recursively yield the skigrams for the rest of seqeunce where
    # len(sequence) < n+k
    for ng in list(skipgrams(history, n, k-1)):
        yield ng

# %%
# remove common words and tokenize
data['full_content'] = data['title'] + ' ' + data['long_text']
full_content = data['full_content'].tolist()
# full_content = [[wordnet_lemmatizer.lemmatize(z) for z in tokenizer.tokenize(str(t).decode('utf-8').lower()) if z not in STOPWORDS] for t in full_content]
# full_content = [[z for z in str(t).lower().split(" ") if z not in STOPWORDS] for t in full_content]

full_content = [[wordnet_lemmatizer.lemmatize(z) for z in tokenizer.tokenize(unicode(t).lower()) if z not in STOPWORDS] for t in full_content]
print full_content[:2]
with open("full_content", "wb") as f:
    f.write(str(full_content))
# Out:
# [[u'round', u'two', u'elliott', u'advisor', u'akzo', u'nobel', u'resume', u'combat', u'dutch', u'court', u'amsterdam', u'reuters', u'activist', u'hedge', u'fund', u'elliott', u'advisor', u'thursday', u'pressed', u'ahead', u'second', u'lawsuit', u'seeking', u'oust', u'chairman', u'dutch', u'paint', u'group', u'akzo', u'nobel', u'rejection', u'26', u'3', u'billion', u'euro', u'30', u'billion', u'takeover', u'proposal', u'u', u'group', u'ppg', u'industry', u'elliott', u'largest', u'akzo', u'investor', u'9', u'5', u'percent', u'stake', u'pursuing', u'case', u'even', u'akzo', u'said', u'tuesday', u'70', u'year', u'old', u'chairman', u'antony', u'burgmans', u'would', u'step', u'term', u'expires', u'next', u'april', u'late', u'elliott', u'engaged', u'increasingly', u'bitter', u'fight', u'burgmans', u'akzo', u'pittsburgh', u'based', u'ppg', u'six', u'month', u'compulsory', u'cooling', u'period', u'expires', u'december', u'analyst', u'believe', u'departure', u'two', u'leading', u'opponent', u'deal', u'chief', u'executive', u'ton', u'buechner', u'announced', u'immediate', u'resignation', u'july', u'19', u'due', u'health', u'reason', u'could', u'open', u'door', u'talk', u'preliminary', u'ruling', u'may', u'amsterdam', u'enterprise', u'chamber', u'rejected', u'elliott', u'bid', u'compel', u'akzo', u'convene', u'extraordinary', u'meeting', u'shareholder', u'vote', u'dismissing', u'burgmans', u'saying', u'attempt', u'wrest', u'control', u'company', u'strategic', u'direction', u'board', u'buechner', u'sudden', u'departure', u'left', u'successor', u'relatively', u'new', u'chemical', u'division', u'chief', u'thierry', u'vanlancker', u'deliver', u'higher', u'sale', u'margin', u'promised', u'dutch', u'paintmaker', u'fended', u'ppg', u'takeover', u'attempt', u'akzo', u'second', u'quarter', u'result', u'announced', u'tuesday', u'missed', u'expectation', u'company', u'share', u'traded', u'75', u'57', u'euro', u'thursday', u'morning', u'far', u'ppg', u'final', u'cash', u'share', u'proposal', u'around', u'95', u'euro', u'made', u'april', u'akzo', u'said', u'shareholder', u'would', u'say', u'extraordinary', u'meeting', u'sept', u'8', u'elliott', u'responded', u'furiously', u'saying', u'akzo', u'chosen', u'yet', u'flout', u'fundamental', u'shareholder', u'right', u'allowing', u'vote', u'burgmans', u'thursday', u'court', u'hear', u'argument', u'elliott', u'york', u'capital', u'management', u'supporting', u'suit', u'seeking', u'summary', u'ruling', u'judge', u'call', u'extraordinary', u'shareholder', u'meeting', u'vote', u'burgmans', u'position', u'akzo', u'would', u'present', u'counter', u'argument', u'ruling', u'expected', u'within', u'two', u'week', u'editing', u'keith', u'weir'], [u'kkr', u'acquire', u'auto', u'asset', u'korea', u'l', u'group', u'943', u'mln', u'seoul', u'reuters', u'u', u'buyout', u'firm', u'kkr', u'co', u'said', u'agreed', u'buy', u'auto', u'part', u'material', u'business', u'south', u'korea', u'l', u'group', u'1', u'05', u'trillion', u'943', u'million', u'deal', u'follows', u'purchase', u'nissan', u'motor', u'supplier', u'calsonic', u'kansei', u'last', u'year', u'kkr', u'create', u'joint', u'venture', u'l', u'l', u'automotive', u'auto', u'part', u'electronics', u'maker', u'additionally', u'buy', u'affiliate', u'make', u'copper', u'foil', u'large', u'capacity', u'lithium', u'ion', u'battery', u'used', u'electric', u'vehicle', u'kkr', u'47', u'percent', u'stake', u'joint', u'venture', u'l', u'automotive', u'make', u'switch', u'interior', u'lamp', u'auto', u'part', u'hyundai', u'motor', u'global', u'automaker', u'well', u'top', u'tier', u'supplier', u'like', u'continental', u'delphi', u'make', u'proposed', u'investment', u'u', u'9', u'3', u'billion', u'asian', u'fund', u'iii', u'november', u'kkr', u'co', u'said', u'would', u'buy', u'calsonic', u'kansei', u'498', u'3', u'billion', u'yen', u'4', u'5', u'billion', u'biggest', u'deal', u'japan', u'reporting', u'hyunjoo', u'jin', u'editing', u'edwina', u'gibbs']]

# %%
full_content_ = full_content
two_skip_bigrams = [list(skipgrams(c, n=3, k=3)) for c in full_content if len(c) > 5  ]
gram_12 = [ [ [a+"_"+b, a+"_"+c] for a, b, c in z ] for z in two_skip_bigrams]

# %%
gram_12 = [reduce(lambda x,y: x+y, z) for z in gram_12]

# %%
gram_12 = [list(set(z)) for z in gram_12]

# %%
gram_12[:3]
# Out:
# [[u'stake_even',
#   u'cooling_december',
#   u'tuesday_chairman',
#   u'departure_opponent',
#   u'step_next',
#   u'within_two',
#   u'six_month',
#   u'ruling_expected',
#   u'fund_elliott',
#   u'share_57',
#   u'saying_flout',
#   u'enterprise_rejected',
#   u'capital_management',
#   u'term_next',
#   u'3_billion',
#   u'bid_akzo',
#   u'extraordinary_responded',
#   u'dismissing_burgmans',
#   u'final_share',
#   u'court_reuters',
#   u'responded_akzo',
#   u'missed_traded',
#   u'door_preliminary',
#   u'hear_capital',
#   u'pursuing_said',
#   u'ppg_six',
#   u'ruling_call',
#   u'believe_departure',
#   u'open_preliminary',
#   u'opponent_buechner',
#   u'fund_advisor',
#   u'euro_akzo',
#   u'takeover_result',
#   u'court_hear',
#   u'direction_board',
#   u'u_ppg',
#   u'pursuing_case',
#   u'elliott_5',
#   u'elliott_9',
#   u'26_3',
#   u'division_thierry',
#   u'ton_announced',
#   u'left_relatively',
#   u'around_made',
#   u'position_argument',
#   u'next_engaged',
#   u'26_30',
#   u'dutch_amsterdam',
#   u'compel_shareholder',
#   u'talk_preliminary',
#   u'pittsburgh_compulsory',
#   u'could_talk',
#   u'supporting_suit',
#   u'within_keith',
#   u'would_sept',
#   u'buechner_successor',
#   u'u_elliott',
#   u'burgmans_elliott',
#   u'higher_dutch',
#   u'promised_paintmaker',
#   u'ppg_elliott',
#   u'even_70',
#   u'dutch_nobel',
#   u'percent_akzo',
#   u'announced_resignation',
#   u'19_reason',
#   u'extraordinary_8',
#   u'call_vote',
#   u'promised_dutch',
#   u'ppg_around',
#   u'saying_akzo',
#   u'rejection_euro',
#   u'missed_share',
#   u'rejected_compel',
#   u'morning_ppg',
#   u'wrest_board',
#   u'elliott_burgmans',
#   u'expected_keith',
#   u'could_preliminary',
#   u'health_talk',
#   u'akzo_flout',
#   u'group_ppg',
#   u'30_takeover',
#   u'billion_30',
#   u'fended_takeover',
#   u'95_akzo',
#   u'right_allowing',
#   u'shareholder_dismissing',
#   u'9_5',
#   u'shareholder_thursday',
#   u'increasingly_fight',
#   u'made_akzo',
#   u'door_ruling',
#   u'shareholder_meeting',
#   u'quarter_announced',
#   u'antony_would',
#   u'advisor_lawsuit',
#   u'shareholder_say',
#   u'resignation_reason',
#   u'expected_week',
#   u'chosen_flout',
#   u'supporting_summary',
#   u'ahead_chairman',
#   u'bitter_fight',
#   u'strategic_sudden',
#   u'reuters_activist',
#   u'departure_successor',
#   u'said_say',
#   u'takeover_u',
#   u'old_chairman',
#   u'advisor_second',
#   u'open_door',
#   u'elliott_investor',
#   u'buechner_left',
#   u'seeking_dutch',
#   u'vote_burgmans',
#   u'late_engaged',
#   u'margin_ppg',
#   u'largest_akzo',
#   u'shareholder_burgmans',
#   u'argument_york',
#   u'judge_extraordinary',
#   u'hear_elliott',
#   u'thursday_court',
#   u'70_year',
#   u'quarter_missed',
#   u'burgmans_argument',
#   u'saying_chosen',
#   u'even_akzo',
#   u'dismissing_wrest',
#   u'rejected_elliott',
#   u'court_amsterdam',
#   u'57_thursday',
#   u'resignation_health',
#   u'result_missed',
#   u'combat_activist',
#   u'old_step',
#   u'takeover_akzo',
#   u'convene_shareholder',
#   u'sudden_departure',
#   u'ppg_final',
#   u'ton_resignation',
#   u'chief_thierry',
#   u'30_group',
#   u'cooling_period',
#   u'shareholder_right',
#   u'akzo_argument',
#   u'higher_paintmaker',
#   u'deal_executive',
#   u'would_meeting',
#   u'talk_enterprise',
#   u'quarter_expectation',
#   u'engaged_fight',
#   u'two_leading',
#   u'akzo_based',
#   u'case_tuesday',
#   u'meeting_shareholder',
#   u'argument_two',
#   u'57_far',
#   u'leading_chief',
#   u'departure_relatively',
#   u'suit_judge',
#   u'two_executive',
#   u'amsterdam_bid',
#   u'elliott_combat',
#   u'talk_amsterdam',
#   u'second_dutch',
#   u'meeting_position',
#   u'takeover_industry',
#   u'health_open',
#   u'responded_furiously',
#   u'two_opponent',
#   u'attempt_strategic',
#   u'july_health',
#   u'preliminary_chamber',
#   u'thursday_morning',
#   u'buechner_19',
#   u'extraordinary_elliott',
#   u'ppg_industry',
#   u'flout_right',
#   u'fended_ppg',
#   u'euro_said',
#   u'resignation_july',
#   u'share_thursday',
#   u'ruling_rejected',
#   u'chosen_yet',
#   u'meeting_furiously',
#   u'expected_two',
#   u'group_rejection',
#   u'fight_pittsburgh',
#   u'company_euro',
#   u'month_compulsory',
#   u'saying_control',
#   u'yet_allowing',
#   u'oust_chairman',
#   u'april_bitter',
#   u'would_extraordinary',
#   u'july_19',
#   u'two_resume',
#   u'increasingly_akzo',
#   u'bid_meeting',
#   u'nobel_combat',
#   u'vote_would',
#   u'ppg_akzo',
#   u'largest_5',
#   u'lawsuit_seeking',
#   u'investor_5',
#   u'tuesday_year',
#   u'could_open',
#   u'period_december',
#   u'investor_9',
#   u'counter_expected',
#   u'group_elliott',
#   u'largest_9',
#   u'increasingly_pittsburgh',
#   u'shareholder_akzo',
#   u'two_weir',
#   u'tuesday_missed',
#   u'5_percent',
#   u'vote_attempt',
#   u'summary_judge',
#   u'supporting_seeking',
#   u'dismissing_control',
#   u'say_elliott',
#   u'rejection_3',
#   u'euro_final',
#   u'elliott_second',
#   u'promised_ppg',
#   u'elliott_thursday',
#   u'70_burgmans',
#   u'control_company',
#   u'april_increasingly',
#   u'would_counter',
#   u'chairman_nobel',
#   u'left_successor',
#   u'largest_investor',
#   u'group_3',
#   u'say_sept',
#   u'division_higher',
#   u'akzo_second',
#   u'tuesday_old',
#   u'said_meeting',
#   u'thursday_seeking',
#   u'ruling_editing',
#   u'share_made',
#   u'second_tuesday',
#   u'shareholder_allowing',
#   u'rejection_30',
#   u'result_company',
#   u'enterprise_compel',
#   u'relatively_new',
#   u'akzo_year',
#   u'saying_attempt',
#   u'euro_april',
#   u'euro_u',
#   u'year_chairman',
#   u'expires_april',
#   u'opponent_executive',
#   u'court_york',
#   u'5_case',
#   u'pressed_ahead',
#   u'ppg_investor',
#   u'akzo_chosen',
#   u'york_capital',
#   u'final_95',
#   u'tuesday_70',
#   u'meeting_elliott',
#   u'second_oust',
#   u'increasingly_bitter',
#   u'case_said',
#   u'ppg_cash',
#   u'akzo_tuesday',
#   u'six_period',
#   u'chamber_rejected',
#   u'vanlancker_deliver',
#   u'term_april',
#   u'relatively_division',
#   u'elliott_responded',
#   u'billion_billion',
#   u'missed_75',
#   u'seeking_paint',
#   u'would_expected',
#   u'management_suit',
#   u'step_april',
#   u'reason_talk',
#   u'percent_pursuing',
#   u'oust_paint',
#   u'pursuing_tuesday',
#   u'paintmaker_attempt',
#   u'sept_saying',
#   u'75_far',
#   u'shareholder_vote',
#   u'70_chairman',
#   u'shareholder_extraordinary',
#   u'akzo_percent',
#   u'dismissing_attempt',
#   u'75_57',
#   u'engaged_bitter',
#   u'advisor_pressed',
#   u'95_said',
#   u'door_may',
#   u'cash_proposal',
#   u'vote_thursday',
#   u'elliott_pressed',
#   u'ruling_may',
#   u'said_year',
#   u'ppg_compulsory',
#   u'reason_could',
#   u'meeting_burgmans',
#   u'period_expires',
#   u'wrest_strategic',
#   u'burgmans_ppg',
#   u'5_pursuing',
#   u'hedge_thursday',
#   u'york_suit',
#   u'shareholder_would',
#   u'compel_convene',
#   u'period_analyst',
#   u'activist_thursday',
#   u'ruling_judge',
#   u'next_elliott',
#   u'call_burgmans',
#   u'chief_ton',
#   u'analyst_opponent',
#   u'counter_argument',
#   u'supporting_judge',
#   u'believe_leading',
#   u'antony_burgmans',
#   u'activist_hedge',
#   u'health_could',
#   u'around_95',
#   u'present_argument',
#   u'expectation_57',
#   u'enterprise_bid',
#   u'court_activist',
#   u'saying_fundamental',
#   u'old_burgmans',
#   u'board_successor',
#   u'euro_morning',
#   u'burgmans_counter',
#   u'year_old',
#   u'flout_allowing',
#   u'may_amsterdam',
#   u'control_buechner',
#   u'second_seeking',
#   u'sale_promised',
#   u'counter_ruling',
#   u'thursday_argument',
#   u'buechner_july',
#   u'health_door',
#   u'nobel_rejection',
#   u'missed_expectation',
#   u'thursday_ppg',
#   u'company_57',
#   u'19_health',
#   u'proposal_euro',
#   u'share_proposal',
#   u'control_strategic',
#   u'chairman_paint',
#   u'thursday_pressed',
#   u'akzo_fundamental',
#   u'amsterdam_enterprise',
#   u'burgmans_based',
#   u'advisor_dutch',
#   u'expectation_traded',
#   u'convene_extraordinary',
#   u'ruling_amsterdam',
#   u'burgmans_step',
#   u'chairman_burgmans',
#   u'8_akzo',
#   u'based_ppg',
#   u'court_fund',
#   u'57_ppg',
#   u'stake_akzo',
#   u'dutch_attempt',
#   u'control_direction',
#   u'april_engaged',
#   u'attempt_wrest',
#   u'chief_executive',
#   u'york_seeking',
#   u'said_tuesday',
#   u'amsterdam_elliott',
#   u'deliver_sale',
#   u'summary_extraordinary',
#   u'argument_supporting',
#   u'sept_responded',
#   u'executive_immediate',
#   u'thursday_far',
#   u'direction_buechner',
#   u'thursday_elliott',
#   u'believe_deal',
#   u'case_akzo',
#   u'investor_percent',
#   u'compel_extraordinary',
#   u'may_rejected',
#   u'sale_fended',
#   u'within_week',
#   u'strategic_departure',
#   u'paintmaker_takeover',
#   u'akzo_six',
#   u'industry_akzo',
#   u'step_expires',
#   u'70_antony',
#   u'announced_expectation',
#   u'buechner_departure',
#   u'largest_percent',
#   u'year_burgmans',
#   u'burgmans_attempt',
#   u'advisor_combat',
#   u'engaged_increasingly',
#   u'shareholder_saying',
#   u'akzo_stake',
#   u'december_two',
#   u'second_quarter',
#   u'extraordinary_vote',
#   u'morning_cash',
#   u'group_26',
#   u'departure_chemical',
#   u'furiously_flout',
#   u'dutch_ppg',
#   u'new_division',
#   u'akzo_shareholder',
#   u'thursday_hear',
#   u'8_responded',
#   u'executive_buechner',
#   u'proposal_ppg',
#   u'chosen_fundamental',
#   u'within_weir',
#   u'term_expires',
#   u'expected_editing',
#   u'bitter_burgmans',
#   u'responded_saying',
#   u'ruling_within',
#   u'resume_reuters',
#   u'oust_dutch',
#   u'tuesday_share',
#   u'thursday_second',
#   u'75_morning',
#   u'traded_57',
#   u'control_board',
#   u'round_nobel',
#   u'amsterdam_chamber',
#   u'right_thursday',
#   u'traded_thursday',
#   u'extraordinary_burgmans',
#   u'yet_flout',
#   u'position_present',
#   u'six_cooling',
#   u'industry_elliott',
#   u'announced_july',
#   u'paint_group',
#   u'left_new',
#   u'month_december',
#   u'bitter_pittsburgh',
#   u'amsterdam_hedge',
#   u'elliott_chosen',
#   u'vote_hear',
#   u'dutch_hedge',
#   u'akzo_quarter',
#   u'around_euro',
#   u'extraordinary_meeting',
#   u'takeover_group',
#   u'board_departure',
#   u'euro_far',
#   u'proposal_group',
#   u'allowing_vote',
#   u'open_may',
#   u'hear_management',
#   u'believe_two',
#   u'week_editing',
#   u'made_shareholder',
#   u'second_missed',
#   u'direction_left',
#   u'burgmans_hear',
#   u'vanlancker_higher',
#   u'argument_ruling',
#   u'akzo_26',
#   u'nobel_26',
#   u'combat_reuters',
#   u'rejected_akzo',
#   u'preliminary_enterprise',
#   u'group_nobel',
#   u'chosen_shareholder',
#   u'ppg_period',
#   u'95_april',
#   u'court_capital',
#   u'december_leading',
#   u'industry_largest',
#   u'convene_dismissing',
#   u'higher_promised',
#   u'chamber_akzo',
#   u'fight_based',
#   u'judge_shareholder',
#   u'u_group',
#   u'ruling_week',
#   u'combat_court',
#   u'antony_expires',
#   u'pressed_lawsuit',
#   u'elliott_akzo',
#   u'summary_call',
#   u'second_chairman',
#   u'immediate_july',
#   u'thierry_vanlancker',
#   u'based_month',
#   u'cash_share',
#   u'new_chemical',
#   u'deliver_margin',
#   u'second_lawsuit',
#   u'chosen_right',
#   u'opponent_ton',
#   u'billion_u',
#   u'vote_argument',
#   u'amsterdam_rejected',
#   u'ppg_proposal',
#   u'due_open',
#   u'based_compulsory',
#   u'9_percent',
#   u'extraordinary_shareholder',
#   u'takeover_ppg',
#   u'sept_elliott',
#   u'burgmans_expires',
#   u'billion_group',
#   u'two_keith',
#   u'akzo_pittsburgh',
#   u'company_strategic',
#   u'reason_door',
#   u'rejected_bid',
#   u'akzo_resume',
#   u'deliver_promised',
#   u'thursday_lawsuit',
#   u'resume_court',
#   u'pursuing_akzo',
#   u'akzo_ppg',
#   u'announced_tuesday',
#   u'seeking_summary',
#   u'thursday_final',
#   u'resignation_19',
#   u'expires_late',
#   u'lawsuit_dutch',
#   u'said_old',
#   u'burgmans_term',
#   u'direction_sudden',
#   u'board_buechner',
#   u'said_chairman',
#   u'meeting_would',
#   u'9_pursuing',
#   u'9_stake',
#   u'final_around',
#   u'elliott_nobel',
#   u'would_april',
#   u'analyst_two',
#   u'elliott_suit',
#   u'period_believe',
#   u'akzo_vote',
#   u'relatively_chemical',
#   u'meeting_responded',
#   u'deal_ton',
#   u'old_antony',
#   u'morning_final',
#   u'investor_stake',
#   u'proposal_95',
#   u'ton_july',
#   u'seeking_chairman',
#   u'sept_8',
#   u'analyst_believe',
#   u'fended_attempt',
#   u'akzo_say',
#   u'departure_left',
#   u'chemical_vanlancker',
#   u'pittsburgh_month',
#   u'95_euro',
#   u'resume_amsterdam',
#   u'pittsburgh_ppg',
#   u'said_would',
#   u'far_proposal',
#   u'akzo_investor',
#   u'deliver_dutch',
#   u'nobel_euro',
#   u'would_term',
#   u'vote_dismissing',
#   u'chairman_would',
#   u'elliott_largest',
#   u'talk_ruling',
#   u'reuters_fund',
#   u'tuesday_traded',
#   u'attempt_company',
#   u'ruling_enterprise',
#   u'executive_ton',
#   u'traded_euro',
#   u'vote_position',
#   u'preliminary_ruling',
#   u'akzo_combat',
#   u'due_health',
#   u'thursday_ahead',
#   u'cash_around',
#   u'division_chief',
#   u'period_departure',
#   u'ppg_largest',
#   u'capital_summary',
#   u'year_would',
#   u'announced_share',
#   u'fundamental_vote',
#   u'expectation_share',
#   u'final_cash',
#   u'talk_may',
#   u'5_even',
#   u'fended_second',
#   u'ton_buechner',
#   u'position_would',
#   u'extraordinary_position',
#   u'chief_deliver',
#   u'stake_case',
#   u'reason_open',
#   u'promised_fended',
#   u'burgmans_present',
#   u'departure_two',
#   u'meeting_sept',
#   u'saying_company',
#   u'meeting_8',
#   u'deal_announced',
#   u'engaged_burgmans',
#   u'thursday_york',
#   u'result_tuesday',
#   u'far_cash',
#   u'expires_next',
#   u'hedge_pressed',
#   u'direction_departure',
#   u'chemical_thierry',
#   u'oust_akzo',
#   u'opponent_deal',
#   u'responded_chosen',
#   u'hear_york',
#   u'case_even',
#   u'argument_week',
#   u'traded_75',
#   u'attempt_second',
#   u'hedge_fund',
#   u'chief_vanlancker',
#   u'reuters_advisor',
#   u'attempt_announced',
#   u'elliott_advisor',
#   u'deal_buechner',
#   u'round_two',
#   u'said_70',
#   u'vanlancker_margin',
#   u'week_keith',
#   u'3_euro',
#   u'ton_immediate',
#   u'made_would',
#   u'responded_yet',
#   u'morning_share',
#   u'elliott_resume',
#   u'successor_chemical',
#   u'elliott_saying',
#   u'nobel_dutch',
#   u'position_counter',
#   u'paint_nobel',
#   u'announced_missed',
#   u'akzo_70',
#   u'relatively_chief',
#   u'company_share',
#   u'dutch_fended',
#   u'takeover_proposal',
#   u'chairman_dutch',
#   u'euro_ppg',
#   u'quarter_result',
#   u'industry_9',
#   u'court_argument',
#   u'oust_group',
#   u'stake_said',
#   u'30_u',
#   u'december_analyst',
#   u'chief_sale',
#   u'chemical_chief',
#   u'ppg_month',
#   u'30_proposal',
#   u'seeking_extraordinary',
#   u'margin_dutch',
#   u'ruling_two',
#   u'akzo_dutch',
#   u'75_thursday',
#   u'july_due',
#   u'judge_call',
#   u'counter_within',
#   u'result_announced',
#   u'ahead_second',
#   u'group_akzo',
#   u'elliott_increasingly',
#   u'said_extraordinary',
#   u'expires_two',
#   u'strategic_buechner',
#   u'based_cooling',
#   u'dutch_group',
#   u'promised_takeover',
#   u'due_door',
#   u'late_bitter',
#   u'bid_convene',
#   u'argument_management',
#   u'share_75',
#   u'attempt_control',
#   u'ppg_share',
#   u'call_meeting',
#   u'ppg_attempt',
#   u'announced_company',
#   u'april_would',
#   u'departure_deal',
#   u'april_say',
#   u'could_ruling',
#   u'suit_seeking',
#   u'successor_new',
#   u'company_75',
#   u'akzo_old',
#   u'elliott_engaged',
#   u'attempt_result',
#   u'nobel_billion',
#   u'percent_case',
#   u'furiously_yet',
#   u'even_year',
#   u'would_8',
#   u'right_vote',
#   u'advisor_nobel',
#   u'vote_court',
#   u'nobel_amsterdam',
#   u'leading_executive',
#   u'two_advisor',
#   u'company_direction',
#   u'margin_promised',
#   u'advisor_resume',
#   u'advisor_thursday',
#   u'26_billion',
#   u'july_reason',
#   u'management_supporting',
#   u'ruling_shareholder',
#   u'9_case',
#   u'75_euro',
#   u'say_meeting',
#   u'chief_higher',
#   u'engaged_akzo',
#   u'combat_amsterdam',
#   u'far_final',
#   u'sudden_relatively',
#   u'expires_believe',
#   u'present_within',
#   u'5_stake',
#   u'far_ppg',
#   u'enterprise_elliott',
#   u'buechner_immediate',
#   u'two_chief',
#   u'management_seeking',
#   u'advisor_ahead',
#   u'two_nobel',
#   u'furiously_akzo',
#   u'chief_immediate',
#   u'nobel_resume',
#   u'bitter_based',
#   u'saying_strategic',
#   u'57_morning',
#   u'euro_30',
#   u'case_70',
#   u'shareholder_sept',
#   u'lawsuit_paint',
#   u'8_saying',
#   u'two_elliott',
#   u'pittsburgh_based',
#   u'fund_thursday',
#   u'suit_ruling',
#   u'fundamental_allowing',
#   u'fund_ahead',
#   u'week_weir',
#   u'industry_investor',
#   u'proposal_around',
#   u'seeking_call',
#   u'due_could',
#   u'expires_analyst',
#   u'akzo_yet',
#   u'company_sudden',
#   u'capital_suit',
#   u'april_shareholder',
#   u'wrest_direction',
#   u'57_euro',
#   u'dutch_paint',
#   u'executive_resignation',
#   u'saying_wrest',
#   u'proposal_u',
#   u'court_hedge',
#   u'expires_engaged',
#   u'chairman_akzo',
#   u'burgmans_saying',
#   u'analyst_departure',
#   u'compel_akzo',
#   u'final_proposal',
#   u'dutch_reuters',
#   u'even_tuesday',
#   u'group_largest',
#   u'cash_euro',
#   u'extraordinary_dismissing',
#   u'term_elliott',
#   u'management_ruling',
#   u'bid_extraordinary',
#   u'bitter_akzo',
#   u'amsterdam_activist',
#   u'vote_saying',
#   u'board_sudden',
#   u'ahead_oust',
#   u'seeking_ruling',
#   u'hedge_elliott',
#   u'expectation_company',
#   u'deliver_higher',
#   u'activist_fund',
#   u'allowing_hear',
#   u'would_ruling',
#   u'month_expires',
#   u'26_euro',
#   u'call_shareholder',
#   u'chamber_bid',
#   u'billion_ppg',
#   u'editing_weir',
#   u'elliott_supporting',
#   u'december_departure',
#   u'meeting_dismissing',
#   u'pittsburgh_six',
#   u'chief_announced',
#   u'immediate_19',
#   u'seeking_judge',
#   u'yet_shareholder',
#   u'may_chamber',
#   u'expectation_75',
#   u'fight_ppg',
#   u'akzo_convene',
#   u'euro_billion',
#   u'cooling_expires',
#   u'euro_made',
#   u'based_six',
#   u'april_akzo',
#   u'expires_departure',
#   u'open_talk',
#   u'burgmans_wrest',
#   u'burgmans_akzo',
#   u'increasingly_burgmans',
#   u'burgmans_position',
#   u'cooling_believe',
#   u'leading_deal',
#   u'dutch_paintmaker',
#   u'next_late',
#   u'akzo_month',
#   u'analyst_leading',
#   u'19_could',
#   u'19_open',
#   u'investor_pursuing',
#   u'result_expectation',
#   u'open_ruling',
#   u'convene_meeting',
#   u'burgmans_control',
#   u'new_vanlancker',
#   u'argument_within',
#   u'lawsuit_oust',
#   u'nobel_court',
#   u'chairman_term',
#   u'late_elliott',
#   u'reuters_elliott',
#   u'wrest_company',
#   u'division_deliver',
#   u'round_advisor',
#   u'compulsory_cooling',
#   u'fundamental_shareholder',
#   u'ppg_takeover',
#   u'board_left',
#   u'ppg_second',
#   u'percent_stake',
#   u'meeting_saying',
#   u'pressed_second',
#   u'around_akzo',
#   u'takeover_quarter',
#   u'fight_akzo',
#   u'strategic_direction',
#   u'could_door',
#   u'round_elliott',
#   u'enterprise_chamber',
#   u'akzo_court',
#   u'position_akzo',
#   u'capital_seeking',
#   u'compulsory_expires',
#   u'december_believe',
#   u'left_division',
#   u'pursuing_even',
#   u'deal_chief',
#   u'takeover_attempt',
#   u'even_said',
#   u'margin_fended',
#   u'chairman_step',
#   u'billion_proposal',
#   u'april_late',
#   u'preliminary_amsterdam',
#   u'immediate_due',
#   u'company_traded',
#   u'elliott_management',
#   u'burgmans_next',
#   u'burgmans_company',
#   u'yet_right',
#   u'flout_vote',
#   u'billion_takeover',
#   u'allowing_court',
#   u'fended_akzo',
#   u'attempt_direction',
#   u'chairman_antony',
#   u'paint_rejection',
#   u'akzo_nobel',
#   u'sale_margin',
#   u'paint_26',
#   u'compel_meeting',
#   u'3_takeover',
#   u'ruling_extraordinary',
#   u'paintmaker_akzo',
#   u'vanlancker_promised',
#   u'new_chief',
#   u'fund_pressed',
#   u'combat_dutch',
#   u'margin_paintmaker',
#   u'chamber_compel',
#   u'division_vanlancker',
#   u'expires_december',
#   u'elliott_ahead',
#   u'elliott_capital',
#   u'ahead_lawsuit',
#   u'would_argument',
#   u'vote_akzo',
#   u'share_around',
#   u'paint_akzo',
#   u'share_euro',
#   u'missed_company',
#   u'argument_capital',
#   u'95_made',
#   u'share_traded',
#   u'attempt_akzo',
#   u'billion_euro',
#   u'tuesday_company',
#   u'higher_margin',
#   u'dutch_activist',
#   u'burgmans_thursday',
#   u'akzo_extraordinary',
#   u'convene_vote',
#   u'door_talk',
#   u'traded_morning',
#   u'dutch_takeover',
#   u'30_billion',
#   u'york_management',
#   u'buechner_announced',
#   u'shareholder_attempt',
#   u'ahead_seeking',
#   u'term_late',
#   u'fight_burgmans',
#   u'elliott_furiously',
#   u'higher_sale',
#   u'health_reason',
#   u'euro_shareholder',
#   u'tuesday_antony',
#   u'akzo_counter',
#   u'say_8',
#   u'akzo_rejection',
#   u'step_late',
#   u'akzo_result',
#   u'suit_summary',
#   u'u_industry',
#   u'court_elliott',
#   u'sale_dutch',
#   u'resignation_due',
#   u'vote_present',
#   u'summary_ruling',
#   u'akzo_billion',
#   u'8_furiously',
#   u'compulsory_analyst',
#   u'two_editing',
#   u'antony_term',
#   u'furiously_saying',
#   u'preliminary_may',
#   u'thierry_margin',
#   u'next_increasingly',
#   u'tuesday_expectation',
#   u'judge_vote',
#   u'door_amsterdam',
#   u'group_industry',
#   u'wrest_control',
#   u'extraordinary_sept',
#   u'resume_combat',
#   u'six_expires',
#   u'euro_takeover',
#   u'akzo_would',
#   u'saying_yet',
#   u'expires_elliott',
#   u'counter_two',
#   u'two_week',
#   u'proposal_elliott',
#   u'shareholder_position',
#   u'new_thierry',
#   u'present_expected',
#   u'8_elliott',
#   u'stake_pursuing',
#   u'sudden_new',
#   u'chief_buechner',
#   u'late_fight',
#   ...],
#  [u'million_follows',
#   u'purchase_motor',
#   u'year_venture',
#   u'auto_korea',
#   u'japan_edwina',
#   u'proposed_investment',
#   u'l_group',
#   u'maker_buy',
#   u'asset_korea',
#   u'proposed_9',
#   u'3_billion',
#   u'hyundai_automaker',
#   u'maker_additionally',
#   u'buyout_kkr',
#   u'top_supplier',
#   u'group_trillion',
#   u'additionally_buy',
#   u'motor_calsonic',
#   u'kkr_buy',
#   u'3_iii',
#   u'kansei_joint',
#   u'supplier_kansei',
#   u'joint_make',
#   u'biggest_reporting',
#   u'part_motor',
#   u'nissan_motor',
#   u'motor_year',
#   u'automaker_well',
#   u'billion_hyunjoo',
#   u'material_korea',
#   u'automotive_interior',
#   u'seoul_buyout',
#   u'tier_delphi',
#   u'said_agreed',
#   u'9_iii',
#   u'u_buyout',
#   u'group_million',
#   u'vehicle_stake',
#   u'part_automaker',
#   u'supplier_proposed',
#   u'asian_iii',
#   u'create_joint',
#   u'seoul_kkr',
#   u'said_calsonic',
#   u'co_agreed',
#   u'group_reuters',
#   u'delphi_u',
#   u'buy_business',
#   u'buy_copper',
#   u'continental_proposed',
#   u'korea_mln',
#   u'stake_venture',
#   u'ion_vehicle',
#   u'joint_auto',
#   u'kkr_47',
#   u'biggest_jin',
#   u'kansei_498',
#   u'continental_delphi',
#   u'auto_business',
#   u'47_percent',
#   u'would_3',
#   u'05_trillion',
#   u'co_calsonic',
#   u'3_fund',
#   u'reuters_kkr',
#   u'south_korea',
#   u'maker_copper',
#   u'percent_venture',
#   u'deal_purchase',
#   u'47_venture',
#   u'november_said',
#   u'auto_buy',
#   u'capacity_ion',
#   u'reporting_jin',
#   u'automotive_part',
#   u'top_delphi',
#   u'kkr_acquire',
#   u'iii_kkr',
#   u'1_05',
#   u'make_lithium',
#   u'year_joint',
#   u'firm_said',
#   u'make_lamp',
#   u'agreed_buy',
#   u'co_said',
#   u'supplier_delphi',
#   u'million_motor',
#   u'south_l',
#   u'l_mln',
#   u'foil_lithium',
#   u'switch_lamp',
#   u'korea_943',
#   u'top_continental',
#   u'electric_percent',
#   u'calsonic_create',
#   u'reporting_edwina',
#   u'would_498',
#   u'asset_l',
#   u'seoul_reuters',
#   u'motor_top',
#   u'percent_automotive',
#   u'motor_well',
#   u'fund_said',
#   u'foil_ion',
#   u'co_would',
#   u'top_tier',
#   u'affiliate_copper',
#   u'follows_purchase',
#   u'auto_additionally',
#   u'south_1',
#   u'make_9',
#   u'buy_auto',
#   u'group_u',
#   u'vehicle_joint',
#   u'november_co',
#   u'make_3',
#   u'automaker_top',
#   u'buy_south',
#   u'stake_joint',
#   u'kkr_l',
#   u'u_fund',
#   u'05_943',
#   u'l_reuters',
#   u'fund_kkr',
#   u'hyundai_global',
#   u'asset_group',
#   u'electric_47',
#   u'calsonic_yen',
#   u'billion_november',
#   u'tier_continental',
#   u'kkr_said',
#   u'biggest_hyunjoo',
#   u'electronics_make',
#   u'billion_asian',
#   u'498_5',
#   u'498_4',
#   u'automaker_supplier',
#   u'group_1',
#   u'billion_kkr',
#   u'auto_material',
#   u'foil_large',
#   u'acquire_auto',
#   u'mln_reuters',
#   u'electric_vehicle',
#   u'delphi_investment',
#   u'fund_co',
#   u'billion_fund',
#   u'auto_part',
#   u'interior_motor',
#   u'make_investment',
#   u'material_business',
#   u'used_vehicle',
#   u'lithium_vehicle',
#   u'kkr_agreed',
#   u'agreed_part',
#   u'last_kkr',
#   u'buy_large',
#   u'asian_co',
#   u'follows_supplier',
#   u'kkr_would',
#   u'deal_editing',
#   u'top_like',
#   u'co_kansei',
#   u'part_hyundai',
#   u'korea_group',
#   u'asset_943',
#   u'iii_co',
#   u'foil_capacity',
#   u'u_billion',
#   u'nissan_supplier',
#   u'battery_vehicle',
#   u'47_l',
#   u'mln_buyout',
#   u'buyout_agreed',
#   u'part_well',
#   u'business_l',
#   u'l_maker',
#   u'percent_l',
#   u'group_943',
#   u'japan_hyunjoo',
#   u'498_3',
#   u'make_capacity',
#   u'agreed_business',
#   u'business_1',
#   u'venture_make',
#   u'large_lithium',
#   u'reuters_u',
#   u'mln_seoul',
#   u'asian_fund',
#   u'l_lamp',
#   u'said_material',
#   u'used_electric',
#   u'5_deal',
#   u'l_switch',
#   u'943_deal',
#   u'acquire_l',
#   u'deal_nissan',
#   u'foil_battery',
#   u'november_would',
#   u'buy_calsonic',
#   u'billion_5',
#   u'reuters_buyout',
#   u'million_deal',
#   u'9_billion',
#   u'like_delphi',
#   u'business_korea',
#   u'make_u',
#   u'l_1',
#   u'u_asian',
#   u'3_5',
#   u'part_electronics',
#   u'943_nissan',
#   u'calsonic_billion',
#   u'billion_deal',
#   u'auto_maker',
#   u'nissan_last',
#   u'trillion_purchase',
#   u'billion_yen',
#   u'l_trillion',
#   u'calsonic_3',
#   u'continental_investment',
#   u'purchase_calsonic',
#   u'1_deal',
#   u'calsonic_year',
#   u'auto_l',
#   u'motor_tier',
#   u'calsonic_last',
#   u'u_kkr',
#   u'copper_lithium',
#   u'said_buy',
#   u'like_make',
#   u'supplier_kkr',
#   u'electronics_maker',
#   u'kkr_venture',
#   u'part_l',
#   u'acquire_group',
#   u'auto_electronics',
#   u'supplier_make',
#   u'investment_asian',
#   u'yen_5',
#   u'make_part',
#   u'jin_edwina',
#   u'used_percent',
#   u'lamp_motor',
#   u'like_proposed',
#   u'november_buy',
#   u'trillion_943',
#   u'kansei_year',
#   u'supplier_continental',
#   u'supplier_like',
#   u'motor_automaker',
#   u'l_make',
#   u'large_battery',
#   u'material_l',
#   u'943_mln',
#   u'material_group',
#   u'kkr_korea',
#   u'korea_seoul',
#   u'hyundai_well',
#   u'affiliate_foil',
#   u'korea_05',
#   u'copper_capacity',
#   u'deal_hyunjoo',
#   u'l_l',
#   u'like_continental',
#   u'automotive_auto',
#   u'stake_automotive',
#   u'said_498',
#   u'buy_kansei',
#   u'4_billion',
#   u'l_05',
#   u'year_l',
#   u'buyout_co',
#   u'buyout_said',
#   u'part_material',
#   u'maker_make',
#   u'asian_kkr',
#   u'vehicle_47',
#   u'interior_auto',
#   u'purchase_kansei',
#   u'business_group',
#   u'yen_deal',
#   u'joint_l',
#   u'billion_4',
#   u'47_joint',
#   u'make_auto',
#   u'percent_joint',
#   u'would_kansei',
#   u'hyunjoo_editing',
#   u'interior_hyundai',
#   u'joint_automotive',
#   u'calsonic_kkr',
#   u'yen_billion',
#   u'joint_venture',
#   u'capacity_battery',
#   u'automotive_additionally',
#   u'l_automotive',
#   u'ion_kkr',
#   u'well_tier',
#   u'u_9',
#   u'943_purchase',
#   u'auto_asset',
#   u'billion_billion',
#   u'reuters_firm',
#   u'kansei_billion',
#   u'kkr_create',
#   u'9_fund',
#   u'9_asian',
#   u'said_part',
#   u'9_3',
#   u'lithium_used',
#   u'jin_editing',
#   u'kkr_asset',
#   u'motor_global',
#   u'stake_make',
#   u'automotive_make',
#   u'global_well',
#   u'additionally_affiliate',
#   u'investment_3',
#   u'make_proposed',
#   u'05_follows',
#   u'investment_9',
#   u'group_seoul',
#   u'supplier_year',
#   u'tier_supplier',
#   u'kkr_stake',
#   u'well_like',
#   u'venture_switch',
#   u'create_automotive',
#   u'switch_interior',
#   u'3_november',
#   u'kansei_3',
#   u'well_continental',
#   u'battery_47',
#   u'kansei_4',
#   u'reporting_hyunjoo',
#   u'iii_november',
#   u'hyundai_top',
#   u'follows_nissan',
#   u'venture_interior',
#   u'acquire_korea',
#   u'editing_gibbs',
#   u'lithium_electric',
#   u'investment_u',
#   u'u_firm',
#   u'yen_4',
#   u'year_create',
#   u'mln_firm',
#   u'asian_november',
#   u'electric_kkr',
#   u'kkr_percent',
#   u'4_japan',
#   u'part_south',
#   u'943_seoul',
#   u'buy_498',
#   u'billion_japan',
#   u'deal_follows',
#   u'5_reporting',
#   u'hyunjoo_gibbs',
#   u'make_interior',
#   u'l_943',
#   u'motor_kansei',
#   u'large_capacity',
#   u'yen_biggest',
#   u'kansei_kkr',
#   u'purchase_supplier',
#   u'auto_automaker',
#   u'affiliate_large',
#   u'buyout_firm',
#   u'capacity_lithium',
#   u'kkr_joint',
#   u'well_top',
#   u'auto_hyundai',
#   u'last_joint',
#   u'1_million',
#   u'billion_biggest',
#   u'hyundai_motor',
#   u'kansei_last',
#   u'global_tier',
#   u'943_buyout',
#   u'acquire_asset',
#   u'large_ion',
#   u'continental_make',
#   u'ion_used',
#   u'buy_affiliate',
#   u'korea_trillion',
#   u'tier_like',
#   u'05_deal',
#   u'kansei_create',
#   u'japan_reporting',
#   u'delphi_9',
#   u'supplier_last',
#   u'reporting_editing',
#   u'proposed_billion',
#   u'part_global',
#   u'copper_foil',
#   u'ion_battery',
#   u'firm_buy',
#   u'kkr_co',
#   u'proposed_u',
#   u'part_buy',
#   u'electric_stake',
#   u'vehicle_kkr',
#   u'seoul_u',
#   u'part_korea',
#   u'maker_affiliate',
#   u'billion_reporting',
#   u'additionally_foil',
#   u'automaker_like',
#   u'motor_last',
#   u'additionally_make',
#   u'fund_november',
#   u'iii_said',
#   u'seoul_firm',
#   u'delphi_proposed',
#   u'make_copper',
#   u'used_47',
#   u'switch_auto',
#   u'japan_editing',
#   u'global_supplier',
#   u'firm_agreed',
#   u'co_part',
#   u'trillion_deal',
#   u'million_nissan',
#   u'make_large',
#   u'iii_would',
#   u'hyunjoo_jin',
#   u'lamp_part',
#   u'electronics_affiliate',
#   u'purchase_nissan',
#   u'nissan_calsonic',
#   u'venture_part',
#   u'reuters_co',
#   u'lamp_hyundai',
#   u'affiliate_capacity',
#   u'battery_electric',
#   u'u_3',
#   u'biggest_deal',
#   u'switch_hyundai',
#   u'million_purchase',
#   u'4_deal',
#   u'47_stake',
#   u'943_reuters',
#   u'percent_stake',
#   u'venture_l',
#   u'agreed_material',
#   u'1_trillion',
#   u'943_u',
#   u'investment_billion',
#   u'automotive_maker',
#   u'year_kkr',
#   u'3_asian',
#   u'make_switch',
#   u'lamp_global',
#   u'5_biggest',
#   u'l_auto',
#   u'copper_ion',
#   u'switch_part',
#   u'buy_part',
#   u'4_5',
#   u'nissan_kansei',
#   u'copper_large',
#   u'hyunjoo_edwina',
#   u'vehicle_percent',
#   u'943_million',
#   u'u_said',
#   u'calsonic_498',
#   u'asset_mln',
#   u'used_kkr',
#   u'battery_kkr',
#   u'group_05',
#   u'continental_u',
#   u'would_buy',
#   u'automotive_lamp',
#   u'tier_make',
#   u'ion_electric',
#   u'follows_calsonic',
#   u'venture_automotive',
#   u'delphi_make',
#   u'business_south',
#   u'5_japan',
#   u'firm_co',
#   u'motor_supplier',
#   u'buy_3',
#   u'electronics_additionally',
#   u'fund_iii',
#   u'last_year',
#   u'auto_motor',
#   u'buy_make',
#   u'kkr_calsonic',
#   u'trillion_follows',
#   u'capacity_electric',
#   u'south_05',
#   u'lamp_auto',
#   u'kkr_auto',
#   u'proposed_3',
#   u'venture_auto',
#   u'5_billion',
#   u'november_kkr',
#   u'498_yen',
#   u'affiliate_make',
#   u'stake_l',
#   u'automotive_electronics',
#   u'mln_u',
#   u'interior_part',
#   u'4_biggest',
#   u'large_used',
#   u'deal_supplier',
#   u'co_buy',
#   u'calsonic_kansei',
#   u'05_million',
#   u'943_follows',
#   u'buy_material',
#   u'3_4',
#   u'automaker_tier',
#   u'said_would',
#   u'create_l',
#   u'electronics_buy',
#   u'3_yen',
#   u'editing_edwina',
#   u'part_maker',
#   u'kansei_yen',
#   u'last_venture',
#   u'l_interior',
#   u'reporting_gibbs',
#   u'part_affiliate',
#   u'auto_global',
#   u'said_auto',
#   u'deal_reporting',
#   u'deal_motor',
#   u'deal_japan',
#   u'lithium_battery',
#   u'auto_south',
#   u'south_group',
#   u'joint_switch',
#   u'buy_foil',
#   u'l_seoul',
#   u'japan_jin',
#   u'capacity_used',
#   u'material_south',
#   u'would_calsonic',
#   u'498_billion',
#   u'korea_l',
#   u'l_electronics',
#   u'automotive_switch',
#   u'group_mln',
#   u'agreed_auto',
#   u'jin_gibbs',
#   u'said_kansei',
#   u'1_943',
#   u'lithium_ion',
#   u'additionally_copper',
#   u'part_additionally',
#   u'billion_iii',
#   u'battery_used',
#   u'make_foil',
#   u'like_investment',
#   u'firm_kkr',
#   u'l_part',
#   u'global_automaker',
#   u'deal_jin',
#   u'well_supplier',
#   u'u_co',
#   u'create_venture',
#   u'follows_motor',
#   u'global_top',
#   u'korea_1',
#   u'interior_lamp',
#   u'trillion_million',
#   u'part_business',
#   u'co_auto',
#   u'last_create',
#   u'buy_billion',
#   u'auto_943',
#   u'auto_group',
#   u'supplier_calsonic',
#   u'biggest_japan'],
#  [u'building_gbp',
#   u'1_product',
#   u'entered_land',
#   u'12_lkk',
#   u'8_billion',
#   u'billion_approximately',
#   u'walkie_company',
#   u'lkk_total',
#   u'hkd_12',
#   u'street_walkie',
#   u'text_eikon',
#   u'12_product',
#   u'talkie_company',
#   u'say_gbp',
#   u'consideration_1',
#   u'building_bln',
#   u'lkk_26',
#   u'street_gbp',
#   u'lkk_health',
#   u'land_group',
#   u'billion_hkd',
#   u'building_street',
#   u'1_2825',
#   u'brief_group',
#   u'1_stg',
#   u'acquires_1',
#   u'office_fenchurch',
#   u'entered_plc',
#   u'building_london',
#   u'product_land',
#   u'plc_building',
#   u'health_26',
#   u'known_text',
#   u'group_landmark',
#   u'known_talkie',
#   u'28_reuters',
#   u'1_hkd',
#   u'deal_gbp',
#   u'20_walkie',
#   u'product_july',
#   u'street_talkie',
#   u'1_bln',
#   u'security_group',
#   u'source_text',
#   u'gbp_2825',
#   u'landmark_1',
#   u'reuters_product',
#   u'billion_26',
#   u'building_stg',
#   u'street_source',
#   u'product_product',
#   u'agreement_security',
#   u'billion_say',
#   u'agreement_group',
#   u'product_entered',
#   u'health_total',
#   u'plc_commercial',
#   u'28_july',
#   u'brief_product',
#   u'group_acquires',
#   u'group_acquire',
#   u'health_july',
#   u'20_1',
#   u'gbp_1',
#   u'walkie_eikon',
#   u'gbp_health',
#   u'consideration_gbp',
#   u'landmark_street',
#   u'security_commercial',
#   u'group_building',
#   u'health_consideration',
#   u'security_building',
#   u'2825_health',
#   u'product_building',
#   u'health_acquires',
#   u'plc_20',
#   u'product_gbp',
#   u'1_12',
#   u'2825_say',
#   u'26_group',
#   u'acquires_office',
#   u'office_bln',
#   u'entered_group',
#   u'gbp_hkd',
#   u'health_deal',
#   u'building_fenchurch',
#   u'product_deal',
#   u'landmark_bln',
#   u'27_reuters',
#   u'eikon_company',
#   u'fenchurch_street',
#   u'27_group',
#   u'group_group',
#   u'fenchurch_talkie',
#   u'bln_stg',
#   u'lkk_deal',
#   u'gbp_billion',
#   u'gbp_approximately',
#   u'say_deal',
#   u'london_2825',
#   u'office_20',
#   u'street_2825',
#   u'1_lkk',
#   u'health_product',
#   u'plc_acquire',
#   u'health_group',
#   u'lkk_july',
#   u'office_28',
#   u'july_agreement',
#   u'8_lkk',
#   u'acquire_20',
#   u'london_1',
#   u'known_source',
#   u'27_lkk',
#   u'2825_hkd',
#   u'12_billion',
#   u'20_fenchurch',
#   u'group_lkk',
#   u'walkie_source',
#   u'land_acquire',
#   u'28_stg',
#   u'commercial_street',
#   u'deal_total',
#   u'bln_lkk',
#   u'approximately_8',
#   u'approximately_lkk',
#   u'consideration_billion',
#   u'stg_27',
#   u'reuters_group',
#   u'text_coverage',
#   u'group_office',
#   u'billion_july',
#   u'office_1',
#   u'london_walkie',
#   u'acquires_fenchurch',
#   u'billion_product',
#   u'fenchurch_walkie',
#   u'group_20',
#   u'26_land',
#   u'product_health',
#   u'entered_agreement',
#   u'landmark_28',
#   u'office_building',
#   u'product_consideration',
#   u'london_text',
#   u'deal_consideration',
#   u'talkie_text',
#   u'total_1',
#   u'consideration_2825',
#   u'group_health',
#   u'product_agreement',
#   u'acquire_commercial',
#   u'hkd_health',
#   u'source_company',
#   u'health_health',
#   u'stg_july',
#   u'billion_deal',
#   u'total_billion',
#   u'lkk_product',
#   u'land_commercial',
#   u'20_london',
#   u'health_landmark',
#   u'billion_12',
#   u'commercial_20',
#   u'office_stg',
#   u'28_bln',
#   u'approximately_12',
#   u'product_lkk',
#   u'26_entered',
#   u'total_consideration',
#   u'consideration_approximately',
#   u'commercial_fenchurch',
#   u'security_plc',
#   u'fenchurch_known',
#   u'stg_reuters',
#   u'london_lkk',
#   u'lkk_landmark',
#   u'27_health',
#   u'say_1',
#   u'12_8',
#   u'july_reuters',
#   u'july_land',
#   u'lkk_acquires',
#   u'billion_lkk',
#   u'plc_fenchurch',
#   u'product_group',
#   u'commercial_london',
#   u'acquires_building',
#   u'source_eikon',
#   u'say_consideration',
#   u'agreement_plc',
#   u'commercial_building',
#   u'2825_lkk',
#   u'july_27',
#   u'lkk_say',
#   u'known_eikon',
#   u'say_total',
#   u'building_1',
#   u'total_gbp',
#   u'8_july',
#   u'28_27',
#   u'land_plc',
#   u'july_health',
#   u'office_street',
#   u'landmark_office',
#   u'fenchurch_2825',
#   u'1_health',
#   u'acquires_landmark',
#   u'agreement_acquire',
#   u'total_2825',
#   u'acquire_building',
#   u'stg_lkk',
#   u'landmark_20',
#   u'reuters_health',
#   u'billion_health',
#   u'security_acquire',
#   u'group_commercial',
#   u'reuters_lkk',
#   u'brief_acquires',
#   u'12_health',
#   u'eikon_coverage',
#   u'2825_billion',
#   u'july_security',
#   u'land_security',
#   u'fenchurch_london',
#   u'health_office',
#   u'text_company',
#   u'product_26',
#   u'health_say',
#   u'deal_1',
#   u'approximately_hkd',
#   u'bln_july',
#   u'2825_product',
#   u'brief_lkk',
#   u'product_total',
#   u'walkie_talkie',
#   u'acquires_28',
#   u'building_july',
#   u'product_say',
#   u'health_lkk',
#   u'street_billion',
#   u'walkie_text',
#   u'acquires_20',
#   u'fenchurch_1',
#   u'lkk_lkk',
#   u'health_entered',
#   u'london_billion',
#   u'health_agreement',
#   u'london_talkie',
#   u'deal_2825',
#   u'product_office',
#   u'approximately_billion',
#   u'1_approximately',
#   u'20_gbp',
#   u'july_26',
#   u'building_28',
#   u'street_known',
#   u'building_known',
#   u'bln_27',
#   u'building_20',
#   u'8_health',
#   u'product_landmark',
#   u'known_walkie',
#   u'acquire_fenchurch',
#   u'hkd_billion',
#   u'july_product',
#   u'product_acquires',
#   u'bln_reuters',
#   u'london_source',
#   u'26_security',
#   u'talkie_coverage',
#   u'street_london',
#   u'acquire_street',
#   u'20_street',
#   u'group_1',
#   u'lkk_group',
#   u'source_coverage',
#   u'hkd_lkk',
#   u'26_agreement',
#   u'group_plc',
#   u'hkd_8',
#   u'2825_12',
#   u'billion_8',
#   u'office_london',
#   u'july_entered',
#   u'27_product',
#   u'group_product',
#   u'london_gbp',
#   u'street_1',
#   u'1_billion',
#   u'8_product',
#   u'landmark_building',
#   u'landmark_fenchurch',
#   u'london_known',
#   u'gbp_lkk',
#   u'talkie_source',
#   u'july_lkk',
#   u'2825_8',
#   u'stg_health',
#   u'brief_health',
#   u'entered_security',
#   u'1_july',
#   u'lkk_entered',
#   u'fenchurch_gbp',
#   u'1_27',
#   u'billion_billion',
#   u'agreement_land',
#   u'talkie_eikon',
#   u'2825_approximately',
#   u'20_known',
#   u'1_28']]

# %%
full_content = gram_12

# %%
# remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)
for text in full_content:
    for token in text:
        if not token.isdigit():
            frequency[token] += 1

full_content = [[token for token in text if frequency[token] > 1] for text in full_content]
print full_content[:2]
# Out:
# [[u'stake_even', u'step_next', u'within_two', u'six_month', u'fund_elliott', u'capital_management', u'term_next', u'3_billion', u'bid_akzo', u'final_share', u'court_reuters', u'pursuing_said', u'fund_advisor', u'u_ppg', u'26_3', u'division_thierry', u'around_made', u'26_30', u'dutch_amsterdam', u'talk_preliminary', u'could_talk', u'buechner_successor', u'u_elliott', u'higher_dutch', u'promised_paintmaker', u'dutch_nobel', u'promised_dutch', u'group_ppg', u'30_takeover', u'billion_30', u'fended_takeover', u'9_5', u'shareholder_thursday', u'shareholder_meeting', u'quarter_announced', u'shareholder_say', u'expected_week', u'reuters_activist', u'said_say', u'takeover_u', u'open_door', u'shareholder_burgmans', u'thursday_court', u'old_step', u'convene_shareholder', u'chief_thierry', u'30_group', u'shareholder_right', u'higher_paintmaker', u'deal_executive', u'would_meeting', u'quarter_expectation', u'two_leading', u'meeting_shareholder', u'meeting_position', u'takeover_industry', u'health_open', u'attempt_strategic', u'july_health', u'thursday_morning', u'ppg_industry', u'euro_said', u'share_thursday', u'expected_two', u'company_euro', u'oust_chairman', u'july_19', u'vote_would', u'ppg_akzo', u'largest_5', u'lawsuit_seeking', u'investor_5', u'tuesday_year', u'largest_9', u'5_percent', u'control_company', u'largest_investor', u'group_3', u'akzo_second', u'said_meeting', u'thursday_seeking', u'share_made', u'result_company', u'euro_april', u'euro_u', u'year_chairman', u'court_york', u'ppg_investor', u'case_said', u'akzo_tuesday', u'vanlancker_deliver', u'term_april', u'billion_billion', u'would_expected', u'paintmaker_attempt', u'shareholder_vote', u'cash_proposal', u'said_year', u'period_expires', u'shareholder_would', u'ruling_judge', u'chief_ton', u'antony_burgmans', u'activist_hedge', u'euro_morning', u'year_old', u'sale_promised', u'proposal_euro', u'share_proposal', u'advisor_dutch', u'expectation_traded', u'chairman_burgmans', u'court_fund', u'dutch_attempt', u'chief_executive', u'said_tuesday', u'deliver_sale', u'executive_immediate', u'believe_deal', u'investor_percent', u'sale_fended', u'within_week', u'paintmaker_takeover', u'step_expires', u'announced_expectation', u'largest_percent', u'shareholder_saying', u'akzo_stake', u'second_quarter', u'group_26', u'dutch_ppg', u'akzo_shareholder', u'executive_buechner', u'term_expires', u'responded_saying', u'tuesday_share', u'control_board', u'right_thursday', u'announced_july', u'left_new', u'dutch_hedge', u'akzo_quarter', u'around_euro', u'takeover_group', u'euro_far', u'proposal_group', u'allowing_vote', u'week_editing', u'made_shareholder', u'court_capital', u'industry_largest', u'higher_promised', u'u_group', u'ruling_week', u'thierry_vanlancker', u'cash_share', u'deliver_margin', u'billion_u', u'9_percent', u'billion_group', u'company_strategic', u'rejected_bid', u'deliver_promised', u'announced_tuesday', u'said_old', u'said_chairman', u'meeting_would', u'9_stake', u'would_april', u'analyst_two', u'investor_stake', u'analyst_believe', u'fended_attempt', u'chemical_vanlancker', u'said_would', u'deliver_dutch', u'would_term', u'chairman_would', u'elliott_largest', u'reuters_fund', u'attempt_company', u'executive_ton', u'traded_euro', u'due_health', u'division_chief', u'year_would', u'announced_share', u'talk_may', u'ton_buechner', u'position_would', u'promised_fended', u'meeting_sept', u'saying_company', u'deal_announced', u'thursday_york', u'expires_next', u'chemical_thierry', u'hedge_fund', u'chief_vanlancker', u'reuters_advisor', u'elliott_advisor', u'round_two', u'3_euro', u'made_would', u'elliott_saying', u'paint_nobel', u'company_share', u'dutch_fended', u'takeover_proposal', u'quarter_result', u'industry_9', u'stake_said', u'30_u', u'chief_sale', u'chemical_chief', u'30_proposal', u'margin_dutch', u'ruling_two', u'akzo_dutch', u'result_announced', u'dutch_group', u'promised_takeover', u'share_75', u'call_meeting', u'announced_company', u'april_would', u'suit_seeking', u ...

# %%
dictionary = gensim.corpora.Dictionary(full_content)
dictionary.save('model/contents.dict')
print dictionary
# Out:
# 2017-07-29 14:20:40,719 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-07-29 14:20:41,346 : INFO : built Dictionary(105883 unique tokens: [u'million_income', u'hillhouse_declined', u'share_hold', u'2013_brc', u'hynix_kkr']...) from 1000 documents (total 368486 corpus positions)
# 2017-07-29 14:20:41,346 : INFO : saving Dictionary object under model/contents.dict, separately None
# 2017-07-29 14:20:41,455 : INFO : saved model/contents.dict
# Dictionary(105883 unique tokens: [u'million_income', u'hillhouse_declined', u'share_hold', u'2013_brc', u'hynix_kkr']...)

# %%
corpus = [dictionary.doc2bow(text) for text in full_content]
gensim.corpora.MmCorpus.serialize('model/contents.mm', corpus)
# Out:
# 2017-07-29 14:20:41,879 : INFO : storing corpus in Matrix Market format to model/contents.mm
# 2017-07-29 14:20:41,880 : INFO : saving sparse matrix to model/contents.mm
# 2017-07-29 14:20:41,880 : INFO : PROGRESS: saving document #0
# 2017-07-29 14:20:42,899 : INFO : saved 1000x105883 matrix, density=0.348% (368486/105883000)
# 2017-07-29 14:20:42,901 : INFO : saving MmCorpus index to model/contents.mm.index

# %% [markdown]
# # LDA

# %%
# Config 
NUM_TOPICS = 10
NUM_TERMS = 100

# %%
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, 
                                      num_topics=NUM_TOPICS, update_every=5, 
                                      chunksize=10000, passes=4)

lda.save('model/lda.save')
# Out:
# 2017-07-29 14:20:42,929 : INFO : using symmetric alpha at 0.1
# 2017-07-29 14:20:42,930 : INFO : using symmetric eta at 9.44438672875e-06
# 2017-07-29 14:20:42,941 : INFO : using serial LDA version on this node
# 2017-07-29 14:20:52,769 : INFO : running online LDA training, 10 topics, 4 passes over the supplied corpus of 1000 documents, updating model once every 1000 documents, evaluating perplexity every 1000 documents, iterating 50x with a convergence threshold of 0.001000
# 2017-07-29 14:20:52,769 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2017-07-29 14:21:18,851 : INFO : -15.362 per-word bound, 42104.3 perplexity estimate based on a held-out corpus of 1000 documents with 368486 words
# 2017-07-29 14:21:18,852 : INFO : PROGRESS: pass 0, at document #1000/1000
# 2017-07-29 14:21:23,230 : INFO : topic #2 (0.100): 0.001*"text_company" + 0.001*"july_reuters" + 0.001*"june_reuters" + 0.001*"source_text" + 0.001*"eikon_coverage" + 0.001*"source_company" + 0.001*"source_coverage" + 0.001*"source_eikon" + 0.001*"reporting_editing" + 0.001*"eikon_company"
# 2017-07-29 14:21:23,232 : INFO : topic #1 (0.100): 0.001*"text_coverage" + 0.001*"source_coverage" + 0.001*"text_company" + 0.001*"eikon_company" + 0.001*"text_eikon" + 0.001*"source_company" + 0.001*"source_text" + 0.001*"eikon_coverage" + 0.001*"source_eikon" + 0.001*"june_reuters"
# 2017-07-29 14:21:23,234 : INFO : topic #4 (0.100): 0.001*"source_company" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"july_reuters" + 0.001*"source_text" + 0.001*"source_eikon" + 0.001*"text_eikon" + 0.001*"eikon_coverage" + 0.001*"reuters_inc" + 0.001*"source_coverage"
# 2017-07-29 14:21:23,236 : INFO : topic #0 (0.100): 0.001*"eikon_company" + 0.001*"source_coverage" + 0.001*"source_company" + 0.001*"source_eikon" + 0.001*"text_company" + 0.001*"source_text" + 0.001*"eikon_coverage" + 0.001*"july_reuters" + 0.001*"text_eikon" + 0.001*"text_coverage"
# 2017-07-29 14:21:23,238 : INFO : topic #5 (0.100): 0.002*"text_company" + 0.002*"source_text" + 0.002*"text_coverage" + 0.002*"text_eikon" + 0.002*"source_company" + 0.002*"eikon_company" + 0.002*"eikon_coverage" + 0.001*"source_eikon" + 0.001*"july_reuters" + 0.001*"source_coverage"
# 2017-07-29 14:21:23,242 : INFO : topic diff=1.904230, rho=1.000000
# 2017-07-29 14:21:36,570 : INFO : -13.570 per-word bound, 12163.0 perplexity estimate based on a held-out corpus of 1000 documents with 368486 words
# 2017-07-29 14:21:36,571 : INFO : PROGRESS: pass 1, at document #1000/1000
# 2017-07-29 14:21:41,500 : INFO : topic #3 (0.100): 0.001*"reporting_editing" + 0.000*"july_reuters" + 0.000*"june_reuters" + 0.000*"private_equity" + 0.000*"1_billion" + 0.000*"company_said" + 0.000*"2_billion" + 0.000*"source_company" + 0.000*"said_would" + 0.000*"chief_executive"
# 2017-07-29 14:21:41,502 : INFO : topic #9 (0.100): 0.001*"june_reuters" + 0.001*"source_company" + 0.001*"source_text" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"reporting_editing" + 0.001*"eikon_coverage" + 0.001*"july_reuters" + 0.001*"source_eikon" + 0.001*"text_eikon"
# 2017-07-29 14:21:41,504 : INFO : topic #5 (0.100): 0.003*"source_text" + 0.003*"text_company" + 0.003*"text_coverage" + 0.002*"source_company" + 0.002*"text_eikon" + 0.002*"eikon_coverage" + 0.002*"eikon_company" + 0.002*"source_eikon" + 0.002*"source_coverage" + 0.002*"july_reuters"
# 2017-07-29 14:21:41,506 : INFO : topic #2 (0.100): 0.001*"reporting_editing" + 0.001*"july_reuters" + 0.001*"june_reuters" + 0.001*"text_company" + 0.001*"source_text" + 0.001*"eikon_coverage" + 0.001*"source_company" + 0.001*"source_eikon" + 0.001*"source_coverage" + 0.001*"eikon_company"
# 2017-07-29 14:21:41,508 : INFO : topic #4 (0.100): 0.001*"source_company" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"july_reuters" + 0.001*"source_text" + 0.001*"source_eikon" + 0.001*"text_eikon" + 0.001*"eikon_coverage" + 0.001*"source_coverage" + 0.001*"reuters_inc"
# 2017-07-29 14:21:41,511 : INFO : topic diff=1.663550, rho=0.577350
# 2017-07-29 14:21:54,880 : INFO : -12.257 per-word bound, 4895.9 perplexity estimate based on a held-out corpus of 1000 documents with 368486 words
# 2017-07-29 14:21:54,881 : INFO : PROGRESS: pass 2, at document #1000/1000
# 2017-07-29 14:22:00,153 : INFO : topic #8 (0.100): 0.001*"reporting_editing" + 0.000*"june_reuters" + 0.000*"said_would" + 0.000*"chief_executive" + 0.000*"july_reuters" + 0.000*"2_billion" + 0.000*"billion_billion" + 0.000*"last_year" + 0.000*"said_company" + 0.000*"company_said"
# 2017-07-29 14:22:00,155 : INFO : topic #0 (0.100): 0.001*"source_company" + 0.001*"source_coverage" + 0.001*"eikon_company" + 0.001*"source_text" + 0.001*"text_company" + 0.001*"source_eikon" + 0.001*"eikon_coverage" + 0.001*"text_eikon" + 0.001*"text_coverage" + 0.001*"july_reuters"
# 2017-07-29 14:22:00,157 : INFO : topic #4 (0.100): 0.001*"source_company" + 0.001*"july_reuters" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"source_text" + 0.001*"source_eikon" + 0.001*"text_eikon" + 0.001*"source_coverage" + 0.001*"eikon_coverage" + 0.001*"eikon_company"
# 2017-07-29 14:22:00,159 : INFO : topic #5 (0.100): 0.003*"source_text" + 0.003*"text_company" + 0.003*"text_coverage" + 0.003*"source_company" + 0.003*"text_eikon" + 0.003*"eikon_company" + 0.003*"eikon_coverage" + 0.003*"source_eikon" + 0.003*"source_coverage" + 0.002*"july_reuters"
# 2017-07-29 14:22:00,161 : INFO : topic #9 (0.100): 0.001*"june_reuters" + 0.001*"source_company" + 0.001*"source_text" + 0.001*"text_company" + 0.001*"text_coverage" + 0.001*"reporting_editing" + 0.001*"july_reuters" + 0.001*"eikon_coverage" + 0.000*"source_eikon" + 0.000*"billion_billion"
# 2017-07-29 14:22:00,164 : INFO : topic diff=1.271645, rho=0.500000
# 2017-07-29 14:22:13,654 : INFO : -11.803 per-word bound, 3573.5 perplexity estimate based on a held-out corpus of 1000 documents with 368486 words
# 2017-07-29 14:22:13,654 : INFO : PROGRESS: pass 3, at document #1000/1000
# 2017-07-29 14:22:19,258 : INFO : topic #9 (0.100): 0.001*"june_reuters" + 0.001*"reporting_editing" + 0.001*"source_text" + 0.001*"source_company" + 0.001*"text_company" + 0.001*"text_coverage" + 0.001*"july_reuters" + 0.001*"billion_billion" + 0.000*"4_billion" + 0.000*"chief_executive"
# 2017-07-29 14:22:19,261 : INFO : topic #5 (0.100): 0.004*"source_text" + 0.004*"text_company" + 0.004*"text_coverage" + 0.004*"source_company" + 0.004*"text_eikon" + 0.004*"eikon_company" + 0.004*"eikon_coverage" + 0.004*"source_eikon" + 0.004*"source_coverage" + 0.002*"july_reuters"
# 2017-07-29 14:22:19,264 : INFO : topic #3 (0.100): 0.001*"reporting_editing" + 0.000*"private_equity" + 0.000*"2_billion" + 0.000*"july_reuters" + 0.000*"said_would" + 0.000*"reuters_top" + 0.000*"june_reuters" + 0.000*"equity_firm" + 0.000*"company_said" + 0.000*"private_firm"
# 2017-07-29 14:22:19,266 : INFO : topic #6 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.000*"july_reuters" + 0.000*"1_billion" + 0.000*"company_said" + 0.000*"billion_billion" + 0.000*"last_year" + 0.000*"june_reuters" + 0.000*"said_deal" + 0.000*"chief_executive"
# 2017-07-29 14:22:19,267 : INFO : topic #7 (0.100): 0.001*"reporting_editing" + 0.001*"july_reuters" + 0.001*"june_reuters" + 0.001*"source_text" + 0.001*"source_coverage" + 0.001*"source_company" + 0.001*"source_eikon" + 0.001*"text_company" + 0.001*"text_coverage" + 0.001*"eikon_company"
# 2017-07-29 14:22:19,270 : INFO : topic diff=0.912767, rho=0.447214
# 2017-07-29 14:22:19,287 : INFO : saving LdaState object under model/lda.save.state, separately None
# 2017-07-29 14:22:19,295 : INFO : saved model/lda.save.state
# 2017-07-29 14:22:19,484 : INFO : saving LdaModel object under model/lda.save, separately ['expElogbeta', 'sstats']
# 2017-07-29 14:22:19,485 : INFO : not storing attribute id2word
# 2017-07-29 14:22:19,485 : INFO : storing np array 'expElogbeta' to model/lda.save.expElogbeta.npy
# 2017-07-29 14:22:19,491 : INFO : not storing attribute state
# 2017-07-29 14:22:19,491 : INFO : not storing attribute dispatcher
# 2017-07-29 14:22:19,493 : INFO : saved model/lda.save

# %%
lda.print_topics(2, 100)
# Out:
# 2017-07-29 14:22:19,501 : INFO : topic #4 (0.100): 0.001*"july_reuters" + 0.001*"source_company" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"source_text" + 0.001*"source_eikon" + 0.001*"text_eikon" + 0.001*"reporting_editing" + 0.001*"source_coverage" + 0.001*"eikon_coverage" + 0.001*"eikon_company" + 0.001*"reuters_inc" + 0.001*"june_reuters" + 0.001*"said_would" + 0.001*"1_billion" + 0.000*"company_said" + 0.000*"per_share" + 0.000*"percent_stake" + 0.000*"million_source" + 0.000*"million_million" + 0.000*"3_billion" + 0.000*"chief_executive" + 0.000*"2_billion" + 0.000*"million_company" + 0.000*"reuters_corp" + 0.000*"billion_billion" + 0.000*"reporting_bengaluru" + 0.000*"said_buy" + 0.000*"1_3" + 0.000*"million_said" + 0.000*"bengaluru_editing" + 0.000*"1_1" + 0.000*"million_text" + 0.000*"july_inc" + 0.000*"private_equity" + 0.000*"told_reuters" + 0.000*"bit_ly" + 0.000*"share_percent" + 0.000*"inc_deal" + 0.000*"said_wednesday" + 0.000*"source_ly" + 0.000*"group_said" + 0.000*"would_buy" + 0.000*"billion_deal" + 0.000*"source_bit" + 0.000*"1_reporting" + 0.000*"26_reuters" + 0.000*"6_reuters" + 0.000*"said_statement" + 0.000*"said_company" + 0.000*"5_billion" + 0.000*"4_billion" + 0.000*"ly_coverage" + 0.000*"matter_said" + 0.000*"ly_company" + 0.000*"said_deal" + 0.000*"bit_coverage" + 0.000*"sao_reuters" + 0.000*"source_said" + 0.000*"deal_acquisition" + 0.000*"investment_firm" + 0.000*"company_corp" + 0.000*"paulo_reuters" + 0.000*"said_said" + 0.000*"people_matter" + 0.000*"bit_company" + 0.000*"mln_reuters" + 0.000*"million_inc" + 0.000*"update_1" + 0.000*"5_percent" + 0.000*"said_private" + 0.000*"company_would" + 0.000*"sao_paulo" + 0.000*"familiar_matter" + 0.000*"reuters_merger" + 0.000*"reuters_said" + 0.000*"billion_company" + 0.000*"equity_firm" + 0.000*"co_million" + 0.000*"acquisition_company" + 0.000*"text_ly" + 0.000*"inc_inc" + 0.000*"private_firm" + 0.000*"billion_million" + 0.000*"source_reuters" + 0.000*"billion_1" + 0.000*"buy_stake" + 0.000*"deal_million" + 0.000*"text_bit" + 0.000*"inc_company" + 0.000*"6_million" + 0.000*"merger_acquisition" + 0.000*"approximately_million" + 0.000*"declined_comment" + 0.000*"7_billion" + 0.000*"sec_filing" + 0.000*"said_sell" + 0.000*"acquisition_reuters" + 0.000*"credit_facility" + 0.000*"million_deal"
# 2017-07-29 14:22:19,503 : INFO : topic #0 (0.100): 0.001*"source_text" + 0.001*"source_company" + 0.001*"text_company" + 0.001*"source_coverage" + 0.001*"eikon_company" + 0.001*"source_eikon" + 0.001*"eikon_coverage" + 0.001*"text_coverage" + 0.001*"text_eikon" + 0.001*"july_reuters" + 0.001*"june_reuters" + 0.001*"reuters_inc" + 0.000*"reporting_editing" + 0.000*"group_company" + 0.000*"group_inc" + 0.000*"per_share" + 0.000*"brief_acquires" + 0.000*"group_group" + 0.000*"reuters_corp" + 0.000*"company_coverage" + 0.000*"reuters_group" + 0.000*"june_inc" + 0.000*"private_equity" + 0.000*"group_acquire" + 0.000*"july_13" + 0.000*"july_10" + 0.000*"company_company" + 0.000*"june_14" + 0.000*"common_stock" + 0.000*"inc_inc" + 0.000*"june_20" + 0.000*"inc_company" + 0.000*"reuters_co" + 0.000*"brief_acquire" + 0.000*"mln_reuters" + 0.000*"equity_firm" + 0.000*"private_firm" + 0.000*"july_inc" + 0.000*"july_19" + 0.000*"july_26" + 0.000*"inc_group" + 0.000*"july_5" + 0.000*"acquire_business" + 0.000*"said_statement" + 0.000*"june_group" + 0.000*"european_commission" + 0.000*"brussels_reuters" + 0.000*"approximately_million" + 0.000*"million_source" + 0.000*"group_july" + 0.000*"brief_group" + 0.000*"share_stock" + 0.000*"july_4" + 0.000*"june_29" + 0.000*"company_source" + 0.000*"inc_acquire" + 0.000*"june_23" + 0.000*"general_electric" + 0.000*"co_june" + 0.000*"eu_approval" + 0.000*"2_billion" + 0.000*"june_26" + 0.000*"june_19" + 0.000*"capital_group" + 0.000*"june_corp" + 0.000*"entered_agreement" + 0.000*"co_ltd" + 0.000*"mln_july" + 0.000*"board_director" + 0.000*"agreement_acquire" + 0.000*"july_24" + 0.000*"million_company" + 0.000*"million_text" + 0.000*"inc_agreement" + 0.000*"july_20" + 0.000*"brief_say" + 0.000*"co_company" + 0.000*"investment_acquire" + 0.000*"acquire_group" + 0.000*"13_reuters" + 0.000*"capital_partner" + 0.000*"company_june" + 0.000*"acquire_company" + 0.000*"group_source" + 0.000*"business_june" + 0.000*"co_acquire" + 0.000*"june_22" + 0.000*"acquire_provider" + 0.000*"company_business" + 0.000*"fund_management" + 0.000*"june_30" + 0.000*"july_11" + 0.000*"inc_acquires" + 0.000*"u_company" + 0.000*"merger_july" + 0.000*"company_group" + 0.000*"acquire_july" + 0.000*"either_company" + 0.000*"purchase_price" + 0.000*"investment_company"
# [(4,
#   u'0.001*"july_reuters" + 0.001*"source_company" + 0.001*"text_coverage" + 0.001*"text_company" + 0.001*"source_text" + 0.001*"source_eikon" + 0.001*"text_eikon" + 0.001*"reporting_editing" + 0.001*"source_coverage" + 0.001*"eikon_coverage" + 0.001*"eikon_company" + 0.001*"reuters_inc" + 0.001*"june_reuters" + 0.001*"said_would" + 0.001*"1_billion" + 0.000*"company_said" + 0.000*"per_share" + 0.000*"percent_stake" + 0.000*"million_source" + 0.000*"million_million" + 0.000*"3_billion" + 0.000*"chief_executive" + 0.000*"2_billion" + 0.000*"million_company" + 0.000*"reuters_corp" + 0.000*"billion_billion" + 0.000*"reporting_bengaluru" + 0.000*"said_buy" + 0.000*"1_3" + 0.000*"million_said" + 0.000*"bengaluru_editing" + 0.000*"1_1" + 0.000*"million_text" + 0.000*"july_inc" + 0.000*"private_equity" + 0.000*"told_reuters" + 0.000*"bit_ly" + 0.000*"share_percent" + 0.000*"inc_deal" + 0.000*"said_wednesday" + 0.000*"source_ly" + 0.000*"group_said" + 0.000*"would_buy" + 0.000*"billion_deal" + 0.000*"source_bit" + 0.000*"1_reporting" + 0.000*"26_reuters" + 0.000*"6_reuters" + 0.000*"said_statement" + 0.000*"said_company" + 0.000*"5_billion" + 0.000*"4_billion" + 0.000*"ly_coverage" + 0.000*"matter_said" + 0.000*"ly_company" + 0.000*"said_deal" + 0.000*"bit_coverage" + 0.000*"sao_reuters" + 0.000*"source_said" + 0.000*"deal_acquisition" + 0.000*"investment_firm" + 0.000*"company_corp" + 0.000*"paulo_reuters" + 0.000*"said_said" + 0.000*"people_matter" + 0.000*"bit_company" + 0.000*"mln_reuters" + 0.000*"million_inc" + 0.000*"update_1" + 0.000*"5_percent" + 0.000*"said_private" + 0.000*"company_would" + 0.000*"sao_paulo" + 0.000*"familiar_matter" + 0.000*"reuters_merger" + 0.000*"reuters_said" + 0.000*"billion_company" + 0.000*"equity_firm" + 0.000*"co_million" + 0.000*"acquisition_company" + 0.000*"text_ly" + 0.000*"inc_inc" + 0.000*"private_firm" + 0.000*"billion_million" + 0.000*"source_reuters" + 0.000*"billion_1" + 0.000*"buy_stake" + 0.000*"deal_million" + 0.000*"text_bit" + 0.000*"inc_company" + 0.000*"6_million" + 0.000*"merger_acquisition" + 0.000*"approximately_million" + 0.000*"declined_comment" + 0.000*"7_billion" + 0.000*"sec_filing" + 0.000*"said_sell" + 0.000*"acquisition_reuters" + 0.000*"credit_facility" + 0.000*"million_deal"'),
#  (0,
#   u'0.001*"source_text" + 0.001*"source_company" + 0.001*"text_company" + 0.001*"source_coverage" + 0.001*"eikon_company" + 0.001*"source_eikon" + 0.001*"eikon_coverage" + 0.001*"text_coverage" + 0.001*"text_eikon" + 0.001*"july_reuters" + 0.001*"june_reuters" + 0.001*"reuters_inc" + 0.000*"reporting_editing" + 0.000*"group_company" + 0.000*"group_inc" + 0.000*"per_share" + 0.000*"brief_acquires" + 0.000*"group_group" + 0.000*"reuters_corp" + 0.000*"company_coverage" + 0.000*"reuters_group" + 0.000*"june_inc" + 0.000*"private_equity" + 0.000*"group_acquire" + 0.000*"july_13" + 0.000*"july_10" + 0.000*"company_company" + 0.000*"june_14" + 0.000*"common_stock" + 0.000*"inc_inc" + 0.000*"june_20" + 0.000*"inc_company" + 0.000*"reuters_co" + 0.000*"brief_acquire" + 0.000*"mln_reuters" + 0.000*"equity_firm" + 0.000*"private_firm" + 0.000*"july_inc" + 0.000*"july_19" + 0.000*"july_26" + 0.000*"inc_group" + 0.000*"july_5" + 0.000*"acquire_business" + 0.000*"said_statement" + 0.000*"june_group" + 0.000*"european_commission" + 0.000*"brussels_reuters" + 0.000*"approximately_million" + 0.000*"million_source" + 0.000*"group_july" + 0.000*"brief_group" + 0.000*"share_stock" + 0.000*"july_4" + 0.000*"june_29" + 0.000*"company_source" + 0.000*"inc_acquire" + 0.000*"june_23" + 0.000*"general_electric" + 0.000*"co_june" + 0.000*"eu_approval" + 0.000*"2_billion" + 0.000*"june_26" + 0.000*"june_19" + 0.000*"capital_group" + 0.000*"june_corp" + 0.000*"entered_agreement" + 0.000*"co_ltd" + 0.000*"mln_july" + 0.000*"board_director" + 0.000*"agreement_acquire" + 0.000*"july_24" + 0.000*"million_company" + 0.000*"million_text" + 0.000*"inc_agreement" + 0.000*"july_20" + 0.000*"brief_say" + 0.000*"co_company" + 0.000*"investment_acquire" + 0.000*"acquire_group" + 0.000*"13_reuters" + 0.000*"capital_partner" + 0.000*"company_june" + 0.000*"acquire_company" + 0.000*"group_source" + 0.000*"business_june" + 0.000*"co_acquire" + 0.000*"june_22" + 0.000*"acquire_provider" + 0.000*"company_business" + 0.000*"fund_management" + 0.000*"june_30" + 0.000*"july_11" + 0.000*"inc_acquires" + 0.000*"u_company" + 0.000*"merger_july" + 0.000*"company_group" + 0.000*"acquire_july" + 0.000*"either_company" + 0.000*"purchase_price" + 0.000*"investment_company"')]

# %%
# select top 100 words for each of the 10 LDA topics
TOP_KEYWORDS = [[word for word, _ in lda.show_topic(topicno, topn=NUM_TERMS)]
             for topicno in range(lda.num_topics)]
print(TOP_KEYWORDS[:3])
# Out:
# [[u'source_text', u'source_company', u'text_company', u'source_coverage', u'eikon_company', u'source_eikon', u'eikon_coverage', u'text_coverage', u'text_eikon', u'july_reuters', u'june_reuters', u'reuters_inc', u'reporting_editing', u'group_company', u'group_inc', u'per_share', u'brief_acquires', u'group_group', u'reuters_corp', u'company_coverage', u'reuters_group', u'june_inc', u'private_equity', u'group_acquire', u'july_13', u'july_10', u'company_company', u'june_14', u'common_stock', u'inc_inc', u'june_20', u'inc_company', u'reuters_co', u'brief_acquire', u'mln_reuters', u'equity_firm', u'private_firm', u'july_inc', u'july_19', u'july_26', u'inc_group', u'july_5', u'acquire_business', u'said_statement', u'june_group', u'european_commission', u'brussels_reuters', u'approximately_million', u'million_source', u'group_july', u'brief_group', u'share_stock', u'july_4', u'june_29', u'company_source', u'inc_acquire', u'june_23', u'general_electric', u'co_june', u'eu_approval', u'2_billion', u'june_26', u'june_19', u'capital_group', u'june_corp', u'entered_agreement', u'co_ltd', u'mln_july', u'board_director', u'agreement_acquire', u'july_24', u'million_company', u'million_text', u'inc_agreement', u'july_20', u'brief_say', u'co_company', u'investment_acquire', u'acquire_group', u'13_reuters', u'capital_partner', u'company_june', u'acquire_company', u'group_source', u'business_june', u'co_acquire', u'june_22', u'acquire_provider', u'company_business', u'fund_management', u'june_30', u'july_11', u'inc_acquires', u'u_company', u'merger_july', u'company_group', u'acquire_july', u'either_company', u'purchase_price', u'investment_company'], [u'source_company', u'source_coverage', u'text_company', u'text_coverage', u'source_text', u'text_eikon', u'eikon_company', u'june_reuters', u'eikon_coverage', u'source_eikon', u'july_reuters', u'reporting_editing', u'reuters_inc', u'declined_comment', u'said_would', u'2_percent', u'billion_billion', u'4_percent', u'1_billion', u'3_percent', u'5_percent', u'1_percent', u'million_million', u'9_percent', u'chief_executive', u'said_sale', u'source_reuters', u'0_percent', u'new_york', u'london_reuters', u'company_said', u'update_2', u'percent_1', u'2_billion', u'paulo_reuters', u'sao_paulo', u'market_said', u'last_week', u'told_reuters', u'share_percent', u'sao_reuters', u'executive_said', u'7_percent', u'3_billion', u'per_share', u'2_2', u'rose_percent', u'familiar_matter', u'inc_deal', u'6_percent', u'percent_share', u'5_billion', u'0_5', u'index_percent', u'1_0', u'said_deal', u'inc_inc', u'fell_percent', u'5_point', u'percent_3', u'percent_4', u'8_percent', u'source_said', u'percent_5', u'percent_point', u'0_3', u'last_month', u'index_1', u'billion_2', u'world_largest', u'index_3', u'1_2', u'0_4', u'additional_reporting', u'percent_6', u'deal_million', u'0_1', u'rose_0', u'1_index', u'percent_stake', u'qatar_percent', u'26_reuters', u'4_point', u'1_3', u'said_company', u'percent_7', u'percent_editing', u'arabia_index', u'oman_index', u'point_egypt', u'4_index', u'dubai_index', u'highlight_saudi', u'added_percent', u'point_dubai', u'percent_kuwait', u'billion_1', u'qatar_index', u'saudi_index', u'index_5'], [u'reporting_editing', u'june_reuters', u'july_reuters', u'company_said', u'1_billion', u'said_would', u'2_billion', u'additional_reporting', u'3_billion', u'share_percent', u'said_company', u'source_text', u'text_company', u'reporting_bengaluru', u'source_eikon', u'billion_billion', u'last_year', u'bengaluru_editing', u'source_company', u'told_reuters', u'eikon_coverage', u'private_equity', u'source_coverage', u'eikon_company', u'text_coverage', u'source_reuters', u'percent_stake', u'text_eikon', u'declined_comment', u'6_billion', u'private_firm', u'per_share', u'9_billion', u'reuters_corp', u'update_1', u'reuters_inc', u'chief_executive', u'world_largest', u'reuters_group', u'said_statement', u'source_said', u'5_billion', u'said_deal', u'2_percent', u'4_billion', u'last_month', u'said_friday', u'a ...

# %%
# Export 
n = 0
combined = []
for _ in TOP_KEYWORDS:
    combined += _

combined_df = pd.DataFrame(combined)
combined_df = pd.DataFrame(combined_df[0].value_counts().sort_values()).reset_index()
combined_df.columns = ['keyword', 'c']

save_to = "exported/skipgram_4_%s.csv" % KEYWORD_TYPE
combined_df[['keyword']].to_csv(save_to, index=False, encoding='utf-8')
print 'Saved to ', save_to
# Out:
# Saved to  exported/skipgram_4_m_a_reuter.csv

# %%
# Break the notebook 
break
# Out:
#   File "<ipython-input-191-da59c82888d2>", line 2
#     break
# SyntaxError: 'break' outside loop

# %% [markdown]
# # TF-IDF

# %%
NUM_CLUSTERS = 10
NUM_TERMS = 50

# %%
tfidf = gensim.models.tfidfmodel.TfidfModel(corpus, id2word=dictionary)
corpus_tfidf = tfidf[corpus]
tfidf.save("model/tfidf.save")

# %%
corpus_tfidf_sorted = []
TOP_KEYWORDS = []
for c in corpus_tfidf:
    top_keywords = sorted(c, key=lambda t: t[1], reverse=True)
    top_keywords = top_keywords[:NUM_TERMS]
    corpus_tfidf_sorted.append(top_keywords)
    TOP_KEYWORDS.append([dictionary[id] for id, _ in top_keywords])

# %%
print TOP_KEYWORDS[:2]

# %%
# Combine top keywords
import itertools
TOP_KEYWORDS_MERGED = list(itertools.chain(*TOP_KEYWORDS))
print "Total keywords: ", len(TOP_KEYWORDS_MERGED)
TOP_KEYWORDS_MERGED = list(set(TOP_KEYWORDS_MERGED))
print "Total keywords after combined: ", len(TOP_KEYWORDS_MERGED)
print TOP_KEYWORDS_MERGED[:10]

# %%
# Export 
save_to = "exported/tfidf/tfidf_keywords.csv"
pd.DataFrame(TOP_KEYWORDS_MERGED, columns=['keyword']).to_csv(save_to, index=False, encoding='utf-8')
print 'Saved to ', save_to

# %% [markdown]
# # TF-IDF with K-means

# %%
# NUM_CLUSTERS = 10
# NUM_TERMS = 100

# %%
# from sklearn.cluster import KMeans
# from scipy.sparse import csr_matrix
# import numpy as np

# %%
# _corpus_tfidf = gensim.matutils.corpus2csc(corpus_tfidf).transpose()
# print _corpus_tfidf[:5]

# %%
# kmeans = KMeans(n_clusters=NUM_CLUSTERS)
# X = kmeans.fit_transform(_corpus_tfidf)

# %%
# X.shape

# %%
# dir(kmeans)
# kmeans.n_clusters
