# %%
import glob
import gensim
import pandas as pd
import logging
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

wordnet_lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'\w+')
STOPWORDS = set(stopwords.words('english'))
STOPWORDS.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# close_branch_reuter, deal_reuter, layoff_reuter, m_a_reuter, new_branch_reuter, new_brand_reuter
KEYWORD_TYPE = 'm_a_reuter'

# Input file
INPUT_FILE = "data/"+ KEYWORD_TYPE +".csv"

data = pd.read_csv(INPUT_FILE, encoding='utf-8', dtype={'short_text': str, 'long_text': str})
print 'Reading', INPUT_FILE, ' => ' , len(data.index), 'rows'
data.drop_duplicates(inplace=True)
# data['short_text'] = data.short_text.astype(str)
print "Unique row:", len(data)
data.head()
# Out:
# Reading data/deal_reuter.csv  =>  546 rows
# Unique row: 545
#                                                  url  \
# 0  https://www.reuters.com/article/us-nomura-jafc...
# 1  https://www.reuters.com/article/us-hutchison-m...
# 2  https://www.reuters.com/article/us-noble-grp-s...
# 3  https://www.reuters.com/article/us-china-cic-l...
# 4  https://www.reuters.com/article/us-china-m-a-u...
#
#                                                title  tag        time  \
# 0  Japan's Nomura sells stake in venture capital ...  NaN  8:47am EDT
# 1  Hutchison's Drei buys Tele2 to rival Carlos Sl...  NaN  8:42am EDT
# 2  At 'bare bones' Noble Group, staff exits and d...  NaN  8:08am EDT
# 3  China's CIC raising $8 billion loan for Logico...  NaN  6:47am EDT
# 4  Value of U.S. deals in China sinks on rising t...  NaN  6:42am EDT
#
#                                           short_text  \
# 0  Nomura Holdings Incsaid on Friday it had sold ...
# 1  Mobile telecoms firm Hutchison Drei Austria is...
# 2  Noble Groupis slimming down drastically to its...
# 3  The China Investment Corp sovereign wealth fun...
# 4  U.S. corporate acquisitions in China collapsed...
#
#                                            long_text
# 0  TOKYO (Reuters) - Nomura Holdings Inc (8604.T)...
# 1  VIENNA (Reuters) - Mobile telecoms firm Hutchi...
# 2  SINGAPORE (Reuters) - Noble Group (NOBG.SI) is...
# 3  HONG KONG (Reuters) - The China Investment Cor...
# 4  HONG KONG (Reuters) - U.S. corporate acquisiti...

# %%
from itertools import chain, combinations
import copy
from nltk.util import ngrams

def pad_sequence(sequence, n, pad_left=False, pad_right=False, pad_symbol=None):
    if pad_left:
        sequence = chain((pad_symbol,) * (n-1), sequence)
    if pad_right:
        sequence = chain(sequence, (pad_symbol,) * (n-1))
    return sequence

def skipgrams(sequence, n, k, pad_left=False, pad_right=False, pad_symbol=None):
    sequence_length = len(sequence)
    sequence = iter(sequence)
    sequence = pad_sequence(sequence, n, pad_left, pad_right, pad_symbol)

    if sequence_length + pad_left + pad_right < k:
        raise Exception("The length of sentence + padding(s) < skip")

    if n < k:
        raise Exception("Degree of Ngrams (n) needs to be bigger than skip (k)")    

    history = []
    nk = n+k

    # Return point for recursion.
    if nk < 1: 
        return
    # If n+k longer than sequence, reduce k by 1 and recur
    elif nk > sequence_length: 
        for ng in skipgrams(list(sequence), n, k-1):
            yield ng

    while nk > 1: # Collects the first instance of n+k length history
        history.append(next(sequence))
        nk -= 1

    # Iterative drop first item in history and picks up the next
    # while yielding skipgrams for each iteration.
    for item in sequence:
        history.append(item)
        current_token = history.pop(0)      
        # Iterates through the rest of the history and 
        # pick out all combinations the n-1grams
        for idx in list(combinations(range(len(history)), n-1)):
            ng = [current_token]
            for _id in idx:
                ng.append(history[_id])
            yield tuple(ng)

    # Recursively yield the skigrams for the rest of seqeunce where
    # len(sequence) < n+k
    for ng in list(skipgrams(history, n, k-1)):
        yield ng

# %%
# remove common words and tokenize
data['full_content'] = data['title'] + ' ' + data['long_text']
full_content = data['full_content'].tolist()
# full_content = [[wordnet_lemmatizer.lemmatize(z) for z in tokenizer.tokenize(str(t).decode('utf-8').lower()) if z not in STOPWORDS] for t in full_content]
# full_content = [[z for z in str(t).lower().split(" ") if z not in STOPWORDS] for t in full_content]

full_content = [[wordnet_lemmatizer.lemmatize(z) for z in tokenizer.tokenize(unicode(t).lower()) if z not in STOPWORDS] for t in full_content]
print full_content[:2]
with open("full_content", "wb") as f:
    f.write(str(full_content))
# Out:
# [[u'japan', u'nomura', u'sell', u'stake', u'venture', u'capital', u'firm', u'jafco', u'tokyo', u'reuters', u'nomura', u'holding', u'inc', u'8604', u'said', u'friday', u'sold', u'share', u'stake', u'jafco', u'co', u'8595', u'back', u'venture', u'capital', u'firm', u'japanese', u'brokerage', u'seek', u'shift', u'capital', u'area', u'see', u'growth', u'nomura', u'japan', u'largest', u'brokerage', u'investment', u'bank', u'said', u'may', u'wanted', u'use', u'capital', u'efficiently', u'currently', u'expanding', u'u', u'investment', u'banking', u'business', u'selling', u'stake', u'jafco', u'would', u'contribute', u'nomura', u'drive', u'enhance', u'capital', u'efficiency', u'optimally', u'allocate', u'management', u'resource', u'nomura', u'said', u'share', u'nomura', u'closed', u'1', u'5', u'percent', u'650', u'1', u'yen', u'jafco', u'share', u'ended', u'15', u'percent', u'5', u'260', u'yen', u'highest', u'since', u'october', u'2015', u'benchmark', u'nikkei', u'n225', u'average', u'index', u'fell', u'0', u'6', u'percent', u'nomura', u'sold', u'8', u'48', u'million', u'share', u'17', u'6', u'percent', u'stake', u'jafco', u'4', u'560', u'yen', u'41', u'per', u'share', u'raising', u'38', u'7', u'billion', u'yen', u'348', u'million', u'nomura', u'said', u'statement', u'nomura', u'research', u'institute', u'ltd', u'4307', u'nomura', u'hold', u'37', u'2', u'percent', u'stake', u'tendered', u'sell', u'4', u'95', u'million', u'jafco', u'share', u'jafco', u'said', u'jafco', u'said', u'buying', u'13', u'4', u'million', u'share', u'two', u'tender', u'61', u'3', u'billion', u'yen', u'551', u'21', u'million', u'deal', u'would', u'generate', u'nomura', u'pretax', u'profit', u'9', u'billion', u'yen', u'80', u'9', u'million', u'booked', u'july', u'september', u'period', u'nomura', u'said', u'separate', u'statement', u'jafco', u'said', u'would', u'tender', u'5', u'million', u'share', u'nomura', u'research', u'institute', u'adding', u'sold', u'share', u'planned', u'book', u'gain', u'18', u'4', u'billion', u'yen', u'165', u'5', u'million', u'july', u'september', u'period', u'may', u'nomura', u'holding', u'began', u'unofficial', u'talk', u'japan', u'post', u'holding', u'co', u'6178', u'sell', u'stake', u'group', u'company', u'nomura', u'real', u'estate', u'holding', u'3231', u'source', u'told', u'reuters', u'deal', u'broke', u'june', u'nomura', u'real', u'estate', u'said', u'japan', u'post', u'longer', u'considering', u'buying', u'stake', u'jafco', u'sale', u'chief', u'financial', u'officer', u'takumi', u'kitamura', u'told', u'conference', u'call', u'nomura', u'planning', u'sell', u'holding', u'nomura', u'real', u'estate', u'nomura', u'research', u'institute', u'34', u'1', u'percent', u'37', u'2', u'percent', u'stake', u'respectively', u'reporting', u'thomas', u'wilson', u'editing', u'jacqueline', u'wong', u'edmund', u'blair'], [u'hutchison', u'drei', u'buy', u'tele2', u'rival', u'carlos', u'slim', u'austria', u'vienna', u'reuters', u'mobile', u'telecom', u'firm', u'hutchison', u'drei', u'austria', u'buying', u'landline', u'focused', u'tele2', u'swedish', u'owner', u'95', u'million', u'euro', u'111', u'million', u'create', u'rival', u'mexican', u'tycoon', u'carlos', u'slim', u'telekom', u'austria', u'drei', u'said', u'friday', u'merged', u'group', u'led', u'hong', u'kong', u'based', u'hutchison', u'would', u'around', u'1', u'billion', u'euro', u'annual', u'sale', u'four', u'million', u'mobile', u'landline', u'internet', u'line', u'compare', u'3', u'4', u'million', u'line', u'2016', u'revenue', u'2', u'6', u'billion', u'euro', u'telekom', u'austria', u'a1', u'unit', u'far', u'monopoly', u'combined', u'telecom', u'service', u'country', u'population', u'8', u'7', u'million', u'clear', u'challenge', u'telekom', u'austria', u'a1', u'said', u'drei', u'austria', u'chief', u'executive', u'jan', u'trionow', u'news', u'conference', u'want', u'move', u'closer', u'a1', u'certainly', u'stop', u'reached', u'a1', u'larger', u'share', u'lucrative', u'market', u'busine ...

# %%
full_content_ = full_content
two_skip_bigrams = [list(skipgrams(c, n=3, k=3)) for c in full_content if len(c) > 5  ]
gram_12 = [ [ [a+"_"+b, a+"_"+c] for a, b, c in z ] for z in two_skip_bigrams]

# %%
gram_12 = [reduce(lambda x,y: x+y, z) for z in gram_12]

# %%
gram_12 = [list(set(z)) for z in gram_12]

# %%
gram_12[:3]
# Out:
# [[u'said_institute',
#   u'billion_deal',
#   u'real_institute',
#   u'nomura_sold',
#   u'nomura_billion',
#   u'said_1',
#   u'nomura_34',
#   u'said_4',
#   u'u_selling',
#   u'capital_investment',
#   u'generate_nomura',
#   u'7_million',
#   u'million_61',
#   u'0_8',
#   u'kitamura_told',
#   u'capital_management',
#   u'takumi_call',
#   u'buying_chief',
#   u'wilson_wong',
#   u'3_billion',
#   u'estate_japan',
#   u'inc_friday',
#   u'estate_nomura',
#   u'jafco_ended',
#   u'6_jafco',
#   u'percent_percent',
#   u'5_since',
#   u'1_stake',
#   u'post_co',
#   u'selling_nomura',
#   u'nikkei_0',
#   u'stake_95',
#   u'real_holding',
#   u'september_separate',
#   u'management_nomura',
#   u'estate_post',
#   u'jafco_per',
#   u'june_japan',
#   u'said_nomura',
#   u'deal_profit',
#   u'efficiently_currently',
#   u'4_61',
#   u'percent_560',
#   u'6_percent',
#   u'said_5',
#   u'share_3',
#   u'capital_currently',
#   u'period_jafco',
#   u'may_efficiently',
#   u'optimally_nomura',
#   u'estate_reuters',
#   u'october_n225',
#   u'yen_jafco',
#   u'8595_japanese',
#   u'kitamura_nomura',
#   u'stake_jafco',
#   u'since_2015',
#   u'statement_5',
#   u'yen_booked',
#   u'company_nomura',
#   u'nomura_largest',
#   u'japan_said',
#   u'research_planned',
#   u'1_5',
#   u'deal_would',
#   u'buying_stake',
#   u'37_tendered',
#   u'percent_nomura',
#   u'gain_4',
#   u'hold_percent',
#   u'talk_co',
#   u'largest_bank',
#   u'4307_37',
#   u'share_4',
#   u'chief_financial',
#   u'4_165',
#   u'co_capital',
#   u'profit_yen',
#   u'brokerage_wanted',
#   u'use_currently',
#   u'use_u',
#   u'japan_longer',
#   u'july_period',
#   u'jafco_said',
#   u'began_unofficial',
#   u'5_may',
#   u'japan_buying',
#   u'closed_5',
#   u'fell_percent',
#   u'said_tender',
#   u'closed_1',
#   u'wilson_edmund',
#   u'percent_jafco',
#   u'nomura_research',
#   u'planned_billion',
#   u'selling_jafco',
#   u'planned_4',
#   u'percent_tendered',
#   u'gain_18',
#   u'jafco_41',
#   u'contribute_drive',
#   u'holding_source',
#   u'highest_2015',
#   u'tokyo_8604',
#   u'million_generate',
#   u'stake_editing',
#   u'would_nomura',
#   u'n225_average',
#   u'contribute_enhance',
#   u'6_stake',
#   u'booked_said',
#   u'ended_15',
#   u'jafco_financial',
#   u'stake_venture',
#   u'seek_see',
#   u'call_nomura',
#   u'firm_seek',
#   u'holding_3231',
#   u'back_capital',
#   u'share_sold',
#   u'million_stake',
#   u'chief_told',
#   u'8_million',
#   u'said_post',
#   u'15_260',
#   u'stake_respectively',
#   u'would_5',
#   u'expanding_investment',
#   u'capital_brokerage',
#   u'co_back',
#   u'selling_contribute',
#   u'ended_5',
#   u'would_9',
#   u'june_said',
#   u'ltd_37',
#   u'sell_holding',
#   u'share_18',
#   u'4_jafco',
#   u'inc_share',
#   u'inc_said',
#   u'research_share',
#   u'tender_share',
#   u'firm_reuters',
#   u'expanding_business',
#   u'resource_nomura',
#   u'15_yen',
#   u'japan_capital',
#   u'buying_4',
#   u'sold_17',
#   u'2015_nikkei',
#   u'venture_jafco',
#   u'may_wanted',
#   u'source_told',
#   u'buying_share',
#   u'highest_since',
#   u'buying_two',
#   u'nikkei_n225',
#   u'longer_sale',
#   u'sell_real',
#   u'7_nomura',
#   u'per_38',
#   u'would_enhance',
#   u'statement_nomura',
#   u'inc_sold',
#   u'551_21',
#   u'capital_efficiently',
#   u'july_said',
#   u'september_nomura',
#   u'21_million',
#   u'source_june',
#   u'buying_financial',
#   u'talk_japan',
#   u'million_statement',
#   u'share_buying',
#   u'3231_reuters',
#   u'8_share',
#   u'hold_2',
#   u'4_560',
#   u'allocate_resource',
#   u'buying_13',
#   u'told_june',
#   u'48_share',
#   u'efficiency_resource',
#   u'brokerage_said',
#   u'began_holding',
#   u'1_ended',
#   u'share_17',
#   u'yen_percent',
#   u'1_jafco',
#   u'holding_sell',
#   u'company_3231',
#   u'stake_estate',
#   u'may_nomura',
#   u'said_efficiently',
#   u'billion_yen',
#   u'nomura_37',
#   u'holding_japan',
#   u'holding_6178',
#   u'source_deal',
#   u'highest_nikkei',
#   u'research_37',
#   u'jafco_tokyo',
#   u'share_jafco',
#   u'estate_told',
#   u'planned_gain',
#   u'reuters_real',
#   u'respectively_reporting',
#   u'3_21',
#   u'period_said',
#   u'japan_investment',
#   u'u_stake',
#   u'jafco_percent',
#   u'80_million',
#   u'sell_95',
#   u'financial_told',
#   u'see_japan',
#   u'jafco_chief',
#   u'holding_inc',
#   u'statement_institute',
#   u'1_percent',
#   u'jafco_enhance',
#   u'co_venture',
#   u'per_7',
#   u'million_september',
#   u'separate_tender',
#   u'6_4',
#   u'reporting_thomas',
#   u'18_165',
#   u'told_broke',
#   u'million_research',
#   u'september_holding',
#   u'nomura_statement',
#   u'period_nomura',
#   u'6_8',
#   u'tendered_4',
#   u'sell_firm',
#   u'institute_34',
#   u'real_nomura',
#   u'japanese_shift',
#   u'real_said',
#   u'thomas_jacqueline',
#   u'nomura_optimally',
#   u'551_million',
#   u'jafco_nomura',
#   u'ltd_nomura',
#   u'stake_company',
#   u'research_institute',
#   u'million_may',
#   u'5_percent',
#   u'9_billion',
#   u'officer_conference',
#   u'estate_source',
#   u'nomura_bank',
#   u'share_260',
#   u'statement_tender',
#   u'jafco_takumi',
#   u'bank_said',
#   u'650_1',
#   u'share_tender',
#   u'estate_1',
#   u'generate_profit',
#   u'61_21',
#   u'stake_chief',
#   u'tendered_sell',
#   u'capital_allocate',
#   u'u_banking',
#   u'september_began',
#   u'october_nikkei',
#   u'560_per',
#   u'estate_holding',
#   u'business_selling',
#   u'nomura_planning',
#   u'book_18',
#   u'takumi_told',
#   u'largest_may',
#   u'research_adding',
#   u'editing_edmund',
#   u'closed_percent',
#   u'optimally_allocate',
#   u'nomura_investment',
#   u'holding_sold',
#   u'nomura_closed',
#   u'october_average',
#   u'july_may',
#   u'shift_see',
#   u'6178_company',
#   u'48_6',
#   u'560_41',
#   u'million_17',
#   u'percent_650',
#   u'34_1',
#   u'reuters_deal',
#   u'million_tender',
#   u'nomura_drive',
#   u'13_million',
#   u'jafco_would',
#   u'nomura_japan',
#   u'buying_sale',
#   u'650_yen',
#   u'u_business',
#   u'thomas_edmund',
#   u'560_yen',
#   u'34_percent',
#   u'considering_jafco',
#   u'yen_165',
#   u'13_two',
#   u'planned_book',
#   u'pretax_80',
#   u'37_percent',
#   u'stake_group',
#   u'booked_september',
#   u'resource_said',
#   u'co_sell',
#   u'research_4307',
#   u'share_stake',
#   u'million_said',
#   u'adding_share',
#   u'yen_benchmark',
#   u'yen_share',
#   u'average_0',
#   u'5_1',
#   u'statement_research',
#   u'seek_capital',
#   u'6178_group',
#   u'2015_index',
#   u'broke_real',
#   u'research_nomura',
#   u'sold_48',
#   u'million_july',
#   u'21_generate',
#   u'kitamura_call',
#   u'reporting_jacqueline',
#   u'tendered_jafco',
#   u'firm_tokyo',
#   u'jafco_tender',
#   u'sold_8',
#   u'2_thomas',
#   u'real_research',
#   u'management_resource',
#   u'5_share',
#   u'holding_reuters',
#   u'generate_billion',
#   u'billion_said',
#   u'brokerage_bank',
#   u'348_said',
#   u'260_october',
#   u'investment_jafco',
#   u'largest_said',
#   u'tokyo_nomura',
#   u'percent_1',
#   u'percent_5',
#   u'2015_n225',
#   u'venture_seek',
#   u'yen_october',
#   u'percent_8',
#   u'reuters_june',
#   u'banking_jafco',
#   u'kitamura_planning',
#   u'shift_nomura',
#   u'source_reuters',
#   u'41_7',
#   u'investment_said',
#   u'wong_blair',
#   u'thomas_editing',
#   u'percent_yen',
#   u'post_holding',
#   u'holding_friday',
#   u'34_2',
#   u'planned_18',
#   u'booked_nomura',
#   u'benchmark_nikkei',
#   u'percent_260',
#   u'holding_estate',
#   u'optimally_resource',
#   u'drive_enhance',
#   u'share_61',
#   u'165_million',
#   u'may_talk',
#   u'see_growth',
#   u'book_4',
#   u'4_per',
#   u'firm_jafco',
#   u'billion_5',
#   u'6178_sell',
#   u'index_6',
#   u'buying_million',
#   u'would_million',
#   u'back_firm',
#   u'group_company',
#   u'area_nomura',
#   u'group_real',
#   u'jafco_drive',
#   u'million_deal',
#   u'said_capital',
#   u'real_3231',
#   u'551_would',
#   u'book_gain',
#   u'would_profit',
#   u'may_use',
#   u'ltd_hold',
#   u'share_1',
#   u'nomura_million',
#   u'share_7',
#   u'share_6',
#   u'share_5',
#   u'optimally_management',
#   u'yen_348',
#   u'japanese_seek',
#   u'deal_nomura',
#   u'share_book',
#   u'september_statement',
#   u'million_two',
#   u'selling_stake',
#   u'stake_drive',
#   u'sale_officer',
#   u'jafco_jafco',
#   u'yen_41',
#   u'post_sell',
#   u'japan_brokerage',
#   u'9_80',
#   u'jafco_inc',
#   u'raising_yen',
#   u'business_would',
#   u'use_capital',
#   u'growth_brokerage',
#   u'holding_told',
#   u'stake_wilson',
#   u'capital_tokyo',
#   u'capital_shift',
#   u'4307_2',
#   u'share_co',
#   u'institute_sold',
#   u'index_0',
#   u'hold_37',
#   u'estate_institute',
#   u'shift_growth',
#   u'80_july',
#   u'stake_co',
#   u'said_closed',
#   u'reporting_editing',
#   u'benchmark_fell',
#   u'business_contribute',
#   u'jafco_reuters',
#   u'enhance_management',
#   u'firm_japanese',
#   u'5_period',
#   u'nomura_brokerage',
#   u'respectively_thomas',
#   u'would_share',
#   u'co_6178',
#   u'nomura_estate',
#   u'real_longer',
#   u'capital_area',
#   u'japanese_brokerage',
#   u'37_respectively',
#   u'jacqueline_wong',
#   u'japan_sell',
#   u'4_tender',
#   u'per_raising',
#   u'nomura_inc',
#   u'deal_generate',
#   u'capital_efficiency',
#   u'percent_wilson',
#   u'planning_nomura',
#   u'nomura_talk',
#   u'respectively_jacqueline',
#   u'firm_shift',
#   u'2_4',
#   u'investment_use',
#   u'use_efficiently',
#   u'sold_gain',
#   u'japan_6178',
#   u'resource_closed',
#   u'bank_wanted',
#   u'area_growth',
#   u'348_nomura',
#   u'n225_6',
#   u'n225_0',
#   u'institute_hold',
#   u'nomura_5',
#   u'average_fell',
#   u'nomura_1',
#   u'percent_37',
#   u'nomura_2',
#   u'unofficial_holding',
#   u'longer_stake',
#   u'nomura_3231',
#   u'nomura_9',
#   u'stake_back',
#   u'1_15',
#   u'unofficial_japan',
#   u'jafco_buying',
#   u'nomura_said',
#   u'percent_sold',
#   u'would_capital',
#   u'told_planning',
#   u'talk_post',
#   u'million_jafco',
#   u'co_group',
#   u'reuters_said',
#   u'reuters_8604',
#   u'stake_financial',
#   u'inc_8604',
#   u'percent_95',
#   u'investment_bank',
#   u'profit_80',
#   u'fell_nomura',
#   u'institute_planned',
#   u'japanese_capital',
#   u'back_venture',
#   u'institute_adding',
#   u'6_48',
#   u'yen_july',
#   u'jafco_holding',
#   u'8604_share',
#   u'adding_book',
#   u'nomura_share',
#   u'1_yen',
#   u'bank_may',
#   u'two_billion',
#   u'reuters_holding',
#   u'currently_expanding',
#   u'percent_share',
#   u'560_raising',
#   u'share_yen',
#   u'4_billion',
#   u'stake_4',
#   u'sell_group',
#   u'co_firm',
#   u'conference_planning',
#   u'tender_61',
#   u'efficiency_management',
#   u'share_billion',
#   u'nomura_venture',
#   u'group_estate',
#   u'june_nomura',
#   u'said_million',
#   u'statement_jafco',
#   u'contribute_efficiency',
#   u'real_source',
#   u'wilson_jacqueline',
#   u'july_september',
#   u'enhance_allocate',
#   u'bank_capital',
#   u'unofficial_post',
#   u'million_pretax',
#   u'investment_selling',
#   u'takumi_conference',
#   u'capital_reuters',
#   u'8595_firm',
#   u'sold_jafco',
#   u'yen_deal',
#   u'260_yen',
#   u'statement_4307',
#   u'3231_deal',
#   u'2015_benchmark',
#   u'share_nomura',
#   u'18_yen',
#   u'yen_highest',
#   u'told_sell',
#   u'estate_3231',
#   u'billion_9',
#   u'nomura_8',
#   u'41_per',
#   u'said_longer',
#   u'said_may',
#   u'2015_average',
#   u'per_billion',
#   u'jafco_15',
#   u'thomas_wong',
#   u'jafco_13',
#   u'holding_stake',
#   u'nikkei_index',
#   u'share_two',
#   u'billion_million',
#   u'company_holding',
#   u'nomura_stake',
#   u'would_drive',
#   u'yen_since',
#   u'551_generate',
#   u'2_tendered',
#   u'jafco_capital',
#   u'began_post',
#   u'21_would',
#   u'fell_0',
#   u'said_sold',
#   u'17_jafco',
#   u'fell_6',
#   u'allocate_share',
#   u'post_longer',
#   u'chief_officer',
#   u'stake_thomas',
#   u'sale_takumi',
#   u'book_yen',
#   u'share_closed',
#   u'million_booked',
#   u'41_38',
#   u'pretax_profit',
#   u'yen_per',
#   u'stake_41',
#   u'tokyo_inc',
#   u'told_conference',
#   u'japan_venture',
#   u'1_1',
#   u'stake_contribute',
#   u'separate_jafco',
#   u'respectively_wilson',
#   u'41_raising',
#   u'650_ended',
#   u'260_since',
#   u'percent_stake',
#   u'yen_38',
#   u'expanding_u',
#   u'may_began',
#   u'may_capital',
#   u'sale_financial',
#   u'48_percent',
#   u'see_brokerage',
#   u'since_n225',
#   u'management_share',
#   u'38_yen',
#   u'billion_165',
#   u'5_650',
#   u'tendered_95',
#   u'95_jafco',
#   u'wanted_use',
#   u'nomura_enhance',
#   u'capital_japanese',
#   u'brokerage_may',
#   u'drive_allocate',
#   u'percent_respectively',
#   u'broke_said',
#   u'japan_co',
#   u'billion_348',
#   u'18_billion',
#   u'benchmark_average',
#   u'brokerage_seek',
#   u'bank_use',
#   u'38_million',
#   u'said_research',
#   u'call_planning',
#   u'5_july',
#   u'estate_considering',
#   u'would_contribute',
#   u'institute_book',
#   u'institute_2',
#   u'4_share',
#   u'would_tender',
#   u'holding_talk',
#   u'friday_stake',
#   u'nomura_8604',
#   u'3_million',
#   u'nikkei_average',
#   u'call_holding',
#   u'editing_wong',
#   u'billion_nomura',
#   u'seek_growth',
#   u'nomura_hold',
#   u'1_650',
#   u'wong_edmund',
#   u'firm_brokerage',
#   u'told_nomura',
#   u'said_statement',
#   u'efficiently_expanding',
#   u'yen_9',
#   u'nomura_650',
#   u'yen_5',
#   u'index_fell',
#   u'6_sold',
#   u'8_6',
#   u'may_currently',
#   u'allocate_said',
#   u'planning_sell',
#   u'september_said',
#   u'5_september',
#   u'5_nomura',
#   u'4307_hold',
#   u'banking_business',
#   u'80_september',
#   u'ended_percent',
#   u'deal_pretax',
#   u'holding_group',
#   u'yen_million',
#   u'japan_bank',
#   u'holding_said',
#   u'stake_officer',
#   u'said_share',
#   u'institute_ltd',
#   u'enhance_efficiency',
#   u'percent_million',
#   u'95_million',
#   u'4_yen',
#   u'brokerage_see',
#   u'80_9',
#   u'nomura_adding',
#   u'brokerage_area',
#   u'nomura_ltd',
#   u'institute_nomura',
#   u'21_nomura',
#   u'longer_jafco',
#   u'8604_said',
#   u'statement_would',
#   u'95_said',
#   u'9_9',
#   u'post_stake',
#   u'currently_business',
#   u'optimally_said',
#   u'nomura_institute',
#   u'capital_u',
#   u'thomas_wilson',
#   u'nomura_friday',
#   u'conference_nomura',
#   u'closed_650',
#   u'drive_capital',
#   u'japan_considering',
#   u'growth_largest',
#   u'told_deal',
#   u'61_yen',
#   u'editing_jacqueline',
#   u'260_highest',
#   u'october_benchmark',
#   u'brokerage_investment',
#   u'post_buying',
#   u'friday_share',
#   u'investment_may',
#   u'considering_stake',
#   u'tender_yen',
#   u'company_estate',
#   u'july_separate',
#   u'million_institute',
#   u'broke_estate',
#   u'estate_34',
#   u'raising_348',
#   u'4_two',
#   u'period_statement',
#   u'reuters_inc',
#   u'stake_sell',
#   u'9_july',
#   u'million_period',
#   u'capital_optimally',
#   u'wanted_expanding',
#   u'period_holding',
#   u'holding_deal',
#   u'statement_ltd',
#   u'average_percent',
#   u'13_4',
#   u'9_september',
#   u'tender_research',
#   u'considering_chief',
#   u'ended_yen',
#   u'48_million',
#   u'7_348',
#   u'million_nomura',
#   u'6178_nomura',
#   u'percent_highest',
#   u'6_nomura',
#   u'stake_capital',
#   u'17_stake',
#   u'said_said',
#   u'since_nikkei',
#   u'capital_firm',
#   u'considering_buying',
#   u'million_percent',
#   u'8595_capital',
#   u'million_share',
#   u'deal_june',
#   u'17_4',
#   u'17_6',
#   u'june_estate',
#   u'deal_estate',
#   u'index_percent',
#   u'2_reporting',
#   u'statement_said',
#   u'15_5',
#   u'2_respectively',
#   u'jafco_co',
#   u'gain_165',
#   u'said_buying',
#   u'sell_jafco',
#   u'260_2015',
#   u'stake_560',
#   u'institute_4307',
#   u'5_million',
#   u'financial_conference',
#   u'percent_thomas',
#   u'37_2',
#   u'stake_tokyo',
#   u'investment_business',
#   u'hold_stake',
#   u'index_nomura',
#   u'gain_yen',
#   u'efficiently_u',
#   u'capital_see',
#   u'5_260',
#   u'estate_said',
#   u'nomura_pretax',
#   u'share_said',
#   u'u_investment',
#   u'million_adding',
#   u'0_percent',
#   u'adding_gain',
#   u'nomura_nomura',
#   u'jafco_contribute',
#   u'348_statement',
#   u'venture_japanese',
#   u'5_institute',
#   u'source_broke',
#   u'9_booked',
#   u'billion_80',
#   u'estate_research',
#   u'research_sold',
#   u'editing_blair',
#   u'post_considering',
#   u'nomura_separate',
#   u'sell_company',
#   u'co_company',
#   u'stake_yen',
#   u'8604_friday',
#   u'165_period',
#   u'broke_june',
#   u'enhance_capital',
#   u'deal_broke',
#   u'sold_8595',
#   u'sell_venture',
#   u'2_stake',
#   u'9_period',
#   u'3231_told',
#   u'drive_optimally',
#   u'resource_share',
#   u'jafco_officer',
#   u'seek_area',
#   u'9_million',
#   u'conference_holding',
#   u'would_generate',
#   u'80_booked',
#   u'said_use',
#   u'contribute_nomura',
#   u'3231_broke',
#   u'61_3',
#   u'38_billion',
#   u'shift_area',
#   u'efficiently_banking',
#   u'share_research',
#   u'nomura_holding',
#   u'share_adding',
#   u'nomura_firm',
#   u'holding_research',
#   u'95_share',
#   u'yen_would',
#   u'wanted_efficiently',
#   u'post_jafco',
#   u'co_8595',
#   u'share_ended',
#   u'stake_8595',
#   u'said_jafco',
#   u'9_yen',
#   u'highest_benchmark',
#   u'institute_share',
#   u'holding_real',
#   u'sold_18',
#   u'back_brokerage',
#   u'million_3',
#   u'business_jafco',
#   u'wanted_capital',
#   u'sold_stake',
#   u'billion_booked',
#   u'nomura_real',
#   u'stake_reporting',
#   u'japan_post',
#   u'ended_260',
#   u'share_38',
#   u'japan_largest',
#   u'nomura_profit',
#   u'largest_brokerage',
#   u'since_benchmark',
#   u'0_6',
#   u'officer_kitamura',
#   u'drive_efficiency',
#   u'wanted_currently',
#   u'yen_ended',
#   u'nomura_capital',
#   u'650_jafco',
#   u'expanding_banking',
#   u'longer_considering',
#   u'said_friday',
#   u'holding_post',
#   u'japan_nomura',
#   u'17_percent',
#   u'research_hold',
#   u'sell_4',
#   u'37_reporting',
#   u'research_ltd',
#   u'tokyo_holding',
#   u'chief_kitamura',
#   u'61_billion',
#   u'officer_told',
#   u'jafco_sale',
#   u'share_raising',
#   u'benchmark_index',
#   u'share_gain',
#   u'2_percent',
#   u'said_wanted',
#   u'efficiency_optimally',
#   u'said_stake',
#   u'nomura_percent',
#   u'ltd_4307',
#   u'capital_expanding',
#   u'tender_billion',
#   u'5_research',
#   u'would_pretax',
#   u'estate_longer',
#   u'real_post',
#   u'holding_began',
#   u'jafco_back',
#   u'4_5',
#   u'average_6',
#   u'3231_source',
#   u'8604_sold',
#   u'stake_firm',
#   u'capital_growth',
#   u'hold_tendered',
#   u'adding_planned',
#   u'period_began',
#   u'firm_nomura',
#   u'nomura_48',
#   u'38_7',
#   u'said_considering',
#   u'area_see',
#   u'growth_japan',
#   u'yen_statement',
#   u'venture_reuters',
#   u'unofficial_talk',
#   u'wilson_editing',
#   u'back_japanese',
#   u'jafco_560',
#   u'pretax_yen',
#   u'nomura_yen',
#   u'jafco_venture',
#   u'financial_officer',
#   u'officer_call',
#   u'stake_sale',
#   u'percent_2',
#   u'sell_nomura',
#   u'jafco_8595',
#   u'venture_capital',
#   u'551_deal',
#   u'million_6',
#   u'nomura_source',
#   u'expanding_selling',
#   u'institute_1',
#   u'61_551',
#   u'respectively_editing',
#   u'share_percent',
#   u'sold_planned',
#   u'billion_21',
#   u'560_share',
#   u'said_separate',
#   u'banking_would',
#   u'37_sell',
#   u'conference_sell',
#   u'7_billion',
#   u'tender_551',
#   u'percent_4',
#   u'real_34',
#   u'investment_wanted',
#   u'capital_seek',
#   u'shift_capital',
#   u'tender_5',
#   u'planning_real',
#   u'tender_3',
#   u'talk_holding',
#   u'0_nomura',
#   u'wilson_blair',
#   u'currently_investment',
#   u'0_sold',
#   u'13_tender',
#   u'nomura_post',
#   u'september_period',
#   u'650_share',
#   u'5_yen',
#   u'percent_sell',
#   u'165_5',
#   u'research_1',
#   u'165_september',
#   u'per_share',
#   u'booked_july',
#   u'separate_statement',
#   u'capital_japan',
#   u'4_41',
#   u'profit_9',
#   u'real_told',
#   u'area_largest',
#   u'business_stake',
#   u'currently_u',
#   u'million_would',
#   u'nomura_began',
#   u'financial_kitamura',
#   u'stake_million',
#   u'since_october',
#   u'18_4',
#   ...],
#  [u'service_expertise',
#   u'company_austria',
#   u'mobile_plan',
#   u'certainly_share',
#   u'number_internet',
#   u'led_would',
#   u'austria_trionow',
#   u'alexander_smith',
#   u'around_billion',
#   u'europe_hope',
#   u'slim_player',
#   u'merged_based',
#   u'country_million',
#   u'mobile_including',
#   u'rival_mexican',
#   u'customer_generate',
#   u'plan_expand',
#   u'progress_rich',
#   u'drei_new',
#   u'a1_unit',
#   u'austria_time',
#   u'telecom_company',
#   u'2014_telecom',
#   u'hong_based',
#   u'billion_time',
#   u'year_editing',
#   u'part_company',
#   u'hutchison_internet',
#   u'would_deal',
#   u'austria_owner',
#   u'slim_telekom',
#   u'management_still',
#   u'especially_major',
#   u'owner_95',
#   u'jan_trionow',
#   u'deal_year',
#   u'austria_austria',
#   u'population_clear',
#   u'landline_95',
#   u'company_broadband',
#   u'telecom_buying',
#   u'new_part',
#   u'create_slim',
#   u'mobile_3',
#   u'group_euro',
#   u'still_tele2',
#   u'euro_opportunity',
#   u'hutchison_buying',
#   u'competitive_especially',
#   u'co_recently',
#   u'pricing_hutchison',
#   u'aggressive_hutchison',
#   u'ratio_percent',
#   u'broadband_drei',
#   u'elsewhere_materialize',
#   u'telekom_far',
#   u'vienna_firm',
#   u'2020_one',
#   u'austria_vienna',
#   u'discussed_market',
#   u'approval_keith',
#   u'telekom_austrian',
#   u'unit_service',
#   u'group_currently',
#   u'rival_vienna',
#   u'owner_111',
#   u'chief_conference',
#   u'slim_telecom',
#   u'term_ratio',
#   u'speed_even',
#   u'telekom_policy',
#   u'larger_customer',
#   u'owner_austria',
#   u'within_next',
#   u'deutsche_pricing',
#   u'7_million',
#   u'led_hong',
#   u'pricing_slim',
#   u'2020_hutchison',
#   u'integral_part',
#   u'merged_led',
#   u'million_million',
#   u'company_especially',
#   u'market_mobile',
#   u'owner_telekom',
#   u'annual_mobile',
#   u'elsewhere_digital',
#   u'even_alpine',
#   u'part_internet',
#   u'generate_term',
#   u'a1_share',
#   u'euro_annual',
#   u'market_2013',
#   u'billion_sale',
#   u'telekom_merged',
#   u'market_2014',
#   u'sale_new',
#   u'asian_telecom',
#   u'mobile_major',
#   u'austria_slim',
#   u'also_withdrawn',
#   u'play_speed',
#   u'key_market',
#   u'government_access',
#   u'longer_sale',
#   u'austrian_asian',
#   u'merged_currently',
#   u'swedish_million',
#   u'billion_a1',
#   u'part_speed',
#   u'drei_friday',
#   u'hoping_elsewhere',
#   u'austria_co',
#   u'country_clear',
#   u'hutchison_landline',
#   u'france_slim',
#   u'a1_lucrative',
#   u'next_12',
#   u'reached_larger',
#   u'tele2_swedish',
#   u'line_3',
#   u'line_2',
#   u'clear_a1',
#   u'line_4',
#   u'longer_new',
#   u'line_6',
#   u'carlos_drei',
#   u'8_million',
#   u'said_austria',
#   u'speed_part',
#   u'certainly_a1',
#   u'larger_share',
#   u'earnings_new',
#   u'conference_want',
#   u'2016_2',
#   u'lagging_government',
#   u'would_1',
#   u'aggressive_pricing',
#   u'2016_6',
#   u'drei_trionow',
#   u'austria_jan',
#   u'close_editing',
#   u'hutchison_drei',
#   u'rich_want',
#   u'became_austrian',
#   u'rich_access',
#   u'elsewhere_broadband',
#   u'become_major',
#   u'ratio_22',
#   u'access_speed',
#   u'euro_unit',
#   u'providing_company',
#   u'move_reached',
#   u'rival_austria',
#   u'company_economic',
#   u'billion_unit',
#   u'6_telekom',
#   u'challenge_said',
#   u'highly_market',
#   u'internet_organisation',
#   u'economic_oecd',
#   u'internet_economic',
#   u'vienna_hutchison',
#   u'customer_25',
#   u'telekom_unit',
#   u'still_austrian',
#   u'telecom_majority',
#   u'hope_broadband',
#   u'closer_certainly',
#   u'monopoly_service',
#   u'especially_operator',
#   u'country_population',
#   u'still_brand',
#   u'larger_lucrative',
#   u'based_hutchison',
#   u'company_operator',
#   u'orange_becoming',
#   u'internet_company',
#   u'new_still',
#   u'guidance_new',
#   u'drei_chief',
#   u'company_high',
#   u'one_entertainment',
#   u'6_austria',
#   u'4_2016',
#   u'plan_customer',
#   u'access_broadband',
#   u'mobile_entertainment',
#   u'sale_million',
#   u'still_discussed',
#   u'telekom_billion',
#   u'drei_austria',
#   u'internet_million',
#   u'austria_executive',
#   u'monopoly_combined',
#   u'company_organisation',
#   u'slim_became',
#   u'operation_oecd',
#   u'country_7',
#   u'aggressive_policy',
#   u'alpine_country',
#   u'million_rival',
#   u'closer_a1',
#   u'line_revenue',
#   u'austria_group',
#   u'merged_hong',
#   u'8_telekom',
#   u'lagging_country',
#   u'remotest_part',
#   u'tele2_million',
#   u'hoping_europe',
#   u'firm_austria',
#   u'country_2020',
#   u'landline_line',
#   u'sale_landline',
#   u'focused_95',
#   u'former_telekom',
#   u'month_market',
#   u'speed_broadband',
#   u'sale_guidance',
#   u'oecd_warned',
#   u'3_line',
#   u'movil_became',
#   u'line_million',
#   u'speed_company',
#   u'stop_reached',
#   u'group_22',
#   u'month_highly',
#   u'early_earnings',
#   u'materialize_major',
#   u'structure_tele2',
#   u'austria_focused',
#   u'annual_million',
#   u'22_year',
#   u'company_access',
#   u'around_sale',
#   u'aggressive_america',
#   u'hutchison_austria',
#   u'million_create',
#   u'would_annual',
#   u'million_internet',
#   u'deal_expected',
#   u'austrian_within',
#   u'providing_high',
#   u'development_progress',
#   u'slim_former',
#   u'service_million',
#   u'term_guidance',
#   u'slim_vienna',
#   u'austria_operation',
#   u'monopoly_austria',
#   u'major_chief',
#   u'line_line',
#   u'government_company',
#   u'tele2_euro',
#   u'12_highly',
#   u'tycoon_carlos',
#   u'warned_rich',
#   u'competitive_mobile',
#   u'swedish_111',
#   u'kong_would',
#   u'reached_a1',
#   u'million_carlos',
#   u'withdrawn_12',
#   u'conference_closer',
#   u'merged_22',
#   u'group_orange',
#   u'expected_year',
#   u'rival_carlos',
#   u'group_kong',
#   u'would_currently',
#   u'structure_still',
#   u'focused_million',
#   u'annual_landline',
#   u'reached_lucrative',
#   u'early_term',
#   u'tele2_brand',
#   u'sale_also',
#   u'want_a1',
#   u'becoming_monopoly',
#   u'would_euro',
#   u'2016_revenue',
#   u'friday_group',
#   u'population_challenge',
#   u'revenue_term',
#   u'plan_business',
#   u'euro_telekom',
#   u'tycoon_telekom',
#   u'said_merged',
#   u'revenue_6',
#   u'country_hutchison',
#   u'market_broadband',
#   u'combined_country',
#   u'revenue_2',
#   u'editing_keith',
#   u'telecom_firm',
#   u'group_high',
#   u'time_europe',
#   u'far_service',
#   u'challenge_drei',
#   u'buy_austria',
#   u'buy_slim',
#   u'vienna_telecom',
#   u'unit_pricing',
#   u'revenue_medium',
#   u'mobile_hutchison',
#   u'hong_around',
#   u'sale_internet',
#   u'want_access',
#   u'hutchison_slim',
#   u'service_business',
#   u'rival_tycoon',
#   u'term_merged',
#   u'business_25',
#   u'austria_expertise',
#   u'austrian_aggressive',
#   u'management_tele2',
#   u'withdrawn_market',
#   u'deutsche_austrian',
#   u'stop_share',
#   u'america_key',
#   u'95_create',
#   u'hope_become',
#   u'internet_mobile',
#   u'6_euro',
#   u'landline_tele2',
#   u'drei_merged',
#   u'medium_ratio',
#   u'slim_austria',
#   u'majority_former',
#   u'euro_create',
#   u'group_hoping',
#   u'austria_highly',
#   u'generate_percent',
#   u'telecom_major',
#   u'becoming_state',
#   u'month_competitive',
#   u'expertise_customer',
#   u'chief_news',
#   u'a1_reached',
#   u'new_integral',
#   u'a1_executive',
#   u'expand_business',
#   u'four_line',
#   u'combined_service',
#   u'group_telecom',
#   u'providing_austria',
#   u'euro_rival',
#   u'customer_medium',
#   u'year_alexander',
#   u'government_want',
#   u'mexican_austria',
#   u'state_austria',
#   u'within_said',
#   u'said_executive',
#   u'broadband_austria',
#   u'sale_four',
#   u'new_group',
#   u'monopoly_country',
#   u'hutchison_buy',
#   u'euro_hoping',
#   u'euro_mobile',
#   u'telekom_monopoly',
#   u'million_line',
#   u'chief_group',
#   u'expected_regulatory',
#   u'want_closer',
#   u'kong_based',
#   u'europe_broadband',
#   u'landline_owner',
#   u'unit_policy',
#   u'brand_withdrawn',
#   u'million_clear',
#   u'play_high',
#   u'lagging_rich',
#   u'slim_drei',
#   u'regulatory_smith',
#   u'group_providing',
#   u'customer_revenue',
#   u'invested_time',
#   u'buying_telecom',
#   u'part_hutchison',
#   u'12_competitive',
#   u'said_jan',
#   u'7_austria',
#   u'market_within',
#   u'austrian_policy',
#   u'business_give',
#   u'alpine_number',
#   u'asian_france',
#   u'monopoly_invested',
#   u'tycoon_drei',
#   u'broadband_battleground',
#   u'reuters_hutchison',
#   u'operator_including',
#   u'conference_move',
#   u'create_carlos',
#   u'market_next',
#   u'lucrative_business',
#   u'management_also',
#   u'deutsche_unit',
#   u'compare_3',
#   u'said_competitive',
#   u'compare_4',
#   u'operation_progress',
#   u'recently_rich',
#   u'service_expand',
#   u'sale_management',
#   u'service_population',
#   u'group_would',
#   u'year_regulatory',
#   u'rival_reuters',
#   u'mobile_firm',
#   u'telecom_austria',
#   u'6_billion',
#   u'vienna_reuters',
#   u'management_structure',
#   u'player_austrian',
#   u'high_speed',
#   u'chief_executive',
#   u'firm_buying',
#   u'expand_generate',
#   u'telekom_pricing',
#   u'mexican_tycoon',
#   u'news_a1',
#   u'million_mexican',
#   u'internet_austria',
#   u'million_2016',
#   u'integral_high',
#   u'austria_market',
#   u'far_combined',
#   u'share_business',
#   u'drei_group',
#   u'battleground_drei',
#   u'including_aggressive',
#   u'becoming_majority',
#   u'remotest_country',
#   u'withdrawn_next',
#   u'one_service',
#   u'service_8',
#   u'telekom_drei',
#   u'22_deal',
#   u'market_early',
#   u'becoming_former',
#   u'service_7',
#   u'hong_hutchison',
#   u'monopoly_telekom',
#   u'austria_tele2',
#   u'want_speed',
#   u'majority_monopoly',
#   u'aggressive_slim',
#   u'market_asian',
#   u'austria_merged',
#   u'structure_discussed',
#   u'1_euro',
#   u'broadband_become',
#   u'broadband_deutsche',
#   u'said_give',
#   u'revenue_telekom',
#   u'austria_far',
#   u'service_plan',
#   u'group_billion',
#   u'25_merged',
#   u'battleground_new',
#   u'warned_progress',
#   u'landline_compare',
#   u'major_battleground',
#   u'pending_editing',
#   u'play_providing',
#   u'far_telecom',
#   u'trionow_term',
#   u'battleground_said',
#   u'hutchison_billion',
#   u'mobile_service',
#   u'owner_million',
#   u'four_landline',
#   u'alpine_one',
#   u'million_mobile',
#   u'co_operation',
#   u'euro_million',
#   u'news_want',
#   u'friday_hong',
#   u'clear_said',
#   u'pricing_america',
#   u'former_state',
#   u'company_internet',
#   u'including_unit',
#   u'chief_trionow',
#   u'alexander_weir',
#   u'trionow_want',
#   u'materialize_battleground',
#   u'based_around',
#   u'competitive_company',
#   u'internet_even',
#   u'reuters_mobile',
#   u'million_euro',
#   u'operation_development',
#   u'euro_sale',
#   u'brand_market',
#   u'unit_far',
#   u'million_tycoon',
#   u'brand_next',
#   u'want_high',
#   u'organisation_operation',
#   u'country_access',
#   u'billion_growth',
#   u'merged_would',
#   u'austria_economic',
#   u'trionow_said',
#   u'2_6',
#   u'entertainment_expand',
#   u'withdrawn_austrian',
#   u'drei_executive',
#   u'around_euro',
#   u'government_high',
#   u'2013_group',
#   u'euro_far',
#   u'want_stop',
#   u'part_alpine',
#   u'market_month',
#   u'population_8',
#   u'month_said',
#   u'chief_jan',
#   u'austrian_next',
#   u'a1_combined',
#   u'pending_regulatory',
#   u'integral_providing',
#   u'3_revenue',
#   u'player_2014',
#   u'owner_monopoly',
#   u'entertainment_service',
#   u'hope_major',
#   u'said_longer',
#   u'player_2013',
#   u'longer_guidance',
#   u'euro_mexican',
#   u'tele2_austria',
#   u'said_highly',
#   u'95_111',
#   u'owner_euro',
#   u'12_austria',
#   u'a1_austria',
#   u'tycoon_austria',
#   u'telecom_especially',
#   u'group_part',
#   u'carlos_austria',
#   u'business_trionow',
#   u'austrian_month',
#   u'mobile_internet',
#   u'group_percent',
#   u'hong_kong',
#   u'slim_said',
#   u'trionow_move',
#   u'brand_austrian',
#   u'structure_also',
#   u'become_drei',
#   u'would_expected',
#   u'expected_pending',
#   u'95_million',
#   u'2014_group',
#   u'reached_share',
#   u'said_telecom',
#   u'million_austria',
#   u'expertise_25',
#   u'america_austrian',
#   u'austria_buying',
#   u'4_revenue',
#   u'europe_materialize',
#   u'clear_challenge',
#   u'hutchison_mobile',
#   u'majority_state',
#   u'austria_mobile',
#   u'8_challenge',
#   u'25_percent',
#   u'based_would',
#   u'focused_tele2',
#   u'slim_key',
#   u'approval_editing',
#   u'access_internet',
#   u'invested_billion',
#   u'providing_internet',
#   u'deal_regulatory',
#   u'speed_internet',
#   u'lucrative_trionow',
#   u'lucrative_market',
#   u'move_a1',
#   u'also_still',
#   u'friday_led',
#   u'a1_drei',
#   u'mobile_broadband',
#   u'sale_mobile',
#   u'development_warned',
#   u'speed_austria',
#   u'discussed_brand',
#   u'broadband_even',
#   u'recently_progress',
#   u'business_early',
#   u'regulatory_alexander',
#   u'lucrative_said',
#   u'larger_business',
#   u'economic_warned',
#   u'22_close',
#   u'buy_tele2',
#   u'oecd_lagging',
#   u'compare_million',
#   u'high_even',
#   u'swedish_owner',
#   u'executive_news',
#   u'operation_recently',
#   u'annual_sale',
#   u'drei_landline',
#   u'7_telekom',
#   u'economic_development',
#   u'major_said',
#   u'merged_ratio',
#   u'would_around',
#   u'based_1',
#   u'early_sale',
#   u'revenue_ratio',
#   u'combined_8',
#   u'buying_france',
#   u'austria_landline',
#   u'generate_medium',
#   u'growth_hope',
#   u'hutchison_around',
#   u'said_earnings',
#   u'time_hoping',
#   u'broadband_telekom',
#   u'austria_reuters',
#   u'number_one',
#   u'customer_early',
#   u'country_mobile',
#   u'hutchison_number',
#   u'group_france',
#   u'mobile_deutsche',
#   u'major_telekom',
#   u'billion_million',
#   u'austria_new',
#   u'time_growth',
#   u'give_guidance',
#   u'policy_hutchison',
#   u'pending_alexander',
#   u'a1_certainly',
#   u'broadband_remotest',
#   u'internet_compare',
#   u'tele2_carlos',
#   u'part_number',
#   u'buying_austria',
#   u'annual_four',
#   u'internet_alpine',
#   u'pending_smith',
#   u'reuters_firm',
#   u'growth_elsewhere',
#   u'term_sale',
#   u'development_recently',
#   u'term_group',
#   u'progress_government',
#   u'slim_state',
#   u'said_part',
#   u'a1_far',
#   u'high_broadband',
#   u'telecom_slim',
#   u'earnings_sale',
#   u'access_even',
#   u'share_trionow',
#   u'europe_become',
#   u'digital_become',
#   u'said_term',
#   u'chief_new',
#   u'market_buying',
#   u'move_stop',
#   u'tele2_rival',
#   u'four_million',
#   u'7_challenge',
#   u'especially_mobile',
#   u'buying_focused',
#   u'population_7',
#   u'said_integral',
#   u'hoping_hope',
#   u'1_annual',
#   u'compare_line',
#   u'organisation_economic',
#   u'america_movil',
#   u'said_chief',
#   u'approval_weir',
#   u'tele2_market',
#   u'unit_aggressive',
#   u'movil_player',
#   u'market_telecom',
#   u'country_company',
#   u'led_based',
#   u'carlos_said',
#   u'opportunity_digital',
#   u'opportunity_elsewhere',
#   u'challenge_a1',
#   u'editing_alexander',
#   u'business_customer',
#   u'still_withdrawn',
#   u'america_player',
#   u'one_mobile',
#   u'company_speed',
#   u'market_business',
#   u'population_million',
#   u'percent_close',
#   u'euro_growth',
#   u'telecom_asian',
#   u'buying_swedish',
#   u'sale_structure',
#   u'combined_telecom',
#   u'executive_trionow',
#   u'executive_want',
#   u'term_currently',
#   u'movil_key',
#   u'hutchison_america',
#   u'materialize_digital',
#   u'said_group',
#   u'austrian_unit',
#   u'reuters_telecom',
#   u'even_2020',
#   u'owner_former',
#   u'slim_friday',
#   u'larger_market',
#   u'structure_brand',
#   u'group_invested',
#   u'warned_recently',
#   u'term_management',
#   u'2013_2014',
#   u'next_highly',
#   u'create_rival',
#   u'lagging_want',
#   u'austria_euro',
#   u'22_expected',
#   u'stop_lucrative',
#   u'3_million',
#   u'trionow_longer',
#   u'unit_combined',
#   u'111_mexican',
#   u'2_euro',
#   u'a1_stop',
#   u'austria_a1',
#   u'currently_close',
#   u'want_move',
#   u'drei_carlos',
#   u'key_austrian',
#   u'firm_drei',
#   u'said_new',
#   u'give_sale',
#   u'closer_reached',
#   u'owner_state',
#   u'one_internet',
#   u'part_country',
#   u'certainly_larger',
#   u'asian_orange',
#   u'state_monopoly',
#   u'france_austria',
#   u'8_7',
#   u'key_2013',
#   u'a1_chief',
#   u'led_kong',
#   u'new_management',
#   u'growth_materialize',
#   u'medium_group',
#   u'part_providing',
#   u'development_oecd',
#   u'service_country',
#   u'want_company',
#   u'carlos_mobile',
#   u'give_longer',
#   u'digital_major',
#   u'france_telecom',
#   u'tele2_slim',
#   u'customer_give',
#   u'editing_weir',
#   u'austria_former',
#   u'hutchison_would',
#   u'said_early',
#   u'want_certainly',
#   u'especially_including',
#   u'warned_lagging',
#   u'even_country',
#   u'2016_euro',
#   u'austria_customer',
#   u'billion_hoping',
#   u'friday_kong',
#   u'become_chief',
#   u'a1_a1',
#   u'austria_monopoly',
#   u'12_said',
#   u'kong_around',
#   u'mobile_landline',
#   u'tele2_withdrawn',
#   u'kong_hutchison',
#   u'compare_2016',
#   u'play_integral',
#   u'policy_america',
#   u'organisation_oecd',
#   u'111_tycoon',
#   u'revenue_euro',
#   u'rich_country',
#   u'guidance_also',
#   u'create_mexican',
#   u'tele2_owner',
#   u'focused_owner',
#   u'austrian_market',
#   u'term_would',
#   u'euro_111',
#   u'former_monopoly',
#   u'movil_austrian',
#   u'editing_smith',
#   u'slim_america',
#   u'expertise_percent',
#   u'austria_friday',
#   u'based_billion',
#   u'trionow_conference',
#   u'ratio_currently',
#   u'said_play',
#   u'highly_competitive',
#   u'country_one',
#   u'guidance_structure',
#   u'group_time',
#   u'group_hong',
#   u'part_2020',
#   u'economic_operation',
#   u'percent_revenue',
#   u'monopoly_billion',
#   u'currently_deal',
#   u'hutchison_became',
#   u'conference_certainly',
#   u'company_operation',
#   u'mexican_carlos',
#   u'approval_alexander',
#   u'internet_co',
#   u'internet_entertainment',
#   u'million_challenge',
#   u'far_monopoly',
#   u'rich_company',
#   u'smith_weir',
#   u'billion_annual',
#   u'expertise_generate',
#   u'executive_conference',
#   u'a1_monopoly',
#   u'become_battleground',
#   u'america_became',
#   u'ratio_would',
#   u'operator_telekom',
#   u'million_revenue',
#   u'combined_population',
#   u'deal_pending',
#   u'trionow_closer',
#   u'remotest_2020',
#   u'co_warned',
#   u'executive_jan',
#   u'telecom_mobile',
#   u'would_billion',
#   u'billion_telekom',
#   u'group_led',
#   u'landline_focused',
#   u'2020_mobile',
#   u'slim_reuters',
#   u'entertainment_austria',
#   u'telekom_austria',
#   u'business_percent',
#   u'merged_group',
#   u'expand_expertise',
#   u'move_closer',
#   u'tele2_within',
#   u'billion_four',
#   u'highly_company',
#   u'co_development',
#   u'highly_telecom',
#   u'landline_internet',
#   u'reached_market',
#   u'high_austria',
#   u'invested_growth',
#   u'high_remotest',
#   u'austria_said',
#   u'mobile_austria',
#   u'a1_larger',
#   u'news_conference',
#   u'merged_kong',
#   u'trionow_news',
#   u'warned_country',
#   u'remotest_hutchison',
#   u'hutchison_euro',
#   u'internet_4',
#   u'speed_economic',
#   u'regulatory_keith',
#   u'next_austria',
#   u'internet_3',
#   u'want_broadband',
#   u'broadband_including',
#   u'111_rival',
#   u'key_telecom',
#   u'austria_majority',
#   u'give_term',
#   u'austria_firm',
#   u'major_including',
#   u'group_ratio',
#   u'battleground_chief',
#   u'2_billion',
#   u'hong_would',
#   u'currently_expected',
#   u'25_revenue',
#   u'player_market',
#   u'ratio_deal',
#   u'chief_play',
#   u'unit_monopoly',
#   u'orange_austria',
#   u'new_providing',
#   u'majority_telekom',
#   u'a1_business',
#   u'orange_majority',
#   u'company_mobile',
#   u'would_percent',
#   u'materialize_broadband',
#   u'reuters_drei',
#   u'internet_country',
#   u'chief_said',
#   u'telecom_group',
#   u'business_revenue',
#   u'said_drei',
#   u'said_led',
#   u'buy_carlos',
#   u'alexander_keith',
#   u'stop_larger',
#   u'opportunity_materialize',
#   u'also_brand',
#   u'close_approval',
#   u'telecom_service',
#   u'line_compare',
#   u'austria_news',
#   u'company_major',
#   u'telecom_population',
#   u'telecom_hutchison',
#   u'economic_co',
#   u'high_internet',
#   u'deal_close',
#   u'jan_conference',
#   u'3_2016',
#   u'regulatory_editing',
#   u'buying_landline',
#   u'austria_unit',
#   u'internet_line',
#   u'state_telekom',
#   u'drei_buying',
#   u'would_22',
#   u'broadband_operator',
#   u'currently_22',
#   u'8_clear',
#   u'hutchison_focused',
#   u'billion_opportunity',
#   u'austria_swedish',
#   u'2_telekom',
#   u'tele2_95',
#   u'customer_longer',
#   u'2013_buying',
#   u'country_high',
#   u'buying_owner',
#   u'line_2016',
#   u'group_austria',
#   u'expected_close',
#   u'recently_country',
#   u'focused_swedish',
#   u'new_discussed',
#   u'earnings_structure',
#   u'drei_jan',
#   u'customer_trionow',
#   u'recently_lagging',
#   u'major_austrian',
#   u'said_friday',
#   u'a1_said',
#   u'around_annual',
#   u'operation_warned',
#   u'expected_approval',
#   u'austrian_2013',
#   u'austrian_2014',
#   u'jan_move',
#   u'group_based',
#   u'also_tele2',
#   u'austrian_pricing',
#   u'currently_percent',
#   u'internet_service',
#   u'country_want',
#   u'providing_speed',
#   u'tele2_austrian',
#   u'discussed_tele2',
#   u'challenge_austria',
#   u'major_drei',
#   u'firm_hutchison',
#   u'part_high',
#   u'broadband_major',
#   u'group_integral',
#   u'operator_austrian',
#   u'close_year',
#   u'million_a1',
#   u'high_company',
#   u'drei_buy',
#   u'next_month',
#   u'carlos_slim',
#   u'progress_country',
#   ...],
#  [u'red_spotlight',
#   u'storm_prohibitive',
#   u'hemmed_constraint',
#   u'wednesday_large',
#   u'55_le',
#   u'research_accused',
#   u'native_head',
#   u'based_248',
#   u'physical_contract',
#   u'firm_asset',
#   u'valuation_book',
#   u'consultant_complied',
#   u'trading_revive',
#   u'used_sad',
#   u'umesh_hong',
#   u'percent_year',
#   u'business_fortune',
#   u'clara_richardson',
#   u'power_based',
#   u'nobg_slimming',
#   u'prelude_hand',
#   u'asian_trading',
#   u'sale_grow',
#   u'billion_stock',
#   u'deal_lost',
#   u'noble_appear',
#   u'noble_debt',
#   u'coal_say',
#   u'term_noble',
#   u'debt_pose',
#   u'thrust_2015',
#   u'providing_lifeline',
#   u'modest_company',
#   u'past_offer',
#   u'lost_major',
#   u'may_rating',
#   u'analyst_cash',
#   u'iceberg_research',
#   u'le_little',
#   u'gas_ore',
#   u'absent_liquefied',
#   u'snapped_asset',
#   u'worth_meanwhile',
#   u'sector_absent',
#   u'248_oil',
#   u'deal_noble',
#   u'billion_writedown',
#   u'research_firm',
#   u'248_sell',
#   u'know_guy',
#   u'trading_lost',
#   u'disposal_flagged',
#   u'coal_enough',
#   u'constraint_issue',
#   u'lost_guy',
#   u'36_dollar',
#   u'found_accounting',
#   u'talking_large',
#   u'reduced_physical',
#   u'money_devries',
#   u'engage_u',
#   u'due_shrunken',
#   u'plan_mark',
#   u'mercuria_248',
#   u'consultant_found',
#   u'said_moody',
#   u'term_last',
#   u'forex_stint',
#   u'sheet_essentially',
#   u'4_rating',
#   u'say_reduced',
#   u'1_disposal',
#   u'counterparties_many',
#   u'peer_group',
#   u'slump_appear',
#   u'bare_bone',
#   u'business_hemmed',
#   u'cutting_simply',
#   u'financing_trading',
#   u'exit_strategist',
#   u'billion_sheet',
#   u'sale_change',
#   u'wider_absent',
#   u'49_le',
#   u'relies_heavily',
#   u'remaining_even',
#   u'lifeline_said',
#   u'crunch_mean',
#   u'one_asset',
#   u'rejected_found',
#   u'liquid_unit',
#   u'sold_gas',
#   u'liquidity_month',
#   u'business_energy',
#   u'peer_million',
#   u'key_deadline',
#   u'trafigura_dramatic',
#   u'pirinski_rio',
#   u'bond_also',
#   u'million_stock',
#   u'market_lost',
#   u'month_debt',
#   u'sold_u',
#   u'25_bond',
#   u'remains_constraint',
#   u'gueorgui_tinto',
#   u'creditsights_research',
#   u'status_warning',
#   u'3_writedown',
#   u'accused_overstating',
#   u'asia_noble',
#   u'talk_asset',
#   u'issue_key',
#   u'engage_energy',
#   u'xs157733877_slumped',
#   u'asian_enough',
#   u'bondholder_asset',
#   u'trading_coal',
#   u'economical_overhaul',
#   u'mine_expanded',
#   u'kong_alex',
#   u'dramatic_wednesday',
#   u'business_heavily',
#   u'sheet_getting',
#   u'business_chris',
#   u'month_reduced',
#   u'return_native',
#   u'last_head',
#   u'nearly_group',
#   u'ax_comment',
#   u'hemmed_financing',
#   u'liquidity_noble',
#   u'said_creditsights',
#   u'noble_large',
#   u'based_analyst',
#   u'exposure_trader',
#   u'liquidity_chunk',
#   u'supply_ship',
#   u'issued_march',
#   u'reuters_si',
#   u'return_rate',
#   u'group_sell',
#   u'peer_248',
#   u'funding_exposure',
#   u'plan_bondholder',
#   u'far_noble',
#   u'know_reporting',
#   u'worth_lot',
#   u'loss_conservative',
#   u'hemmed_trading',
#   u'sheet_debt',
#   u'expertise_theory',
#   u'cent_march',
#   u'kong_ferreira',
#   u'one_arrest',
#   u'analyst_industry',
#   u'le_4',
#   u'balance_getting',
#   u'credit_warning',
#   u'capital_structure',
#   u'percent_le',
#   u'ore_analyst',
#   u'financing_house',
#   u'slimming_asian',
#   u'dramatic_overhaul',
#   u'remaining_october',
#   u'listed_boom',
#   u'sector_virtually',
#   u'noble_steep',
#   u'hole_key',
#   u'decline_steep',
#   u'trading_enough',
#   u'woe_contagion',
#   u'billion_billion',
#   u'2016_steep',
#   u'expertise_noble',
#   u'gueorgui_pirinski',
#   u'commodity_house',
#   u'york_research',
#   u'8_balance',
#   u'storm_trader',
#   u'little_rating',
#   u'si_coal',
#   u'lost_participant',
#   u'25_cent',
#   u'quantitative_left',
#   u'process_sell',
#   u'sold_power',
#   u'immediate_mean',
#   u'essentially_worth',
#   u'risk_absent',
#   u'cash_key',
#   u'recovered_noble',
#   u'chairman_interview',
#   u'deal_market',
#   u'participant_guy',
#   u'bare_noble',
#   u'house_boom',
#   u'modest_economical',
#   u'liquefied_gas',
#   u'drastically_trading',
#   u'mercuria_group',
#   u'engage_said',
#   u'2_meanwhile',
#   u'indonesia_kalimantan',
#   u'guy_easy',
#   u'quantitative_confirmed',
#   u'sale_liquidity',
#   u'248_started',
#   u'major_participant',
#   u'requirement_high',
#   u'company_said',
#   u'mark_bondholder',
#   u'tinto_ax',
#   u'including_ship',
#   u'month_cut',
#   u'bondholder_hand',
#   u'balance_sheet',
#   u'ore_pirinski',
#   u'including_business',
#   u'group_pose',
#   u'devries_based',
#   u'economical_latest',
#   u'york_analyst',
#   u'trader_funding',
#   u'mean_gone',
#   u'noble_chief',
#   u'february_obscure',
#   u'trading_people',
#   u'player_gas',
#   u'asset_noble',
#   u'told_firm',
#   u'loss_balance',
#   u'veteran_exit',
#   u'get_hole',
#   u'company_hemmed',
#   u'one_energy',
#   u'deal_see',
#   u'coal_deal',
#   u'month_physical',
#   u'close_company',
#   u'participant_easy',
#   u'company_latest',
#   u'new_york',
#   u'sheet_analyst',
#   u'stock_representative',
#   u'reuters_back',
#   u'month_despite',
#   u'may_credit',
#   u'business_exit',
#   u'million_10',
#   u'asset_rejected',
#   u'worth_money',
#   u'engage_one',
#   u'staff_risk',
#   u'leading_1',
#   u'also_point',
#   u'junk_expect',
#   u'leading_8',
#   u'high_profile',
#   u'expertise_analyst',
#   u'constraint_lost',
#   u'trader_noble',
#   u'way_earnings',
#   u'trading_worth',
#   u'nobg_si',
#   u'january_2016',
#   u'park_analyst',
#   u'accused_billion',
#   u'pirinski_tinto',
#   u'debt_deadline',
#   u'fell_point',
#   u'market_month',
#   u'ferreira_marque',
#   u'regularly_noble',
#   u'billion_andy',
#   u'relies_analyst',
#   u'hand_immediate',
#   u'1_meanwhile',
#   u'said_based',
#   u'european_rival',
#   u'trading_supply',
#   u'asset_coal',
#   u'key_bone',
#   u'theory_large',
#   u'strategist_singapore',
#   u'49_group',
#   u'participant_month',
#   u'pricewaterhousecoopers_international',
#   u'based_mercuria',
#   u'analyst_moody',
#   u'2020_te',
#   u'sale_immediate',
#   u'remains_financing',
#   u'deadline_lifeline',
#   u'see_participant',
#   u'year_mill',
#   u'global_cut',
#   u'far_back',
#   u'question_debt',
#   u'cite_departure',
#   u'bond_fell',
#   u'sell_plan',
#   u'strategist_last',
#   u'december_recruiter',
#   u'complied_back',
#   u'quit_noble',
#   u'far_slumped',
#   u'quantitative_team',
#   u'iceberg_accused',
#   u'essential_said',
#   u'daga_desai',
#   u'rule_january',
#   u'iceberg_asset',
#   u'oil_liquefied',
#   u'steep_pose',
#   u'red_thrust',
#   u'corporate_status',
#   u'asia_treasury',
#   u'york_independent',
#   u'bare_exit',
#   u'liquid_billion',
#   u'rival_glen',
#   u'latest_mark',
#   u'client_including',
#   u'hand_chunk',
#   u'reuters_noble',
#   u'previously_large',
#   u'rival_dramatic',
#   u'3_sustainable',
#   u'billion_consultant',
#   u'sale_arrest',
#   u'2022_9',
#   u'sheet_billion',
#   u'arrest_crunch',
#   u'reduced_trading',
#   u'complied_rule',
#   u'2015_found',
#   u'devries_creditsights',
#   u'nearly_le',
#   u'woe_appear',
#   u'5_dollar',
#   u'corporate_junk',
#   u'mill_rival',
#   u'35_le',
#   u'asian_coal',
#   u'situation_gloystein',
#   u'globally_glen',
#   u'trading_noble',
#   u'said_park',
#   u'rating_analyst',
#   u'european_2016',
#   u'coal_expanded',
#   u'noble_trading',
#   u'contact_trader',
#   u'group_si',
#   u'exit_debt',
#   u'trader_hole',
#   u'essential_close',
#   u'offer_keep',
#   u'p_global',
#   u'slumped_35',
#   u'slumped_32',
#   u'noble_rejected',
#   u'largely_trading',
#   u'si_core',
#   u'overhaul_percent',
#   u'le_10',
#   u'sugar_coal',
#   u'mill_expanded',
#   u'bank_player',
#   u'debt_source',
#   u'staff_recruiter',
#   u'february_previously',
#   u'bone_red',
#   u'noble_declined',
#   u'noble_aluminum',
#   u'drastically_business',
#   u'slumped_9',
#   u'anshuman_henning',
#   u'ship_kalimantan',
#   u'trader_despite',
#   u'noble_deadline',
#   u'noble_asset',
#   u'share_49',
#   u'umesh_editing',
#   u'essential_investor',
#   u'group_process',
#   u'research_billion',
#   u'expanded_globally',
#   u'trader_get',
#   u'physical_gas',
#   u'treasury_iron',
#   u'due_32',
#   u'pose_contagion',
#   u'used_noble',
#   u'slimming_drastically',
#   u'sad_see',
#   u'lost_trader',
#   u'oil_plan',
#   u'power_peer',
#   u'henning_gloystein',
#   u'due_staff',
#   u'32_9',
#   u'expertise_large',
#   u'2020_bond',
#   u'pose_singapore',
#   u'used_deal',
#   u'natural_iron',
#   u'selling_red',
#   u'steep_woe',
#   u'globally_rival',
#   u'shrunken_3',
#   u'needed_go',
#   u'business_bare',
#   u'3_say',
#   u'woe_pose',
#   u'high_departure',
#   u'fortune_shrunken',
#   u'large_business',
#   u'billion_peak',
#   u'worth_creditsights',
#   u'creditsights_trader',
#   u'business_head',
#   u'metal_natural',
#   u'hong_editing',
#   u'75_iceberg',
#   u'short_issue',
#   u'interview_firm',
#   u'debt_term',
#   u'ship_thermal',
#   u'month_may',
#   u'market_say',
#   u'flagged_billion',
#   u'year_told',
#   u'industry_source',
#   u'noble_market',
#   u'fortune_staff',
#   u'2016_commodity',
#   u'sugar_mill',
#   u'iceberg_facing',
#   u'park_remaining',
#   u'asset_mine',
#   u'noble_bond',
#   u'corporate_rating',
#   u'tinto_rio',
#   u'analyst_rio',
#   u'source_close',
#   u'rule_noble',
#   u'commodity_woe',
#   u'story_commodity',
#   u'customer_thermal',
#   u'easy_daga',
#   u'u_exit',
#   u'talk_hand',
#   u'gas_high',
#   u'gas_coal',
#   u'swiss_group',
#   u'immediate_large',
#   u'staff_cite',
#   u'announced_1',
#   u'kong_marque',
#   u'balance_back',
#   u'le_value',
#   u'noble_trader',
#   u'risk_physical',
#   u'structure_investor',
#   u'comment_trading',
#   u'founder_told',
#   u'confirmed_week',
#   u'credit_status',
#   u'needed_cautious',
#   u'coal_kalimantan',
#   u'trader_cost',
#   u'including_indonesia',
#   u'issued_te',
#   u'joined_ax',
#   u'elman_interview',
#   u'75_told',
#   u'left_year',
#   u'high_engage',
#   u'risk_sector',
#   u'rating_status',
#   u'left_simply',
#   u'announced_u',
#   u'risk_engage',
#   u'nobg_asian',
#   u'expanded_rival',
#   u'umesh_kong',
#   u'dollar_consultant',
#   u'32_25',
#   u'absent_oil',
#   u'key_staff',
#   u'research_grow',
#   u'said_analyst',
#   u'due_slumped',
#   u'expertise_trader',
#   u'heavily_contact',
#   u'sustainable_devries',
#   u'million_started',
#   u'9_55',
#   u'exposure_simply',
#   u'third_4',
#   u'noble_facing',
#   u'back_january',
#   u'l_announced',
#   u'mine_globally',
#   u'lot_reality',
#   u'dollar_pricewaterhousecoopers',
#   u'say_commodity',
#   u'slump_woe',
#   u'ferreira_richardson',
#   u'analyst_joined',
#   u'kong_editing',
#   u'slump_noble',
#   u'l_wednesday',
#   u'55_third',
#   u'slimming_core',
#   u'recruiter_profile',
#   u'interview_back',
#   u'49_valuing',
#   u'march_te',
#   u'obscure_overstating',
#   u'third_p',
#   u'unit_disposal',
#   u'indonesia_asia',
#   u'2020_usg6542tae1',
#   u'major_house',
#   u'bank_agriculture',
#   u'get_2020',
#   u'term_liquidity',
#   u'chunk_said',
#   u'2015_obscure',
#   u'virtually_liquefied',
#   u'house_analyst',
#   u'writedown_quarterly',
#   u'noble_complied',
#   u'te_point',
#   u'native_forex',
#   u'1_conservative',
#   u'back_noble',
#   u'last_key',
#   u'remaining_bone',
#   u'bank_metal',
#   u'group_core',
#   u'debt_liquidity',
#   u'singapore_shadow',
#   u'risk_contagion',
#   u'fell_half',
#   u'2015_accused',
#   u'merchant_glencore',
#   u'lost_past',
#   u'client_bigger',
#   u'hole_bond',
#   u'creditsights_reality',
#   u'rule_far',
#   u'rio_noble',
#   u'noble_include',
#   u'rate_asia',
#   u'loss_1',
#   u'l_overhaul',
#   u'announced_power',
#   u'complied_accounting',
#   u'loss_8',
#   u'reuters_go',
#   u'9_le',
#   u'month_cash',
#   u'requirement_counterparty',
#   u'facing_perfect',
#   u'remaining_debt',
#   u'week_iceland',
#   u'said_constraint',
#   u'energy_trader',
#   u'house_trader',
#   u'debt_billion',
#   u'told_storm',
#   u'relies_trader',
#   u'iron_joined',
#   u'said_reality',
#   u'umesh_desai',
#   u'latest_prelude',
#   u'risk_said',
#   u'situation_henning',
#   u'iceberg_reuters',
#   u'joined_rio',
#   u'theory_trading',
#   u'said_wednesday',
#   u'bondholder_arrest',
#   u'singapore_si',
#   u'joined_tinto',
#   u'month_global',
#   u'analyst_question',
#   u'drastically_coal',
#   u'credit_junk',
#   u'reduce_term',
#   u'month_p',
#   u'u_include',
#   u'clearly_said',
#   u'oil_1',
#   u'large_lot',
#   u'asset_way',
#   u'billion_quarterly',
#   u'mean_chunk',
#   u'previously_agriculture',
#   u'steep_appear',
#   u'75_representative',
#   u'client_merchant',
#   u'u_gas',
#   u'large_core',
#   u'noble_boom',
#   u'team_last',
#   u'conservative_essentially',
#   u'te_9',
#   u'getting_back',
#   u'5_25',
#   u'joined_rival',
#   u'32_5',
#   u'deadline_providing',
#   u'virtually_physical',
#   u'situation_anshuman',
#   u'high_including',
#   u'glen_dramatic',
#   u'business_trader',
#   u'firm_needed',
#   u'offer_recruiter',
#   u'strategist_confirmed',
#   u'meanwhile_billion',
#   u'analyst_oil',
#   u'billion_debt',
#   u'noble_reduced',
#   u'exposure_many',
#   u'wider_contagion',
#   u'large_player',
#   u'still_large',
#   u'noble_spotlight',
#   u'rating_corporate',
#   u'arrest_immediate',
#   u'decline_pose',
#   u'l_trafigura',
#   u'business_said',
#   u'billion_sustainable',
#   u'sale_crunch',
#   u'energy_248',
#   u'back_contract',
#   u'thermal_coal',
#   u'including_rival',
#   u'lot_creditsights',
#   u'rival_2015',
#   u'rival_2016',
#   u'counterparties_cutting',
#   u'noble_previously',
#   u'noble_talk',
#   u'immediate_hand',
#   u'analyst_expect',
#   u'latest_share',
#   u'devries_reality',
#   u'including_recovered',
#   u'lot_devries',
#   u'agriculture_gas',
#   u'glencore_slump',
#   u'asset_liquidity',
#   u'asset_sale',
#   u'january_chairman',
#   u'independent_way',
#   u'based_independent',
#   u'providing_said',
#   u'economical_wednesday',
#   u'bond_due',
#   u'remaining_noble',
#   u'still_previously',
#   u'noble_u',
#   u'departure_including',
#   u'possible_get',
#   u'next_flagged',
#   u'fortune_balance',
#   u'moody_remaining',
#   u'iceberg_perfect',
#   u'declined_trading',
#   u'gone_analyst',
#   u'departure_u',
#   u'next_1',
#   u'analyst_mark',
#   u'company_wednesday',
#   u'say_noble',
#   u'32_third',
#   u'investor_hemmed',
#   u'overhaul_gas',
#   u'manager_despite',
#   u'oil_unit',
#   u'million_process',
#   u'2022_xs157733877',
#   u'story_trading',
#   u'short_liquidity',
#   u'drastically_core',
#   u'started_liquid',
#   u'core_park',
#   u'latest_talk',
#   u'investor_remains',
#   u'financing_issue',
#   u'billion_two',
#   u'getting_worth',
#   u'regularly_market',
#   u'plan_next',
#   u'noble_international',
#   u'elman_needed',
#   u'business_mercuria',
#   u'contagion_oil',
#   u'sold_business',
#   u'constraint_major',
#   u'clara_alex',
#   u'36_latest',
#   u'guy_situation',
#   u'largely_physical',
#   u'billion_balance',
#   u'ship_indonesia',
#   u'based_research',
#   u'noble_gueorgui',
#   u'energy_million',
#   u'many_possible',
#   u'providing_still',
#   u'absent_gas',
#   u'strategist_team',
#   u'natural_ore',
#   u'talk_bondholder',
#   u'revive_exodus',
#   u'default_analyst',
#   u'creditsights_devries',
#   u'staff_high',
#   u'lost_easy',
#   u'capital_company',
#   u'ore_joined',
#   u'york_creditsights',
#   u'structure_source',
#   u'revive_fortune',
#   u'veteran_business',
#   u'noble_lost',
#   u'key_high',
#   u'noble_si',
#   u'selling_noble',
#   u'noble_shadow',
#   u'trader_remaining',
#   u'may_cut',
#   u'worth_2',
#   u'le_million',
#   u'worth_1',
#   u'told_interview',
#   u'head_quantitative',
#   u'regularly_see',
#   u'gloystein_singapore',
#   u'iron_ore',
#   u'noble_staff',
#   u'based_firm',
#   u'swiss_based',
#   u'counterparty_u',
#   u'large_worth',
#   u'te_trading',
#   u'manager_past',
#   u'iron_coal',
#   u'profile_noble',
#   u'stock_percent',
#   u'sad_participant',
#   u'due_te',
#   u'commodity_people',
#   u'question_even',
#   u'said_talking',
#   u'possible_2020',
#   u'source_said',
#   u'sold_swiss',
#   u'immediate_crunch',
#   u'l_dramatic',
#   u'devries_lost',
#   u'recruiter_including',
#   u'gas_peer',
#   u'forex_left',
#   u'shadow_asset',
#   u'decline_wider',
#   u'3_said',
#   u'plan_1',
#   u'reuters_needed',
#   u'player_oil',
#   u'reporting_henning',
#   u'core_chris',
#   u'trader_deal',
#   u'nobg_core',
#   u'company_investor',
#   u'january_noble',
#   u'company_talking',
#   u'physical_customer',
#   u'two_also',
#   u'left_get',
#   u'service_even',
#   u'key_also',
#   u'little_p',
#   u'singapore_listed',
#   u'u_aluminum',
#   u'trading_may',
#   u'group_risk',
#   u'capital_engage',
#   u'easy_henning',
#   u'bondholder_one',
#   u'asia_european',
#   u'rating_junk',
#   u'1_two',
#   u'32_35',
#   u'dollar_march',
#   u'including_european',
#   u'andy_based',
#   u'business_include',
#   u'noble_year',
#   u'commodity_slump',
#   u'2015_complied',
#   u'gone_said',
#   u'even_short',
#   u'little_4',
#   u'industry_asia',
#   u'risk_u',
#   u'5_36',
#   u'boom_asset',
#   u'told_go',
#   u'accused_noble',
#   u'said_bank',
#   u'coal_may',
#   u'prelude_asset',
#   u'pose_sector',
#   u'25_issued',
#   u'liquid_announced',
#   u'participant_reporting',
#   u'house_singapore',
#   u'told_perfect',
#   u'creditsights_independent',
#   u'said_devries',
#   u'billion_source',
#   u'trading_lot',
#   u'hand_asset',
#   u'asset_mill',
#   u'high_risk',
#   u'sad_major',
#   u'rule_back',
#   u'1_writedown',
#   u'service_debt',
#   u'richard_elman',
#   u'reporting_anshuman',
#   u'park_question',
#   u'anshuman_daga',
#   u'company_nearly',
#   u'quit_analyst',
#   u'boom_snapped',
#   u'appear_risk',
#   u'noble_key',
#   u'hole_usg6542tae1',
#   u'noble_richard',
#   u'spotlight_obscure',
#   u'native_rate',
#   u'point_32',
#   u'noble_mark',
#   u'point_36',
#   u'found_rule',
#   u'sugar_mine',
#   u'cautious_company',
#   u'contract_thermal',
#   u'nearly_percent',
#   u'trader_past',
#   u'many_simply',
#   u'globally_l',
#   u'rival_tinto',
#   u'told_noble',
#   u'noble_credit',
#   u'singapore_umesh',
#   u'back_wednesday',
#   u'exodus_debt',
#   u'liquefied_natural',
#   u'chairman_richard',
#   u'bond_march',
#   u'devries_business',
#   u'u_business',
#   u'money_reality',
#   u'arrest_hand',
#   u'trading_shadow',
#   u'noble_decline',
#   u'core_may',
#   u'based_energy',
#   u'slid_valuing',
#   u'company_still',
#   u'key_te',
#   u'chunk_gone',
#   u'based_peer',
#   u'month_deadline',
#   u'noble_oil',
#   u'coal_customer',
#   u'75_year',
#   u'exposure_possible',
#   u'creditsights_key',
#   u'may_declined',
#   u'trader_analyst',
#   u'extended_key',
#   u'ship_client',
#   u'group_started',
#   u'used_see',
#   u'native_iceland',
#   u'corporate_warning',
#   u'year_reuters',
#   u'founder_reuters',
#   u'arrest_mean',
#   u'mark_prelude',
#   u'20_wednesday',
#   u'trader_prohibitive',
#   u'may_fortune',
#   u'sustainable_said',
#   u'billion_said',
#   u'dollar_rejected',
#   u'sad_market',
#   u'said_regularly',
#   u'way_capital',
#   u'energy_group',
#   u'le_400',
#   u'group_exit',
#   u'wednesday_u',
#   u'high_high',
#   u'used_regularly',
#   u'cutting_left',
#   u'back_chairman',
#   u'said_remains',
#   u'cash_december',
#   u'junk_status',
#   u'snapped_coal',
#   u'valuing_group',
#   u'gueorgui_joined',
#   u'singapore_editing',
#   u'spotlight_february',
#   u'modest_cautious',
#   u'noble_founder',
#   u'4_global',
#   u'also_trading',
#   u'group_le',
#   u'liquidity_large',
#   u'singapore_iceland',
#   u'january_founder',
#   u'natural_gas',
#   u'woe_risk',
#   u'back_company',
#   u'said_trader',
#   u'kong_clara',
#   u'counterparty_said',
#   u'boom_mill',
#   u'process_unit',
#   u'month_rating',
#   u'warning_default',
#   u'singapore_boom',
#   u'slid_percent',
#   u'10_75',
#   u'major_issue',
#   u'creditsights_firm',
#   u'contract_ship',
#   u'ax_may',
#   u'hemmed_issue',
#   u'reality_lost',
#   u'contract_book',
#   u'listed_shadow',
#   u'left_possible',
#   u'wednesday_slid',
#   u'le_billion',
#   u'trader_manager',
#   u'bone_selling',
#   u'listed_year',
#   u'debt_20',
#   u'noble_latest',
#   u'coal_noble',
#   u'2016_decline',
#   u'thermal_indonesia',
#   u'said_used',
#   u'lost_many',
#   u'noble_corporate',
#   u'recovered_slump',
#   u'people_expertise',
#   u'virtually_absent',
#   u'35_55',
#   u'sustainable_andy',
#   u'simply_get',
#   u'business_financing',
#   u'noble_month',
#   u'singapore_week',
#   u'firm_back',
#   u'selling_remaining',
#   u'new_analyst',
#   u'mill_coal',
#   u'issued_2022',
#   u'cutting_many',
#   u'singapore_return',
#   u'issue_lost',
#   u'trader_theory',
#   u'share_slid',
#   u'hong_kong',
#   u'requirement_risk',
#   u'worth_devries',
#   u'billion_next',
#   u'2015_previously',
#   u'year_snapped',
#   u'plan_billion',
#   u'need_structure',
#   u'appear_wider',
#   ...]]

# %%
full_content = gram_12

# %%
# remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)
for text in full_content:
    for token in text:
        if not token.isdigit():
            frequency[token] += 1

full_content = [[token for token in text if frequency[token] > 1] for text in full_content]
print full_content[:2]
# Out:
# [[u'said_institute', u'billion_deal', u'said_1', u'said_4', u'u_selling', u'capital_investment', u'7_million', u'0_8', u'capital_management', u'3_billion', u'inc_friday', u'percent_percent', u'5_since', u'1_stake', u'post_co', u'nikkei_0', u'real_holding', u'6_percent', u'said_5', u'share_3', u'capital_currently', u'estate_reuters', u'since_2015', u'statement_5', u'company_nomura', u'japan_said', u'1_5', u'deal_would', u'buying_stake', u'hold_percent', u'talk_co', u'largest_bank', u'share_4', u'chief_financial', u'co_capital', u'profit_yen', u'july_period', u'japan_buying', u'closed_5', u'fell_percent', u'closed_1', u'planned_billion', u'holding_source', u'highest_2015', u'million_generate', u'stake_editing', u'6_stake', u'booked_said', u'stake_venture', u'seek_see', u'firm_seek', u'share_sold', u'million_stake', u'chief_told', u'8_million', u'said_post', u'stake_respectively', u'would_5', u'would_9', u'june_said', u'sell_holding', u'share_18', u'inc_share', u'inc_said', u'tender_share', u'firm_reuters', u'expanding_business', u'source_told', u'buying_share', u'highest_since', u'buying_two', u'nikkei_n225', u'longer_sale', u'sell_real', u'inc_sold', u'july_said', u'21_million', u'source_june', u'million_statement', u'share_buying', u'8_share', u'hold_2', u'buying_13', u'told_june', u'48_share', u'brokerage_said', u'1_ended', u'share_17', u'holding_sell', u'stake_estate', u'billion_yen', u'holding_japan', u'source_deal', u'respectively_reporting', u'period_said', u'japan_investment', u'u_stake', u'80_million', u'financial_told', u'holding_inc', u'1_percent', u'co_venture', u'per_7', u'million_september', u'6_4', u'reporting_thomas', u'million_research', u'6_8', u'sell_firm', u'real_said', u'stake_company', u'million_may', u'5_percent', u'9_billion', u'bank_said', u'stake_chief', u'560_per', u'estate_holding', u'business_selling', u'largest_may', u'editing_edmund', u'closed_percent', u'48_6', u'million_17', u'percent_650', u'34_1', u'reuters_deal', u'13_million', u'nomura_japan', u'buying_sale', u'u_business', u'34_percent', u'37_percent', u'stake_group', u'resource_said', u'co_sell', u'share_stake', u'million_said', u'adding_share', u'5_1', u'seek_capital', u'2015_index', u'million_july', u'reporting_jacqueline', u'firm_tokyo', u'sold_8', u'5_share', u'generate_billion', u'billion_said', u'largest_said', u'percent_1', u'percent_5', u'percent_8', u'reuters_june', u'source_reuters', u'investment_said', u'thomas_editing', u'percent_yen', u'post_holding', u'34_2', u'planned_18', u'benchmark_nikkei', u'holding_estate', u'165_million', u'may_talk', u'see_growth', u'4_per', u'billion_5', u'index_6', u'buying_million', u'would_million', u'back_firm', u'group_company', u'group_real', u'million_deal', u'said_capital', u'would_profit', u'may_use', u'share_1', u'share_7', u'share_6', u'share_5', u'japanese_seek', u'million_two', u'selling_stake', u'japan_brokerage', u'business_would', u'use_capital', u'share_co', u'index_0', u'shift_growth', u'stake_co', u'said_closed', u'reporting_editing', u'business_contribute', u'enhance_management', u'firm_japanese', u'would_share', u'japan_sell', u'nomura_inc', u'2_4', u'area_growth', u'percent_37', u'longer_stake', u'stake_back', u'1_15', u'percent_sold', u'would_capital', u'co_group', u'reuters_said', u'stake_financial', u'inc_8604', u'investment_bank', u'profit_80', u'japanese_capital', u'1_yen', u'bank_may', u'two_billion', u'reuters_holding', u'percent_share', u'4_billion', u'stake_4', u'sell_group', u'co_firm', u'share_billion', u'group_estate', u'said_million', u'bank_capital', u'investment_selling', u'capital_reuters', u'yen_deal', u'billion_9', u'said_longer', u'said_may', u'per_billion', u'holding_stake', u'nikkei_index', u'share_two', u'billion_million', u'company_holding', u'would_drive', u'said_sold', u'fell_6', u'chief_officer', u'book_yen', u'share_closed', u'million_booked', u'stake_41', u'tokyo_inc', u'told_conference', u'1_1', u'percent_stake', u'may_capital', u'sale_financial', u'4 ...

# %%
dictionary = gensim.corpora.Dictionary(full_content)
dictionary.save('model/contents.dict')
print dictionary
# Out:
# 2017-07-29 14:04:29,854 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-07-29 14:04:30,241 : INFO : built Dictionary(70027 unique tokens: [u'year_hathaway', u'trade_1', u'major_acquisition', u'conference_wednesday', u'peer_12']...) from 545 documents (total 225063 corpus positions)
# 2017-07-29 14:04:30,242 : INFO : saving Dictionary object under model/contents.dict, separately None
# 2017-07-29 14:04:30,392 : INFO : saved model/contents.dict
# Dictionary(70027 unique tokens: [u'year_hathaway', u'trade_1', u'major_acquisition', u'conference_wednesday', u'peer_12']...)

# %%
corpus = [dictionary.doc2bow(text) for text in full_content]
gensim.corpora.MmCorpus.serialize('model/contents.mm', corpus)
# Out:
# 2017-07-29 14:04:30,732 : INFO : storing corpus in Matrix Market format to model/contents.mm
# 2017-07-29 14:04:30,734 : INFO : saving sparse matrix to model/contents.mm
# 2017-07-29 14:04:30,735 : INFO : PROGRESS: saving document #0
# 2017-07-29 14:04:31,347 : INFO : saved 545x70027 matrix, density=0.590% (225063/38164715)
# 2017-07-29 14:04:31,348 : INFO : saving MmCorpus index to model/contents.mm.index

# %% [markdown]
# # LDA

# %%
# Config 
NUM_TOPICS = 10
NUM_TERMS = 100

# %%
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, 
                                      num_topics=NUM_TOPICS, update_every=5, 
                                      chunksize=10000, passes=4)

lda.save('model/lda.save')
# Out:
# 2017-07-29 14:04:31,368 : INFO : using symmetric alpha at 0.1
# 2017-07-29 14:04:31,369 : INFO : using symmetric eta at 1.42802062062e-05
# 2017-07-29 14:04:31,377 : INFO : using serial LDA version on this node
# 2017-07-29 14:04:37,937 : INFO : running online LDA training, 10 topics, 4 passes over the supplied corpus of 545 documents, updating model once every 545 documents, evaluating perplexity every 545 documents, iterating 50x with a convergence threshold of 0.001000
# 2017-07-29 14:04:37,937 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2017-07-29 14:04:54,208 : INFO : -15.217 per-word bound, 38086.4 perplexity estimate based on a held-out corpus of 545 documents with 225063 words
# 2017-07-29 14:04:54,209 : INFO : PROGRESS: pass 0, at document #545/545
# 2017-07-29 14:04:56,373 : INFO : topic #2 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"1_billion" + 0.000*"billion_billion" + 0.000*"declined_comment" + 0.000*"3_billion" + 0.000*"source_said" + 0.000*"5_billion" + 0.000*"last_year" + 0.000*"source_reuters"
# 2017-07-29 14:04:56,374 : INFO : topic #5 (0.100): 0.001*"reporting_editing" + 0.001*"declined_comment" + 0.001*"1_billion" + 0.001*"source_reuters" + 0.000*"said_would" + 0.000*"source_said" + 0.000*"chief_executive" + 0.000*"billion_billion" + 0.000*"last_year" + 0.000*"company_said"
# 2017-07-29 14:04:56,376 : INFO : topic #0 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"2_billion" + 0.001*"company_said" + 0.000*"billion_billion" + 0.000*"source_said" + 0.000*"private_equity" + 0.000*"source_reuters" + 0.000*"declined_comment"
# 2017-07-29 14:04:56,377 : INFO : topic #9 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"source_reuters" + 0.000*"last_year" + 0.000*"chief_executive" + 0.000*"2_billion" + 0.000*"1_billion" + 0.000*"billion_billion" + 0.000*"additional_reporting"
# 2017-07-29 14:04:56,378 : INFO : topic #7 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"1_billion" + 0.001*"source_reuters" + 0.000*"source_said" + 0.000*"billion_billion" + 0.000*"million_million" + 0.000*"private_equity" + 0.000*"last_year"
# 2017-07-29 14:04:56,380 : INFO : topic diff=1.844572, rho=1.000000
# 2017-07-29 14:05:03,886 : INFO : -13.369 per-word bound, 10579.4 perplexity estimate based on a held-out corpus of 545 documents with 225063 words
# 2017-07-29 14:05:03,886 : INFO : PROGRESS: pass 1, at document #545/545
# 2017-07-29 14:05:06,667 : INFO : topic #6 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"new_york" + 0.001*"percent_stake" + 0.000*"company_said" + 0.000*"billion_billion" + 0.000*"declined_comment" + 0.000*"share_percent" + 0.000*"chief_executive"
# 2017-07-29 14:05:06,669 : INFO : topic #9 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"last_year" + 0.001*"billion_billion" + 0.001*"source_reuters" + 0.001*"declined_comment" + 0.000*"2_billion" + 0.000*"additional_reporting" + 0.000*"chief_executive" + 0.000*"said_statement"
# 2017-07-29 14:05:06,670 : INFO : topic #5 (0.100): 0.001*"reporting_editing" + 0.001*"declined_comment" + 0.001*"1_billion" + 0.001*"source_reuters" + 0.001*"source_said" + 0.001*"last_year" + 0.001*"said_would" + 0.000*"familiar_matter" + 0.000*"chief_executive" + 0.000*"private_equity"
# 2017-07-29 14:05:06,671 : INFO : topic #1 (0.100): 0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"chief_executive" + 0.001*"declined_comment" + 0.001*"said_would" + 0.001*"new_york" + 0.000*"additional_reporting" + 0.000*"2_billion" + 0.000*"company_said" + 0.000*"private_equity"
# 2017-07-29 14:05:06,672 : INFO : topic #3 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"company_said" + 0.000*"billion_billion" + 0.000*"chief_executive" + 0.000*"1_billion" + 0.000*"last_year" + 0.000*"million_million" + 0.000*"3_billion" + 0.000*"said_deal"
# 2017-07-29 14:05:06,674 : INFO : topic diff=1.659017, rho=0.577350
# 2017-07-29 14:05:14,614 : INFO : -12.145 per-word bound, 4528.6 perplexity estimate based on a held-out corpus of 545 documents with 225063 words
# 2017-07-29 14:05:14,615 : INFO : PROGRESS: pass 2, at document #545/545
# 2017-07-29 14:05:17,692 : INFO : topic #0 (0.100): 0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"said_would" + 0.001*"company_said" + 0.001*"source_said" + 0.001*"2_billion" + 0.000*"declined_comment" + 0.000*"chief_executive" + 0.000*"said_company" + 0.000*"new_york"
# 2017-07-29 14:05:17,693 : INFO : topic #8 (0.100): 0.001*"reporting_editing" + 0.001*"company_said" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"last_year" + 0.000*"million_million" + 0.000*"2_billion" + 0.000*"chief_executive" + 0.000*"said_deal" + 0.000*"additional_reporting"
# 2017-07-29 14:05:17,695 : INFO : topic #1 (0.100): 0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"chief_executive" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"new_york" + 0.000*"2_billion" + 0.000*"company_said" + 0.000*"additional_reporting" + 0.000*"billion_billion"
# 2017-07-29 14:05:17,696 : INFO : topic #6 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"percent_stake" + 0.001*"1_billion" + 0.001*"new_york" + 0.000*"declined_comment" + 0.000*"company_said" + 0.000*"billion_billion" + 0.000*"share_percent" + 0.000*"3_billion"
# 2017-07-29 14:05:17,697 : INFO : topic #2 (0.100): 0.001*"reporting_editing" + 0.001*"billion_billion" + 0.001*"1_billion" + 0.001*"declined_comment" + 0.001*"source_reuters" + 0.001*"3_billion" + 0.000*"5_billion" + 0.000*"additional_reporting" + 0.000*"last_year" + 0.000*"source_said"
# 2017-07-29 14:05:17,699 : INFO : topic diff=1.254345, rho=0.500000
# 2017-07-29 14:05:25,712 : INFO : -11.717 per-word bound, 3367.6 perplexity estimate based on a held-out corpus of 545 documents with 225063 words
# 2017-07-29 14:05:25,713 : INFO : PROGRESS: pass 3, at document #545/545
# 2017-07-29 14:05:29,846 : INFO : topic #8 (0.100): 0.001*"reporting_editing" + 0.001*"company_said" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"million_million" + 0.001*"2_billion" + 0.000*"last_year" + 0.000*"said_deal" + 0.000*"additional_reporting" + 0.000*"chief_executive"
# 2017-07-29 14:05:29,847 : INFO : topic #7 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"private_equity" + 0.001*"source_reuters" + 0.001*"source_said" + 0.001*"million_euro" + 0.001*"million_million" + 0.001*"said_statement" + 0.000*"1_billion"
# 2017-07-29 14:05:29,848 : INFO : topic #9 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"billion_billion" + 0.001*"last_year" + 0.001*"source_reuters" + 0.001*"declined_comment" + 0.000*"additional_reporting" + 0.000*"2_billion" + 0.000*"company_said" + 0.000*"said_statement"
# 2017-07-29 14:05:29,849 : INFO : topic #0 (0.100): 0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"said_would" + 0.001*"source_said" + 0.001*"company_said" + 0.001*"2_billion" + 0.000*"declined_comment" + 0.000*"said_company" + 0.000*"chief_executive" + 0.000*"new_york"
# 2017-07-29 14:05:29,851 : INFO : topic #6 (0.100): 0.001*"reporting_editing" + 0.001*"said_would" + 0.001*"percent_stake" + 0.001*"1_billion" + 0.001*"new_york" + 0.000*"declined_comment" + 0.000*"company_said" + 0.000*"share_percent" + 0.000*"7_billion" + 0.000*"billion_billion"
# 2017-07-29 14:05:29,852 : INFO : topic diff=0.883583, rho=0.447214
# 2017-07-29 14:05:29,906 : INFO : saving LdaState object under model/lda.save.state, separately None
# 2017-07-29 14:05:29,913 : INFO : saved model/lda.save.state
# 2017-07-29 14:05:30,032 : INFO : saving LdaModel object under model/lda.save, separately ['expElogbeta', 'sstats']
# 2017-07-29 14:05:30,033 : INFO : not storing attribute id2word
# 2017-07-29 14:05:30,033 : INFO : storing np array 'expElogbeta' to model/lda.save.expElogbeta.npy
# 2017-07-29 14:05:30,040 : INFO : not storing attribute state
# 2017-07-29 14:05:30,041 : INFO : not storing attribute dispatcher
# 2017-07-29 14:05:30,042 : INFO : saved model/lda.save

# %%
lda.print_topics(2, 100)
# Out:
# 2017-07-29 14:05:30,048 : INFO : topic #8 (0.100): 0.001*"reporting_editing" + 0.001*"company_said" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"million_million" + 0.001*"2_billion" + 0.000*"last_year" + 0.000*"said_deal" + 0.000*"additional_reporting" + 0.000*"chief_executive" + 0.000*"billion_billion" + 0.000*"percent_share" + 0.000*"reporting_bengaluru" + 0.000*"new_york" + 0.000*"declined_comment" + 0.000*"1_1" + 0.000*"told_reuters" + 0.000*"3_billion" + 0.000*"bengaluru_editing" + 0.000*"percent_stake" + 0.000*"million_euro" + 0.000*"percent_percent" + 0.000*"4_billion" + 0.000*"share_percent" + 0.000*"said_wednesday" + 0.000*"said_reporting" + 0.000*"said_expected" + 0.000*"said_statement" + 0.000*"euro_million" + 0.000*"billion_year" + 0.000*"said_buy" + 0.000*"said_thursday" + 0.000*"would_buy" + 0.000*"united_state" + 0.000*"8_billion" + 0.000*"source_reuters" + 0.000*"3_percent" + 0.000*"said_company" + 0.000*"two_said" + 0.000*"deal_said" + 0.000*"last_month" + 0.000*"5_billion" + 0.000*"deal_reuters" + 0.000*"chief_said" + 0.000*"million_said" + 0.000*"month_said" + 0.000*"investment_bank" + 0.000*"5_percent" + 0.000*"said_monday" + 0.000*"private_equity" + 0.000*"paris_reuters" + 0.000*"people_said" + 0.000*"deal_could" + 0.000*"said_price" + 0.000*"group_would" + 0.000*"source_said" + 0.000*"billion_said" + 0.000*"percent_year" + 0.000*"billion_1" + 0.000*"deal_year" + 0.000*"1_year" + 0.000*"million_reuters" + 0.000*"said_firm" + 0.000*"said_business" + 0.000*"cash_share" + 0.000*"executive_said" + 0.000*"two_year" + 0.000*"6_billion" + 0.000*"reporting_additional" + 0.000*"7_billion" + 0.000*"9_percent" + 0.000*"sale_deal" + 0.000*"initial_offering" + 0.000*"said_comment" + 0.000*"reporting_john" + 0.000*"first_half" + 0.000*"said_adding" + 0.000*"million_company" + 0.000*"deal_company" + 0.000*"deal_announced" + 0.000*"next_year" + 0.000*"deal_reporting" + 0.000*"respond_comment" + 0.000*"shareholder_vote" + 0.000*"also_said" + 0.000*"5_million" + 0.000*"thomson_reuters" + 0.000*"people_familiar" + 0.000*"deal_sell" + 0.000*"percent_said" + 0.000*"co_n" + 0.000*"said_head" + 0.000*"sell_stake" + 0.000*"said_also" + 0.000*"private_firm" + 0.000*"c_4" + 0.000*"million_2016" + 0.000*"company_month" + 0.000*"year_said" + 0.000*"25_percent"
# 2017-07-29 14:05:30,050 : INFO : topic #1 (0.100): 0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"chief_executive" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"new_york" + 0.000*"company_said" + 0.000*"2_billion" + 0.000*"additional_reporting" + 0.000*"billion_billion" + 0.000*"private_equity" + 0.000*"3_billion" + 0.000*"5_billion" + 0.000*"percent_stake" + 0.000*"equity_firm" + 0.000*"told_reuters" + 0.000*"deal_said" + 0.000*"private_firm" + 0.000*"source_reuters" + 0.000*"7_billion" + 0.000*"executive_said" + 0.000*"matter_said" + 0.000*"familiar_matter" + 0.000*"chief_officer" + 0.000*"share_percent" + 0.000*"deal_reuters" + 0.000*"immediately_comment" + 0.000*"people_matter" + 0.000*"said_friday" + 0.000*"billion_1" + 0.000*"last_year" + 0.000*"said_thursday" + 0.000*"said_company" + 0.000*"familiar_said" + 0.000*"1_2" + 0.000*"market_said" + 0.000*"4_billion" + 0.000*"source_said" + 0.000*"million_million" + 0.000*"said_could" + 0.000*"deal_would" + 0.000*"said_bid" + 0.000*"1_1" + 0.000*"business_said" + 0.000*"writing_editing" + 0.000*"request_comment" + 0.000*"said_deal" + 0.000*"worth_1" + 0.000*"chief_said" + 0.000*"last_month" + 0.000*"worth_billion" + 0.000*"new_editing" + 0.000*"two_year" + 0.000*"york_editing" + 0.000*"united_state" + 0.000*"4_percent" + 0.000*"million_reuters" + 0.000*"8_billion" + 0.000*"6_billion" + 0.000*"billion_euro" + 0.000*"euro_billion" + 0.000*"inc_n" + 0.000*"said_said" + 0.000*"said_june" + 0.000*"deal_could" + 0.000*"said_share" + 0.000*"comment_said" + 0.000*"billion_deal" + 0.000*"comment_comment" + 0.000*"said_statement" + 0.000*"people_said" + 0.000*"1_3" + 0.000*"analyst_said" + 0.000*"said_comment" + 0.000*"company_deal" + 0.000*"reuters_bank" + 0.000*"1_percent" + 0.000*"reporting_writing" + 0.000*"respond_request" + 0.000*"8_percent" + 0.000*"milan_reuters" + 0.000*"source_matter" + 0.000*"respond_comment" + 0.000*"said_million" + 0.000*"one_source" + 0.000*"1_euro" + 0.000*"reuters_reported" + 0.000*"joint_venture" + 0.000*"5_percent" + 0.000*"would_deal" + 0.000*"executive_officer" + 0.000*"million_euro" + 0.000*"said_buy" + 0.000*"deal_source" + 0.000*"billion_including" + 0.000*"bengaluru_editing" + 0.000*"million_said" + 0.000*"people_familiar" + 0.000*"per_share" + 0.000*"also_said"
# [(8,
#   u'0.001*"reporting_editing" + 0.001*"company_said" + 0.001*"said_would" + 0.001*"1_billion" + 0.001*"million_million" + 0.001*"2_billion" + 0.000*"last_year" + 0.000*"said_deal" + 0.000*"additional_reporting" + 0.000*"chief_executive" + 0.000*"billion_billion" + 0.000*"percent_share" + 0.000*"reporting_bengaluru" + 0.000*"new_york" + 0.000*"declined_comment" + 0.000*"1_1" + 0.000*"told_reuters" + 0.000*"3_billion" + 0.000*"bengaluru_editing" + 0.000*"percent_stake" + 0.000*"million_euro" + 0.000*"percent_percent" + 0.000*"4_billion" + 0.000*"share_percent" + 0.000*"said_wednesday" + 0.000*"said_reporting" + 0.000*"said_expected" + 0.000*"said_statement" + 0.000*"euro_million" + 0.000*"billion_year" + 0.000*"said_buy" + 0.000*"said_thursday" + 0.000*"would_buy" + 0.000*"united_state" + 0.000*"8_billion" + 0.000*"source_reuters" + 0.000*"3_percent" + 0.000*"said_company" + 0.000*"two_said" + 0.000*"deal_said" + 0.000*"last_month" + 0.000*"5_billion" + 0.000*"deal_reuters" + 0.000*"chief_said" + 0.000*"million_said" + 0.000*"month_said" + 0.000*"investment_bank" + 0.000*"5_percent" + 0.000*"said_monday" + 0.000*"private_equity" + 0.000*"paris_reuters" + 0.000*"people_said" + 0.000*"deal_could" + 0.000*"said_price" + 0.000*"group_would" + 0.000*"source_said" + 0.000*"billion_said" + 0.000*"percent_year" + 0.000*"billion_1" + 0.000*"deal_year" + 0.000*"1_year" + 0.000*"million_reuters" + 0.000*"said_firm" + 0.000*"said_business" + 0.000*"cash_share" + 0.000*"executive_said" + 0.000*"two_year" + 0.000*"6_billion" + 0.000*"reporting_additional" + 0.000*"7_billion" + 0.000*"9_percent" + 0.000*"sale_deal" + 0.000*"initial_offering" + 0.000*"said_comment" + 0.000*"reporting_john" + 0.000*"first_half" + 0.000*"said_adding" + 0.000*"million_company" + 0.000*"deal_company" + 0.000*"deal_announced" + 0.000*"next_year" + 0.000*"deal_reporting" + 0.000*"respond_comment" + 0.000*"shareholder_vote" + 0.000*"also_said" + 0.000*"5_million" + 0.000*"thomson_reuters" + 0.000*"people_familiar" + 0.000*"deal_sell" + 0.000*"percent_said" + 0.000*"co_n" + 0.000*"said_head" + 0.000*"sell_stake" + 0.000*"said_also" + 0.000*"private_firm" + 0.000*"c_4" + 0.000*"million_2016" + 0.000*"company_month" + 0.000*"year_said" + 0.000*"25_percent"'),
#  (1,
#   u'0.001*"reporting_editing" + 0.001*"1_billion" + 0.001*"chief_executive" + 0.001*"said_would" + 0.001*"declined_comment" + 0.001*"new_york" + 0.000*"company_said" + 0.000*"2_billion" + 0.000*"additional_reporting" + 0.000*"billion_billion" + 0.000*"private_equity" + 0.000*"3_billion" + 0.000*"5_billion" + 0.000*"percent_stake" + 0.000*"equity_firm" + 0.000*"told_reuters" + 0.000*"deal_said" + 0.000*"private_firm" + 0.000*"source_reuters" + 0.000*"7_billion" + 0.000*"executive_said" + 0.000*"matter_said" + 0.000*"familiar_matter" + 0.000*"chief_officer" + 0.000*"share_percent" + 0.000*"deal_reuters" + 0.000*"immediately_comment" + 0.000*"people_matter" + 0.000*"said_friday" + 0.000*"billion_1" + 0.000*"last_year" + 0.000*"said_thursday" + 0.000*"said_company" + 0.000*"familiar_said" + 0.000*"1_2" + 0.000*"market_said" + 0.000*"4_billion" + 0.000*"source_said" + 0.000*"million_million" + 0.000*"said_could" + 0.000*"deal_would" + 0.000*"said_bid" + 0.000*"1_1" + 0.000*"business_said" + 0.000*"writing_editing" + 0.000*"request_comment" + 0.000*"said_deal" + 0.000*"worth_1" + 0.000*"chief_said" + 0.000*"last_month" + 0.000*"worth_billion" + 0.000*"new_editing" + 0.000*"two_year" + 0.000*"york_editing" + 0.000*"united_state" + 0.000*"4_percent" + 0.000*"million_reuters" + 0.000*"8_billion" + 0.000*"6_billion" + 0.000*"billion_euro" + 0.000*"euro_billion" + 0.000*"inc_n" + 0.000*"said_said" + 0.000*"said_june" + 0.000*"deal_could" + 0.000*"said_share" + 0.000*"comment_said" + 0.000*"billion_deal" + 0.000*"comment_comment" + 0.000*"said_statement" + 0.000*"people_said" + 0.000*"1_3" + 0.000*"analyst_said" + 0.000*"said_comment" + 0.000*"company_deal" + 0.000*"reuters_bank" + 0.000*"1_percent" + 0.000*"reporting_writing" + 0.000*"respond_request" + 0.000*"8_percent" + 0.000*"milan_reuters" + 0.000*"source_matter" + 0.000*"respond_comment" + 0.000*"said_million" + 0.000*"one_source" + 0.000*"1_euro" + 0.000*"reuters_reported" + 0.000*"joint_venture" + 0.000*"5_percent" + 0.000*"would_deal" + 0.000*"executive_officer" + 0.000*"million_euro" + 0.000*"said_buy" + 0.000*"deal_source" + 0.000*"billion_including" + 0.000*"bengaluru_editing" + 0.000*"million_said" + 0.000*"people_familiar" + 0.000*"per_share" + 0.000*"also_said"')]

# %%
# select top 100 words for each of the 10 LDA topics
TOP_KEYWORDS = [[word for word, _ in lda.show_topic(topicno, topn=NUM_TERMS)]
             for topicno in range(lda.num_topics)]
print(TOP_KEYWORDS[:3])
# Out:
# [[u'reporting_editing', u'1_billion', u'said_would', u'source_said', u'company_said', u'2_billion', u'declined_comment', u'said_company', u'chief_executive', u'new_york', u'3_billion', u'private_equity', u'billion_billion', u'last_year', u'source_reuters', u'hong_kong', u'said_statement', u'said_deal', u'last_month', u'private_firm', u'5_billion', u'equity_firm', u'matter_said', u'executive_said', u'additional_reporting', u'share_percent', u'million_million', u'familiar_matter', u'chief_said', u'4_billion', u'familiar_said', u'value_billion', u'said_could', u'hong_reuters', u'kong_reuters', u'market_billion', u'initial_offering', u'business_said', u'firm_said', u'united_state', u'7_billion', u'stock_exchange', u'reuters_reported', u'source_matter', u'billion_sale', u'reuters_data', u'initial_public', u'public_offering', u'one_said', u'market_value', u'company_would', u'according_reuters', u'people_matter', u'billion_reuters', u'immediately_comment', u'source_familiar', u'sale_said', u'past_year', u'reuters_corp', u'said_declined', u'london_reuters', u'according_data', u'billion_deal', u'said_sale', u'told_reuters', u'request_comment', u'year_company', u'toshiba_corp', u'respond_request', u'respond_comment', u'billion_year', u'5_percent', u'said_source', u'8_billion', u'company_billion', u'inc_n', u'company_including', u'said_thursday', u'said_said', u'percent_percent', u'joint_venture', u'said_adding', u'deal_would', u'million_said', u'firm_billion', u'thomson_data', u'thomson_reuters', u'year_said', u'toshiba_said', u'billion_company', u'last_week', u'billion_asset', u'percent_said', u'9_billion', u'deal_said', u'said_group', u'would_company', u'bankrupt_nuclear', u'reuters_firm', u'two_said'], [u'reporting_editing', u'1_billion', u'chief_executive', u'said_would', u'declined_comment', u'new_york', u'company_said', u'2_billion', u'additional_reporting', u'billion_billion', u'private_equity', u'3_billion', u'5_billion', u'percent_stake', u'equity_firm', u'told_reuters', u'deal_said', u'private_firm', u'source_reuters', u'7_billion', u'executive_said', u'matter_said', u'familiar_matter', u'chief_officer', u'share_percent', u'deal_reuters', u'immediately_comment', u'people_matter', u'said_friday', u'billion_1', u'last_year', u'said_thursday', u'said_company', u'familiar_said', u'1_2', u'market_said', u'4_billion', u'source_said', u'million_million', u'said_could', u'deal_would', u'said_bid', u'1_1', u'business_said', u'writing_editing', u'request_comment', u'said_deal', u'worth_1', u'chief_said', u'last_month', u'worth_billion', u'new_editing', u'two_year', u'york_editing', u'united_state', u'4_percent', u'million_reuters', u'8_billion', u'6_billion', u'billion_euro', u'euro_billion', u'inc_n', u'said_said', u'said_june', u'deal_could', u'said_share', u'comment_said', u'billion_deal', u'comment_comment', u'said_statement', u'people_said', u'1_3', u'analyst_said', u'said_comment', u'company_deal', u'reuters_bank', u'1_percent', u'reporting_writing', u'respond_request', u'8_percent', u'milan_reuters', u'source_matter', u'respond_comment', u'said_million', u'one_source', u'1_euro', u'reuters_reported', u'joint_venture', u'5_percent', u'would_deal', u'executive_officer', u'million_euro', u'said_buy', u'deal_source', u'billion_including', u'bengaluru_editing', u'million_said', u'people_familiar', u'per_share', u'also_said'], [u'reporting_editing', u'billion_billion', u'1_billion', u'declined_comment', u'source_reuters', u'3_billion', u'5_billion', u'additional_reporting', u'last_year', u'2_billion', u'source_said', u'said_would', u'hong_kong', u'matter_said', u'immediately_comment', u'private_equity', u'1_1', u'7_billion', u'6_billion', u'billion_1', u'people_said', u'told_reuters', u'said_deal', u'billion_source', u'said_company', u'4_billion', u'knowledge_said', u'said_statement', u'chief_executive', u'people_matter', u'reuters_reported', u'paulo_reuters', u'billion_said', u'sao_reuters', u'sao_paulo', u'1_reporting', u'company_sai ...

# %%
# Export 
n = 0
combined = []
for _ in TOP_KEYWORDS:
    combined += _

combined_df = pd.DataFrame(combined)
combined_df = pd.DataFrame(combined_df[0].value_counts().sort_values()).reset_index()
combined_df.columns = ['keyword', 'c']

save_to = "exported/skipgram_4_%s.csv" % KEYWORD_TYPE
combined_df[['keyword']].to_csv(save_to, index=False, encoding='utf-8')
print 'Saved to ', save_to
# Out:
# Saved to  exported/skipgram_4_deal_reuter.csv

# %%
# Break the notebook 
break
# Out:
#   File "<ipython-input-172-da59c82888d2>", line 2
#     break
# SyntaxError: 'break' outside loop

# %% [markdown]
# # TF-IDF

# %%
NUM_CLUSTERS = 10
NUM_TERMS = 50

# %%
tfidf = gensim.models.tfidfmodel.TfidfModel(corpus, id2word=dictionary)
corpus_tfidf = tfidf[corpus]
tfidf.save("model/tfidf.save")

# %%
corpus_tfidf_sorted = []
TOP_KEYWORDS = []
for c in corpus_tfidf:
    top_keywords = sorted(c, key=lambda t: t[1], reverse=True)
    top_keywords = top_keywords[:NUM_TERMS]
    corpus_tfidf_sorted.append(top_keywords)
    TOP_KEYWORDS.append([dictionary[id] for id, _ in top_keywords])

# %%
print TOP_KEYWORDS[:2]

# %%
# Combine top keywords
import itertools
TOP_KEYWORDS_MERGED = list(itertools.chain(*TOP_KEYWORDS))
print "Total keywords: ", len(TOP_KEYWORDS_MERGED)
TOP_KEYWORDS_MERGED = list(set(TOP_KEYWORDS_MERGED))
print "Total keywords after combined: ", len(TOP_KEYWORDS_MERGED)
print TOP_KEYWORDS_MERGED[:10]

# %%
# Export 
save_to = "exported/tfidf/tfidf_keywords.csv"
pd.DataFrame(TOP_KEYWORDS_MERGED, columns=['keyword']).to_csv(save_to, index=False, encoding='utf-8')
print 'Saved to ', save_to

# %% [markdown]
# # TF-IDF with K-means

# %%
# NUM_CLUSTERS = 10
# NUM_TERMS = 100

# %%
# from sklearn.cluster import KMeans
# from scipy.sparse import csr_matrix
# import numpy as np

# %%
# _corpus_tfidf = gensim.matutils.corpus2csc(corpus_tfidf).transpose()
# print _corpus_tfidf[:5]

# %%
# kmeans = KMeans(n_clusters=NUM_CLUSTERS)
# X = kmeans.fit_transform(_corpus_tfidf)

# %%
# X.shape

# %%
# dir(kmeans)
# kmeans.n_clusters
